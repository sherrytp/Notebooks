# %%
from bs4 import BeautifulSoup
import requests
from lxml import html
from urllib.request import Request, urlopen
import urllib.request
from selenium import webdriver

# %%
url = "https://www.amazon.com/b/ref=gbpp_itr_m-3_01bf_Arts&Pho?node=1&ie=UTF8"


page =  requests.get(url)

# %%
url = "https://www.amazon.com/Black-Friday/b/?ie=UTF8&node=384082011&ref=nav_cs_gb"

options = webdriver.ChromeOptions()
options.add_argument('--headless')

browser = webdriver.Chrome(executable_path="/Users/sherrytp/Documents/projects/webscraping/chromedriver",options=options)
browser.get(url)
innerHTML = browser.page_source #returns the inner HTML as a string

soup = BeautifulSoup(innerHTML,'lxml')

# %%
soup.select("div.a-row.dealContainer.dealTile")
# Out:
# [<div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/KitchenAid-KL26M1XER-Professional-6-Qt-Bowl-Lift/dp/B01LYV1U30/ref=gbps_img_m-8_e218_c67f8445?smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Save on KitchenAid Professional 6-Qt. Bowl-Lift Stand Mixer" role="img" src="https://images-na.ssl-images-amazon.com/images/I/51GLdYSOcrL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base dotdBadge">DEAL OF THE DAY</span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$209.00</span>
#  </div>
#  <div class="a-row a-spacing-top-mini unitLineHeight">
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#                          Price:
#                      </span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight a-text-strike">$279.34</span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#   (25% off)
#
#                      </span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_0_dealClock" role="timer">13:28:49</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/KitchenAid-KL26M1XER-Professional-6-Qt-Bowl-Lift/dp/B01LYV1U30/ref=gbps_tit_m-8_e218_c67f8445?smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"0","widgetID":"101","dealID":"c67f8445"}'>
#              Save on KitchenAid Professional 6-Qt. Bowl-Lift Stand Mixer
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-base inlineBlock unitLineHeight autoHeight" id="shipSoldInfo" style="width: 210px;">
#  Ships from and sold by Amazon.com.
#          </span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 581 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B01LYV1U30/ref=gbps_rvw_m-8_e218_c67f8445?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"0","widgetID":"101","dealID":"c67f8445"}'>
#  <i class="a-icon a-icon-star a-star-4-5"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">581</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-addtocart" data-gbdeal-addtocart='{"dealState":"AVAILABLE","legacyDealID":"A1R95PITOPLFOX","dealType":"DEAL_OF_THE_DAY","position":"0","asin":"B01LYV1U30","widgetID":"101","offerID":"0efQXx5MSgD1%2FcAP3KoSc1ZLNIZz2%2BJGJ38HG55amNgSn2%2FLzSyEFWvafNAMfxQ36O9dvgCa401ukRJtcQD4mvxiVEkRCVCgudIkpULNcfTTp635Iy7rRA%3D%3D","dealID":"c67f8445"}'>
#  <span class="a-button a-button-normal a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><button class="a-button-text a-text-center" type="button">
#                                  Add to Cart
#                              </button></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/apb/page/ref=gbps_img_m-8_e218_a7308776?handlerName=OctopusDealLandingStream&amp;deals=a7308776&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A294P4X9EWVXLJ&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Save up to 33% on Anker Charging Accessories" role="img" src="https://m.media-amazon.com/images/I/41tHlATCacL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base dotdBadge">DEAL OF THE DAY</span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$7.69 - $59.99</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_1_dealClock" role="timer">13:23:50</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/apb/page/ref=gbps_tit_m-8_e218_a7308776?handlerName=OctopusDealLandingStream&amp;deals=a7308776&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A294P4X9EWVXLJ&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"1","widgetID":"101","dealID":"a7308776"}'>
#              Save up to 33% on Anker Charging Accessories
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 823 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B01NBQX0O5/ref=gbps_rvw_m-8_e218_a7308776?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"1","widgetID":"101","dealID":"a7308776"}'>
#  <i class="a-icon a-icon-star a-star-4-5"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">823</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"1","widgetID":"101","dealID":"a7308776"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/apb/page/ref=gbps_ulm_m-8_e218_a7308776?handlerName=OctopusDealLandingStream&amp;deals=a7308776&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A294P4X9EWVXLJ&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/apb/page/ref=gbps_img_m-8_e218_a5a6a0e8?handlerName=OctopusDealLandingStream&amp;deals=a5a6a0e8&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Save on Lord of the Rings Trilogy, The Hobbit Trilogy, and more" role="img" src="https://images-na.ssl-images-amazon.com/images/I/51803W0MkvL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base dotdBadge">DEAL OF THE DAY</span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$25.99 - $75.49</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_2_dealClock" role="timer">13:28:49</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/apb/page/ref=gbps_tit_m-8_e218_a5a6a0e8?handlerName=OctopusDealLandingStream&amp;deals=a5a6a0e8&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"2","widgetID":"101","dealID":"a5a6a0e8"}'>
#              Save on Lord of the Rings Trilogy, The Hobbit Trilogy, and more
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 10392 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B007ZQAKHU/ref=gbps_rvw_m-8_e218_a5a6a0e8?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"2","widgetID":"101","dealID":"a5a6a0e8"}'>
#  <i class="a-icon a-icon-star a-star-4-5"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">10392</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"2","widgetID":"101","dealID":"a5a6a0e8"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/apb/page/ref=gbps_ulm_m-8_e218_a5a6a0e8?handlerName=OctopusDealLandingStream&amp;deals=a5a6a0e8&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/apb/page/ref=gbps_img_m-8_e218_c08a6f78?handlerName=OctopusDealLandingStream&amp;deals=c08a6f78&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Save up to 35% on Suncast Deckboxes &amp; Patio Furniture with storage" role="img" src="https://images-na.ssl-images-amazon.com/images/I/31NmqdCOVnL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base dotdBadge">DEAL OF THE DAY</span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$39.19 - $110.89</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_3_dealClock" role="timer">13:28:49</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/apb/page/ref=gbps_tit_m-8_e218_c08a6f78?handlerName=OctopusDealLandingStream&amp;deals=c08a6f78&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;"><span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"3","widgetID":"101","dealID":"c08a6f78"}'>
#              Save up to 35% on Suncast Deckboxes &amp; Patio Furniture with ...</span></a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 1794 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B0044V3USU/ref=gbps_rvw_m-8_e218_c08a6f78?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"3","widgetID":"101","dealID":"c08a6f78"}'>
#  <i class="a-icon a-icon-star a-star-4"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">1794</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"3","widgetID":"101","dealID":"c08a6f78"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/apb/page/ref=gbps_ulm_m-8_e218_c08a6f78?handlerName=OctopusDealLandingStream&amp;deals=c08a6f78&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/apb/page/ref=gbps_img_m-8_e218_63bad85a?handlerName=OctopusDealLandingStream&amp;deals=63bad85a&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A1KWJVS57NX03I&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt='Save on Apple 12" MacBook (Mid-2017) 8GB 256GB SSD (Certified Refurbished by Apple)' role="img" src="https://images-na.ssl-images-amazon.com/images/I/41QYtRPQXIL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base dotdBadge">DEAL OF THE DAY</span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$899.99</span>
#  </div>
#  <div class="a-row a-spacing-top-mini unitLineHeight">
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#                          Price:
#                      </span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight a-text-strike">$1,299.99</span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#   (31% off)
#
#                      </span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_4_dealClock" role="timer">13:23:50</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/apb/page/ref=gbps_tit_m-8_e218_63bad85a?handlerName=OctopusDealLandingStream&amp;deals=63bad85a&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A1KWJVS57NX03I&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;"><span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"4","widgetID":"101","dealID":"63bad85a"}'>
#              Save on Apple 12" MacBook (Mid-2017) 8GB 256GB SSD (Certified ...</span></a>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"4","widgetID":"101","dealID":"63bad85a"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/apb/page/ref=gbps_ulm_m-8_e218_63bad85a?handlerName=OctopusDealLandingStream&amp;deals=63bad85a&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A1KWJVS57NX03I&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/apb/page/ref=gbps_img_m-8_e218_58ce9d4a?handlerName=OctopusDealLandingStream&amp;deals=58ce9d4a&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A298MPJAFJ2R5R&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Save 40% On Car LED Headlight Bulbs" role="img" src="https://images-na.ssl-images-amazon.com/images/I/51giG45INYL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base dotdBadge">DEAL OF THE DAY</span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$23.99 - $29.99</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_5_dealClock" role="timer">13:23:50</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/apb/page/ref=gbps_tit_m-8_e218_58ce9d4a?handlerName=OctopusDealLandingStream&amp;deals=58ce9d4a&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A298MPJAFJ2R5R&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"5","widgetID":"101","dealID":"58ce9d4a"}'>
#              Save 40% On Car LED Headlight Bulbs
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 523 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B07CG1Z9X4/ref=gbps_rvw_m-8_e218_58ce9d4a?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"5","widgetID":"101","dealID":"58ce9d4a"}'>
#  <i class="a-icon a-icon-star a-star-4"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">523</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"5","widgetID":"101","dealID":"58ce9d4a"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/apb/page/ref=gbps_ulm_m-8_e218_58ce9d4a?handlerName=OctopusDealLandingStream&amp;deals=58ce9d4a&amp;marketplaceId=ATVPDKIKX0DER&amp;smid=A298MPJAFJ2R5R&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/apb/page/ref=gbps_img_m-8_e218_6beddf86?handlerName=OctopusDealLandingStream&amp;deals=6beddf86&amp;marketplaceId=ATVPDKIKX0DER&amp;showVariations=false&amp;smid=A2N304EJPQT92P&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Save Up To 40% on Land's End Sweaters" role="img" src="https://images-na.ssl-images-amazon.com/images/I/41RR1N5EauL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base dotdBadge">DEAL OF THE DAY</span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$24.99 - $69.99</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_6_dealClock" role="timer">13:23:50</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/apb/page/ref=gbps_tit_m-8_e218_6beddf86?handlerName=OctopusDealLandingStream&amp;deals=6beddf86&amp;marketplaceId=ATVPDKIKX0DER&amp;showVariations=false&amp;smid=A2N304EJPQT92P&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"6","widgetID":"101","dealID":"6beddf86"}'>
#              Save Up To 40% on Land's End Sweaters
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 5 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B0765N9MVW/ref=gbps_rvw_m-8_e218_6beddf86?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"6","widgetID":"101","dealID":"6beddf86"}'>
#  <i class="a-icon a-icon-star a-star-4-5"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">5</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"6","widgetID":"101","dealID":"6beddf86"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/apb/page/ref=gbps_ulm_m-8_e218_6beddf86?handlerName=OctopusDealLandingStream&amp;deals=6beddf86&amp;marketplaceId=ATVPDKIKX0DER&amp;showVariations=false&amp;smid=A2N304EJPQT92P&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/Amazon-Echo-Dot-Portable-Bluetooth-Speaker-with-Alexa-Black/dp/B01DFKC2SO/ref=gbps_img_m-8_e218_2e0daa30?smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Buy 4 Echo Dots (2nd Gen), save $60 off original price" role="img" src="https://images-na.ssl-images-amazon.com/images/I/41iz5Tw82IL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleThreeLine singleCellTitle autoHeight" href="https://www.amazon.com/Amazon-Echo-Dot-Portable-Bluetooth-Speaker-with-Alexa-Black/dp/B01DFKC2SO/ref=gbps_tit_m-8_e218_2e0daa30?smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"7","widgetID":"101","dealID":"2e0daa30"}'>
#              Buy 4 Echo Dots (2nd Gen), save $60 off original price
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"7","widgetID":"101","dealID":"2e0daa30"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/Amazon-Echo-Dot-Portable-Bluetooth-Speaker-with-Alexa-Black/dp/B01DFKC2SO/ref=gbps_ulm_m-8_e218_2e0daa30?smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/Wireless-ENACFIRE-Bluetooth-Headphones-Microphone/dp/B078WP9M4F/ref=gbps_img_m-8_e218_84a3862f?smid=A30KU0DJWS6TAH&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Wireless Earbuds, ENACFIRE E18 Latest Bluetooth 5.0 True Wireless Bluetooth Earbuds 15H Playtime 3D Stereo Sound Wireless Headphones, Built-in Microphone" role="img" src="https://images-na.ssl-images-amazon.com/images/I/41ZaPJOn-fL._SCLZZZZZZZ___AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$29.99</span>
#  </div>
#  <div class="a-row a-spacing-top-mini unitLineHeight">
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#                          Price:
#                      </span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight a-text-strike">$45.99</span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#   (35% off)
#
#                      </span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <div class="a-row progbarWrapper">
#  <div class="progbar" style="width:90%"></div>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <div class="a-column a-span5 a-text-left unitLineHeight">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                      90% Claimed
#                  </span>
#  </div>
#  </div>
#  <div class="a-column a-span7 a-text-right unitLineHeight a-span-last">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_8_dealClock" role="timer">
#                  2:43:51
#              </span>
#  </div>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/Wireless-ENACFIRE-Bluetooth-Headphones-Microphone/dp/B078WP9M4F/ref=gbps_tit_m-8_e218_84a3862f?smid=A30KU0DJWS6TAH&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;"><span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"8","widgetID":"101","dealID":"84a3862f"}'>
#              Wireless Earbuds, ENACFIRE E18 Latest Bluetooth 5.0 True Wireles...</span></a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-base inlineBlock unitLineHeight autoHeight" id="shipSoldInfo" style="width: 210px;">
#  Sold by E&amp;C Store and Fulfilled by Amazon.
#          </span>
#  </div>
#  </div>
#  <div class="a-row">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 1038 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B078WP9M4F/ref=gbps_rvw_m-8_e218_84a3862f?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"8","widgetID":"101","dealID":"84a3862f"}'>
#  <i class="a-icon a-icon-star a-star-4"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">1038</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom"> <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-addtocart" data-gbdeal-addtocart='{"dealState":"AVAILABLE","legacyDealID":"A3QMQV60YA9BLE","dealType":"LIGHTNING_DEAL","position":"8","asin":"B078WP9M4F","widgetID":"101","offerID":"rV00IljOGiUcvzA8MBt1ZnS%2Fn9YuWkEdCVQPtyTcx2sN%2BfU%2FhqtSXDO7Fq4%2FCNZ9wUAyZMnnQrw7EuL%2BugzBraV6mu0Im7VJ49lIUG18xeA4rgXTb8Q6CFxPheSicVToo0pOlgMP%2FYY4CmkeBVBKX2nxIWogvxr5","dealID":"84a3862f"}'>
#  <span class="a-button a-button-normal a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><button class="a-button-text a-text-center" type="button">
#                                  Add to Cart
#                              </button></span></span>
#  </span>
#  </div></div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/Certified-Refurbished-Remote-Streaming-Player/dp/B01ETRH0AM/ref=gbps_img_m-8_e218_ae4e5fc9?smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Certified Refurbished Fire TV Stick with Alexa Voice Remote for $29.99" role="img" src="https://images-na.ssl-images-amazon.com/images/I/41vQqNH7zQL._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$29.99</span>
#  </div>
#  <div class="a-row a-spacing-top-mini unitLineHeight">
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#                          List:
#                      </span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight a-text-strike">$34.99</span>
#  <span class="a-size-base a-color-base inlineBlock unitLineHeight">
#   (14% off)
#
#                      </span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/Certified-Refurbished-Remote-Streaming-Player/dp/B01ETRH0AM/ref=gbps_tit_m-8_e218_ae4e5fc9?smid=ATVPDKIKX0DER&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"9","widgetID":"101","dealID":"ae4e5fc9"}'>
#              Certified Refurbished Fire TV Stick with Alexa Voice Remote for $29.99
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-base inlineBlock unitLineHeight autoHeight" id="shipSoldInfo">
#  Ships from and sold by Amazon.com.
#          </span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 2887 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B01ETRH0AM/ref=gbps_rvw_m-8_e218_ae4e5fc9?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"9","widgetID":"101","dealID":"ae4e5fc9"}'>
#  <i class="a-icon a-icon-star a-star-4"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">2887</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-addtocart" data-gbdeal-addtocart='{"dealState":"AVAILABLE","legacyDealID":"A27VTBATL7X5PJ","dealType":"BEST_DEAL","position":"9","asin":"B01ETRH0AM","widgetID":"101","offerID":"zx7iBcuA0E1Ayc%2FMBmLTcpSQTl9ei91DNXbl8HHjBMDVfsAn9CpDayr%2F%2FK0sjjFkwaRMGT2GQ8CTylT8dlluADZf5Hey3TxEGchwvqHJ0dyG%2B8wDKZd8Nw%3D%3D","dealID":"ae4e5fc9"}'>
#  <span class="a-button a-button-normal a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><button class="a-button-text a-text-center" type="button">
#                                  Add to Cart
#                              </button></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/Outlander-Packable-Lightweight-Backpack-Waterproof/dp/B0753D8G33/ref=gbps_img_m-8_e218_ba53be81?smid=A1WIK7FIS3TB8C&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Outlander Ultra Lightweight Packable Water Resistant Travel Hiking Backpack Daypack Handy Foldable Camping Outdoor Backpack" role="img" src="https://images-na.ssl-images-amazon.com/images/I/51IuEQ3P8rL._SCLZZZZZZZ___AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$12.31 - $22.55</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <div class="a-row progbarWrapper">
#  <div class="progbar" style="width:32%"></div>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <div class="a-column a-span5 a-text-left unitLineHeight">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                      32% Claimed
#                  </span>
#  </div>
#  </div>
#  <div class="a-column a-span7 a-text-right unitLineHeight a-span-last">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_10_dealClock" role="timer">
#                  18:51
#              </span>
#  </div>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="https://www.amazon.com/Outlander-Packable-Lightweight-Backpack-Waterproof/dp/B0753D8G33/ref=gbps_tit_m-8_e218_ba53be81?smid=A1WIK7FIS3TB8C&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;"><span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"10","widgetID":"101","dealID":"ba53be81"}'>
#              Outlander Ultra Lightweight Packable Water Resistant Travel ...</span></a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-base inlineBlock unitLineHeight autoHeight" id="shipSoldInfo" style="width: 210px;">
#  Sold by W&amp;A and Fulfilled by Amazon.
#          </span>
#  </div>
#  </div>
#  <div class="a-row">
#  <div class="a-row reviewStars">
#  <a aria-label="See all 7383 reviews" class="a-link-normal touchAnchor" href="/gp/product-reviews/B0092ECRLA/ref=gbps_rvw_m-8_e218_ba53be81?pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="link">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"REVIEWS","position":"10","widgetID":"101","dealID":"ba53be81"}'>
#  <i class="a-icon a-icon-star a-star-4-5"><span class="a-icon-alt">Avg. Customer Review</span></i>
#  <span class="a-size-small a-color-base">7383</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  <div class="a-row stackToBottom"> <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-seeoptions" data-gbdeal-seeoptions='{"dealState":"AVAILABLE","legacyDealID":"A1GEPN1PNZRLHC","dealType":"LIGHTNING_DEAL","position":"10","asin":"B0092ECRLA","widgetID":"101","offerID":"GZlzte%2F%2Fv%2BW0V98IGgGve6d9CAkuV9o9QuAEP0ICxVbPEHt5la2szZKCfPSYwGE0PYMvTvn8kjCIQa1pUnL6Wz8fz2%2BuFhC8mrnUGiWSmtQCuEtzDF8rYMWBFaZ9JmK7ZfnHotmnY80YxYWNSIrFaA%3D%3D","dealID":"ba53be81"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><button class="a-button-text a-text-center" type="button">
#                                  Choose options
#                              </button></span></span>
#  </span>
#  </div></div>
#  </div>
#  </div>, <div class="a-row dealContainer dealTile">
#  <a class="a-link-normal" href="https://www.amazon.com/Miusey-Blouses-Sweater-Vintage-Clothing/dp/B074YZ5C6X/ref=gbps_img_m-8_e218_49ff4774?smid=A1YYI53EEY1YMY&amp;pf_rd_p=5e6de09d-bef7-4e4d-bedd-33ad8096e218&amp;pf_rd_s=merchandised-search-8&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Miusey Women's Long Sleeve Cowl Neck Form Fitting Casual Tunic Top Blouse" role="img" src="https://images-na.ssl-images-amazon.com/images/I/41k6W0oZl-L._SCLZZZZZZZ___AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row priceBlock unitLineHeight">
#  <span class="a-size-medium a-color-base inlineBlock unitLineHeight">$8.99 - $25.49</span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <div class="a-row progbarWrapper">
#  <div class="progbar" style="width:21%"></div>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini unitLineHeight">
#  <div class="a-column a-span5 a-text-left unitLineHeight">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                      21% Claimed
#                  </span>
#  </div>
#  </div>
#  <div class="a-column a-span7 a-text-right unitLineHeight a-span-last">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Ends in
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight" id="101_dealView_11_dealClock" role="timer">
#                  5:03:51
#              </span>
#  </div>
#  </div>
#  </div>
# ...
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Use promo code TWOPACK and get $10 off two Fire TV Stick 4K devices" role="img" src="https://m.media-amazon.com/images/G/01/kindle/dp/2018/02254378/VX-2354-c-GOLDBOX-500x500-1X._AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <span class="a-size-mini a-color-base hiddenCss"> </span>
#  </div>
#  <div class="a-row a-spacing-mini">
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleThreeLine singleCellTitle autoHeight" href="https://www.amazon.com/Introducing-Fire-TV-Stick-4K-with-All-New-Alexa-Voice-Remote/dp/B079QHML21/ref=gbph_tit_m10_c369_8149d46d?smid=ATVPDKIKX0DER&amp;pf_rd_p=f4bd37bc-69a1-4f55-aec3-927985dac369&amp;pf_rd_s=merchandised-search-10&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"3","widgetID":"103","dealID":"8149d46d"}'>
#              Use promo code TWOPACK and get $10 off two Fire TV Stick 4K devices
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini"></div>
#  <div class="a-row stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"SEE_MORE","position":"3","widgetID":"103","dealID":"8149d46d"}'>
#  <span class="a-button a-button-span12 a-button-primary fixedWidth210"><span class="a-button-inner"><a class="a-button-text a-text-center" href="https://www.amazon.com/Introducing-Fire-TV-Stick-4K-with-All-New-Alexa-Voice-Remote/dp/B079QHML21/ref=gbph_ulm_m10_c369_8149d46d?smid=ATVPDKIKX0DER&amp;pf_rd_p=f4bd37bc-69a1-4f55-aec3-927985dac369&amp;pf_rd_s=merchandised-search-10&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" role="button">
#                                  See details
#                              </a></span></span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="a-row dealTile dealContainer">
#  <a class="a-link-normal" href="/dp/B01L8PNAS4/ref=gbph_img_m12_8c30_6788b422?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="DEARCASE Women's Long Sleeve Casual Loose T-Shirt Dress" role="img" src="https://images-na.ssl-images-amazon.com/images/I/31ST1MdaShL._SCLZZZZZZZ___AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base primeBadge peaBadge">
#  <span class="a-color-base solidBadgeText">
#                              PRIME EARLY ACCESS DEAL
#                          </span>
#  </span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  <span class="a-size-mini a-color-base badgeSkew overlapSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="/dp/B01L8PNAS4/ref=gbph_tit_m12_8c30_6788b422?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;">
#  <span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"0","widgetID":"102","dealID":"6788b422"}'>
#              DEARCASE Women's Long Sleeve Casual Loose T-Shirt Dress
#
#          </span>
#  </a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Starts for you at
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  6:20pm
#              </span>
#  </div>
#  </div>
#  <div class="a-section" id="primeOnlySection"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-base">Get access to this deal 30 minutes earlier with</span>
#  <a class="a-size-mini a-spacing-none a-spacing-top-none a-link-normal" href="/gp/prime/pipeline/membersignup/136-1855480-8607545?ie=UTF8&amp;locationId=prime_confirm&amp;primeCampaignId=primeEarlyAccess_goldboxdeals_desktop&amp;redirectURL=L0JsYWNrLUZyaWRheS9iLz9pZT1VVEY4Jm5vZGU9Mzg0MDgyMDExJnJlZj1uYXZfY3NfZ2I%3D&amp;ref=primeEarlyAccess_goldboxdeals_widgetpage">Amazon Prime.</a>
#  </div></div>
#  <div class="a-row a-spacing-top-mini stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <div class="a-column a-span12 a-spacing-none">
#  <span class="a-declarative" data-action="gbdeal-watchdeal" data-gbdeal-watchdeal='{"position":"0","widgetID":"102","asin":"","dealID":"6788b422"}'>
#  <a aria-label="Watch this deal DEARCASE Women's Long Sleeve Casual Loose T-Shirt Dress" class="a-link-normal" href="#" role="button">
#  <div class="a-row watchTheDealButton" id="watchButton_6788b422">
#  <div class="a-column a-span12 watchTheDealText">
#  <span class="a-size-base" id="watchButtonText_6788b422">
#                                              Watch this deal
#                                          </span>
#  </div>
#  </div>
#  </a>
#  </span>
#  </div>
#  </div></div>
#  </div>
#  </div>, <div class="a-row dealTile dealContainer">
#  <a class="a-link-normal" href="/dp/B01NAPQ4QP/ref=gbph_img_m12_8c30_b78dc5d4?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="DUDE Wipes Flushable Wet Wipes Dispenser (3 Packs 48 Wipes), Unscented Wet Wipes with Vitamin-E &amp; Aloe for at-Home Use, 100% Biodegradable Septic and Sewer Safe" role="img" src="https://images-na.ssl-images-amazon.com/images/I/510r8MPQBsL._SCLZZZZZZZ___AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini hiddenCss">emptyBlock</div>
#  <div class="a-row a-spacing-top-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="/dp/B01NAPQ4QP/ref=gbph_tit_m12_8c30_b78dc5d4?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;"><span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"1","widgetID":"102","dealID":"b78dc5d4"}'>
#              DUDE Wipes Flushable Wet Wipes Dispenser (3 Packs 48 Wipes), Un...</span></a>
#  </div>
#  <div class="a-row a-spacing-top-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Starts at
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  10:25am
#              </span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-top-mini stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <div class="a-column a-span12 a-spacing-none">
#  <span class="a-declarative" data-action="gbdeal-watchdeal" data-gbdeal-watchdeal='{"position":"1","widgetID":"102","asin":"","dealID":"b78dc5d4"}'>
#  <a aria-label="Watch this deal DUDE Wipes Flushable Wet Wipes Dispenser (3 Packs 48 Wipes), Unscented Wet Wipes with Vitamin-E &amp; Aloe for at-Home Use, 100% Biodegradable Septic and Sewer Safe" class="a-link-normal" href="#" role="button">
#  <div class="a-row watchTheDealButton" id="watchButton_b78dc5d4">
#  <div class="a-column a-span12 watchTheDealText">
#  <span class="a-size-base" id="watchButtonText_b78dc5d4">
#                                              Watch this deal
#                                          </span>
#  </div>
#  </div>
#  </a>
#  </span>
#  </div>
#  </div></div>
#  </div>
#  </div>, <div class="a-row dealTile dealContainer">
#  <a class="a-link-normal" href="/dp/B01N8PNS84/ref=gbph_img_m12_8c30_ec20c84f?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="Cha4TEA 36-Count K Cups Variety Tea Sampler Pack for Keurig K-Cup Brewers, Multiple Flavors (Green Tea, Black Tea, Jasmine, Earl Grey, Oolong Green Tea, English Breakfast)" role="img" src="https://images-na.ssl-images-amazon.com/images/I/61keSpjQYpL._SCLZZZZZZZ___AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base primeBadge peaBadge">
#  <span class="a-color-base solidBadgeText">
#                              PRIME EARLY ACCESS DEAL
#                          </span>
#  </span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  <span class="a-size-mini a-color-base badgeSkew overlapSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="/dp/B01N8PNS84/ref=gbph_tit_m12_8c30_ec20c84f?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;"><span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"2","widgetID":"102","dealID":"ec20c84f"}'>
#              Cha4TEA 36-Count K Cups Variety Tea Sampler Pack for Keurig K-Cu...</span></a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Starts for you at
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  7:30pm
#              </span>
#  </div>
#  </div>
#  <div class="a-section" id="primeOnlySection"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-base">Get access to this deal 30 minutes earlier with</span>
#  <a class="a-size-mini a-spacing-none a-spacing-top-none a-link-normal" href="/gp/prime/pipeline/membersignup/136-1855480-8607545?ie=UTF8&amp;locationId=prime_confirm&amp;primeCampaignId=primeEarlyAccess_goldboxdeals_desktop&amp;redirectURL=L0JsYWNrLUZyaWRheS9iLz9pZT1VVEY4Jm5vZGU9Mzg0MDgyMDExJnJlZj1uYXZfY3NfZ2I%3D&amp;ref=primeEarlyAccess_goldboxdeals_widgetpage">Amazon Prime.</a>
#  </div></div>
#  <div class="a-row a-spacing-top-mini stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <div class="a-column a-span12 a-spacing-none">
#  <span class="a-declarative" data-action="gbdeal-watchdeal" data-gbdeal-watchdeal='{"position":"2","widgetID":"102","asin":"","dealID":"ec20c84f"}'>
#  <a aria-label="Watch this deal Cha4TEA 36-Count K Cups Variety Tea Sampler Pack for Keurig K-Cup Brewers, Multiple Flavors (Green Tea, Black Tea, Jasmine, Earl Grey, Oolong Green Tea, English Breakfast)" class="a-link-normal" href="#" role="button">
#  <div class="a-row watchTheDealButton" id="watchButton_ec20c84f">
#  <div class="a-column a-span12 watchTheDealText">
#  <span class="a-size-base" id="watchButtonText_ec20c84f">
#                                              Watch this deal
#                                          </span>
#  </div>
#  </div>
#  </a>
#  </span>
#  </div>
#  </div></div>
#  </div>
#  </div>, <div class="a-row dealTile dealContainer">
#  <a class="a-link-normal" href="/dp/B07H3RVH27/ref=gbph_img_m12_8c30_407541b2?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealImage">
#  <div class="a-row a-spacing-base a-spacing-top-base imageBlock">
#  <div class="a-row dealContainer">
#  <div class="a-row layer">
#  <img alt="FEETCITY Mens Snow Boots Women Winter Anti-Slip Ankle Booties Waterproof Slip On Warm Fur Lined Sneaker" role="img" src="https://images-na.ssl-images-amazon.com/images/I/419EubP7rEL._SCLZZZZZZZ___AA210_.jpg"/>
#  </div>
#  <div class="a-row layer backGround">
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="a-row dealDetailContainer">
#  <div class="a-row a-spacing-mini">
#  <div class="a-row">
#  <span class="a-size-mini a-color-base primeBadge peaBadge">
#  <span class="a-color-base solidBadgeText">
#                              PRIME EARLY ACCESS DEAL
#                          </span>
#  </span>
#  <span class="a-size-mini a-color-base badgeSkew"></span>
#  <span class="a-size-mini a-color-base badgeSkew overlapSkew"></span>
#  </div>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <a class="a-size-base a-link-normal dealTitleTwoLine singleCellTitle autoHeight" href="/dp/B07H3RVH27/ref=gbph_tit_m12_8c30_407541b2?pf_rd_p=975d6d47-2e70-4665-a6fb-bacd91228c30&amp;pf_rd_s=merchandised-search-12&amp;pf_rd_t=101&amp;pf_rd_i=384082011&amp;pf_rd_m=ATVPDKIKX0DER&amp;pf_rd_r=ANQ2SGD12GRGAZPZXSBT" id="dealTitle" style="width: 210px;"><span class="a-declarative" data-action="gbdeal-actionrecord" data-gbdeal-actionrecord='{"actionType":"TITLE","position":"3","widgetID":"102","dealID":"407541b2"}'>
#              FEETCITY Mens Snow Boots Women Winter Anti-Slip Ankle Bo...</span></a>
#  </div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  Starts for you at
#              </span>
#  <span class="a-size-mini a-color-secondary inlineBlock unitLineHeight">
#                  9:30am
#              </span>
#  </div>
#  </div>
#  <div class="a-section" id="primeOnlySection"></div>
#  <div class="a-row a-spacing-mini">
#  <div class="a-row unitLineHeight">
#  <span class="a-size-mini a-color-base">Get access to this deal 30 minutes earlier with</span>
#  <a class="a-size-mini a-spacing-none a-spacing-top-none a-link-normal" href="/gp/prime/pipeline/membersignup/136-1855480-8607545?ie=UTF8&amp;locationId=prime_confirm&amp;primeCampaignId=primeEarlyAccess_goldboxdeals_desktop&amp;redirectURL=L0JsYWNrLUZyaWRheS9iLz9pZT1VVEY4Jm5vZGU9Mzg0MDgyMDExJnJlZj1uYXZfY3NfZ2I%3D&amp;ref=primeEarlyAccess_goldboxdeals_widgetpage">Amazon Prime.</a>
#  </div></div>
#  <div class="a-row a-spacing-top-mini stackToBottom">
#  <div class="a-row a-spacing-medium">
#  <div class="a-column a-span12 a-spacing-none">
#  <span class="a-declarative" data-action="gbdeal-watchdeal" data-gbdeal-watchdeal='{"position":"3","widgetID":"102","asin":"","dealID":"407541b2"}'>
#  <a aria-label="Watch this deal FEETCITY Mens Snow Boots Women Winter Anti-Slip Ankle Booties Waterproof Slip On Warm Fur Lined Sneaker" class="a-link-normal" href="#" role="button">
#  <div class="a-row watchTheDealButton" id="watchButton_407541b2">
#  <div class="a-column a-span12 watchTheDealText">
#  <span class="a-size-base" id="watchButtonText_407541b2">
#                                              Watch this deal
#                                          </span>
#  </div>
#  </div>
#  </a>
#  </span>
#  </div>
#  </div></div>
#  </div>
#  </div>]

# %% [markdown]
# # Login

# %%
loginUrl = "https://www.amazon.com/ap/signin?_encoding=UTF8&accountStatusPolicy=P1&openid.assoc_handle=usflex&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.mode=checkid_setup&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&openid.ns.pape=http%3A%2F%2Fspecs.openid.net%2Fextensions%2Fpape%2F1.0&openid.pape.max_auth_age=0&openid.return_to=https%3A%2F%2Fwww.amazon.com%2Fgp%2Fcss%2Forder-history%3Fie%3DUTF8%26ref_%3Dnav_youraccount_orders&pageId=webcs-yourorder&showRmrMe=1"

page = requests.get(loginUrl)

# %%
# Browser

options = webdriver.ChromeOptions()
options.add_argument('--headless')

browser = webdriver.Chrome(executable_path="/Users/sherrytp/Documents/projects/webscraping/chromedriver")
browser.get(loginUrl)
innerHTML = browser.page_source #returns the inner HTML as a string

soup1 = BeautifulSoup(innerHTML,'lxml')

# %%
soup1.findAll('input')
# Out:
# [<input name="appActionToken" type="hidden" value="mdRjvij2B36XgXSaZW2PXhAftxAcAj3D"/>,
#  <input name="appAction" type="hidden" value="SIGNIN"/>,
#  <input name="openid.return_to" type="hidden" value="ape:aHR0cHM6Ly93d3cuYW1hem9uLmNvbS9ncC9jc3Mvb3JkZXItaGlzdG9yeT9pZT1VVEY4JnJlZl89bmF2X3lvdXJhY2NvdW50X29yZGVycw=="/>,
#  <input name="prevRID" type="hidden" value="ape:QzhISjFWWkJKUU0zRjc1NzZIWEY="/>,
#  <input name="workflowState" type="hidden" value="eyJ6aXAiOiJERUYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiQTI1NktXIn0.-rGEpwoz-fxmG44Cr64iZxiVVpGWqnb5coEnbawAY3XoP6DEsQ9foA.X7zz-OdY1h9FxQ8k.FgvZdz5MD8C8bVXVCB2uoWBKkat5iBCVGGl-CE46QIC3i8x0jPFu-wzUlQSi6x43lBSxbYMhdB1-aO4t1Y3Dky_cT0vmAgytSnYgoAdGU18KS7FBmOi5aHcV-pCtuXBJC7qOHU-kzoGiYR2jnKe3oF-WnEVcfq7m0FX_K30Kw8rzx6Av28eCts0jiaRKrZPK_PETvzOj2uMDyjGk6H1OzFJtV2t4ZKYjUHSWYdxkIZUA0CNsZLzd3pfhIOnx1zpRW6JUIfKKClRP67rviBQAJMTokOy8_UMFRUqBJDQkDRBJ_S1sMaL25-H1JfGXvfXK-5lGONrYxb4g2Jjo0vKi0KwB5zYdOrulzFWWdjLRMrJnOQ.9DTiRmSq_6gIt7HVbpJmDg"/>,
#  <input class="a-input-text a-span12 auth-autofocus auth-required-field" id="ap_email" maxlength="128" name="email" tabindex="1" type="email"/>,
#  <input name="create" type="hidden" value="0"/>,
#  <input class="a-input-text a-span12 auth-required-field" id="ap_password" name="password" tabindex="2" type="password"/>,
#  <input aria-labelledby="a-autoid-0-announce" class="a-button-input" id="signInSubmit" tabindex="5" type="submit"/>,
#  <input name="rememberMe" tabindex="4" type="checkbox" value="true"/>,
#  <input name="ue_back" type="hidden" value="2"/>]

# %%
soup1.find("input",{'id':'ap_email'})
# Out:
# <input class="a-input-text a-span12 auth-autofocus auth-required-field" id="ap_email" maxlength="128" name="email" tabindex="1" type="email"/>

# %%
soup1.find("input",{'id':'ap_password'})
# Out:
# <input class="a-input-text a-span12 auth-required-field" id="ap_password" name="password" tabindex="2" type="password"/>

# %%
username = browser.find_element_by_id("ap_email") #username form field
password = browser.find_element_by_id("ap_password") #password form field

username.send_keys("zl2528@columbia.edu")
password.send_keys("****")

submitButton = browser.find_element_by_id("signInSubmit") 
submitButton.click()

# %%
email = browser.find_element_by_id("ap_email")
password = browser.find_element_by_id("ap_password")

# %%
email.send_keys("liuasr@bc.edu")
password.send_keys("Lrf700817")

# %%
loginButton = browser.find_element_by_id("a-autoid-0")

# %%
loginButton.click()

# %%
linkList = soup.select(".herf")

# %%
tmpPath = link.find("a").attrs.get("href")

# %%
bookRow = soup.select(".a-row.a-spacing-none")

# %%
# Book Title

list1 = soup.select(".a-link-normal.s-access-detail-page.s-color-twister-title-link.a-text-normal")

# %%
list1[2].text

# %%
list1[0].attrs.get('href')
# Out:
# 'https://www.amazon.com/Homebody-Guide-Creating-Spaces-Never/dp/006280197X/ref=lp_1_1_1/136-4231815-0885743?s=books&ie=UTF8&qid=1541910523&sr=1-1'

# %% [markdown]
# ### 1 get all href and text simutanousely
#
# ### 2 save them to dictionary, dic = {} dic[bookname] = href

# %%
dicBook = {}

for link in list1:
    bookLink = link.attrs.get("href")
    bookTitle = link.text

    dicBook[bookTitle] = bookLink

# %%
pd.DataFrame([dicBook.keys(),dicBook.values()]).transpose()
# Out:
#                                                     0  \
# 0   Homebody: A Guide to Creating Spaces You Never...
# 1                                   Beastie Boys Book
# 2   Hindsight: & All the Things I Can't See in Fro...
# 3   The 5 Love Languages: The Secret to Love that ...
# 4   Whiskey in a Teacup: What Growing Up in the So...
# 5                     Shade: A Tale of Two Presidents
# 6        Cozy Minimalist Home: More Style, Less Stuff
# 7   National Geographic The Photo Ark: One Man's Q...
# 8   Katie Daisy 2018 - 2019 On-the-Go Weekly Plann...
# 9   Dungeons and Dragons Art and Arcana [Special E...
# 10  Lettering and Modern Calligraphy: A Beginner's...
# 11  Dungeons and Dragons Art and Arcana: A Visual ...
#
#                                                     1
# 0   https://www.amazon.com/Homebody-Guide-Creating...
# 1   https://www.amazon.com/Beastie-Boys-Book-Micha...
# 2   https://www.amazon.com/Hindsight-All-Things-Ca...
# 3   https://www.amazon.com/Love-Languages-Secret-t...
# 4   https://www.amazon.com/Whiskey-Teacup-Growing-...
# 5   https://www.amazon.com/Shade-Tale-Presidents-P...
# 6   https://www.amazon.com/Cozy-Minimalist-Home-St...
# 7   https://www.amazon.com/National-Geographic-Pho...
# 8   https://www.amazon.com/Katie-Daisy-2018-Go-17-...
# 9   https://www.amazon.com/Dungeons-Dragons-Arcana...
# 10  https://www.amazon.com/Lettering-Modern-Callig...
# 11  https://www.amazon.com/Dungeons-Dragons-Art-Ar...

# %%
bookLink
# Out:
# 'https://www.amazon.com/Dungeons-Dragons-Art-Arcana-History/dp/0399580948/ref=lp_1_1_12/136-4231815-0885743?s=books&ie=UTF8&qid=1541910523&sr=1-12'

# %%
bookTitle
# Out:
# 'Dungeons and Dragons Art and Arcana: A Visual History'

# %%
dicBook = {}
dicBook[bookTitle] = bookLink

# %%
dicBook
# Out:
# {'Dungeons and Dragons Art and Arcana: A Visual History': 'https://www.amazon.com/Dungeons-Dragons-Art-Arcana-History/dp/0399580948/ref=lp_1_1_12/136-4231815-0885743?s=books&ie=UTF8&qid=1541910523&sr=1-12'}

# %%
list1
# Out:
# [<a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Beastie-Boys-Book-Michael-Diamond/dp/0812995546/ref=lp_1_1_1/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-1" title="Beastie Boys Book"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Beastie Boys Book" data-max-rows="0">Beastie Boys Book</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Homebody-Guide-Creating-Spaces-Never/dp/006280197X/ref=lp_1_1_2/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-2" title="Homebody: A Guide to Creating Spaces You Never Want to Leave"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Homebody: A Guide to Creating Spaces You Never Want to Leave" data-max-rows="0">Homebody: A Guide to Creating Spaces You Never Want to Leave</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Hindsight-All-Things-Cant-Front/dp/0062448307/ref=lp_1_1_3/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-3" title="Hindsight: &amp; All the Things I Can't See in Front of Me"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Hindsight: &amp; All the Things I Can't See in Front of Me" data-max-rows="0">Hindsight: &amp; All the Things I Can't See in Front of Me</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Love-Languages-Secret-that-Lasts/dp/080241270X/ref=lp_1_1_4/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-4" title="The 5 Love Languages: The Secret to Love that Lasts"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="The 5 Love Languages: The Secret to Love that Lasts" data-max-rows="0">The 5 Love Languages: The Secret to Love that Lasts</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Whiskey-Teacup-Growing-Taught-Biscuits/dp/1501166271/ref=lp_1_1_5/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-5" title="Whiskey in a Teacup: What Growing Up in the South Taught Me About Life, Love, and Baking Biscuits"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Whiskey in a Teacup: What Growing Up in the South Taught Me About Life, Love, and Baking Biscuits" data-max-rows="2">Whiskey in a Teacup: What Growing Up in the South Taught Me About Life, Love, and Baking Biscuits</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Shade-Tale-Presidents-Pete-Souza/dp/0316421820/ref=lp_1_1_6/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-6" title="Shade: A Tale of Two Presidents"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Shade: A Tale of Two Presidents" data-max-rows="0">Shade: A Tale of Two Presidents</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Cozy-Minimalist-Home-Style-Stuff/dp/0310350913/ref=lp_1_1_7/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-7" title="Cozy Minimalist Home: More Style, Less Stuff"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Cozy Minimalist Home: More Style, Less Stuff" data-max-rows="0">Cozy Minimalist Home: More Style, Less Stuff</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/National-Geographic-Photo-Ark-Document/dp/1426217773/ref=lp_1_1_8/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-8" title="National Geographic The Photo Ark: One Man's Quest to Document the World's Animals"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="National Geographic The Photo Ark: One Man's Quest to Document the World's Animals" data-max-rows="0">National Geographic The Photo Ark: One Man's Quest to Document the World's Animals</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Dungeons-Dragons-Arcana-Special-Ephemera/dp/0399582754/ref=lp_1_1_9/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-9" title="Dungeons and Dragons Art and Arcana [Special Edition, Boxed Book &amp; Ephemera Set]: A Visual History"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Dungeons and Dragons Art and Arcana [Special Edition, Boxed Book &amp; Ephemera Set]: A Visual History" data-max-rows="2">Dungeons and Dragons Art and Arcana [Special Edition, Boxed Book &amp; Ephemera Set]: A Visual History</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Katie-Daisy-2018-Go-17-Month/dp/1631363867/ref=lp_1_1_10/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-10" title="Katie Daisy 2018 - 2019 On-the-Go Weekly Planner: 17-Month Calendar with Pocket (Aug 2018 - Dec 2019, 5 x 7 closed)"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Katie Daisy 2018 - 2019 On-the-Go Weekly Planner: 17-Month Calendar with Pocket (Aug 2018 - Dec 2019, 5 x 7 closed)" data-max-rows="2">Katie Daisy 2018 - 2019 On-the-Go Weekly Planner: 17-Month Calendar with Pocket (Aug 2018 - Dec 2019, 5 x 7 closed)</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Dungeons-Dragons-Art-Arcana-History/dp/0399580948/ref=lp_1_1_11/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-11" title="Dungeons and Dragons Art and Arcana: A Visual History"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Dungeons and Dragons Art and Arcana: A Visual History" data-max-rows="0">Dungeons and Dragons Art and Arcana: A Visual History</h2></a>,
#  <a class="a-link-normal s-access-detail-page s-color-twister-title-link a-text-normal" href="https://www.amazon.com/Lettering-Modern-Calligraphy-Beginners-Guide/dp/1948209004/ref=lp_1_1_12/142-6347245-5465727?s=books&amp;ie=UTF8&amp;qid=1541611129&amp;sr=1-12" title="Lettering and Modern Calligraphy: A Beginner's Guide: Learn Hand Lettering and Brush Lettering"><h2 class="a-size-medium s-inline s-access-title a-text-normal" data-attribute="Lettering and Modern Calligraphy: A Beginner's Guide: Learn Hand Lettering and Brush Lettering" data-max-rows="2">Lettering and Modern Calligraphy: A Beginner's Guide: Learn Hand Lettering and Brush Lettering</h2></a>]
