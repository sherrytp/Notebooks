# %% [markdown]
# <a href="https://www.kaggle.com/code/sherrytp/scrapping-twitter?scriptVersionId=126240043" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from bs4 import BeautifulSoup
import requests
from lxml import html
from urllib.request import Request, urlopen
import urllib.request
from selenium import webdriver
import os

# %%
url = "https://twitter.com/HoustonRockets"


options = webdriver.ChromeOptions()
options.add_argument('--headless')

# browser = webdriver.Chrome(executable_path="/Users/yangyufan/Desktop/Python/Webscraping/chromedriver",options=options)
browser = webdriver.Chrome(executable_path="/Users/sherrytp/Desktop/Python/Webscraping/chromedriver")

browser.get(url)
innerHTML = browser.page_source #returns the inner HTML as a string

soup = BeautifulSoup(innerHTML,'lxml')

# %%
username = browser.find_element_by_name("session[username_or_email]")
password = browser.find_element_by_name("session[password]")

# %%
username.send_keys("8572091349")
password.send_keys("yyf416069")

# %%
loginButton = browser.find_elements_by_tag_name('input')

# %%
browser.find_element_by_xpath('//input[@value="Log in"]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-34-2c7cbb477549> in <module>()
# ----> 1 browser.find_element_by_xpath('//input[text()="Log in"]').click()
#       2
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     383             element = driver.find_element_by_xpath('//div/td[1]')
#     384         """
# --> 385         return self.find_element(by=By.XPATH, value=xpath)
#     386
#     387     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     953         return self.execute(Command.FIND_ELEMENT, {
#     954             'using': by,
# --> 955             'value': value})['value']
#     956
#     957     def find_elements(self, by=By.ID, value=None):
#
# ...
