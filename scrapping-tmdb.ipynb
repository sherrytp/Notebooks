# %% [markdown]
# <a href="https://www.kaggle.com/code/sherrytp/scrapping-tmdb?scriptVersionId=126239963" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.themoviedb.org/movie?language=en-US"

# %%
response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')
# soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# # Movie Poster Url Scrape

# %%
#### Eg: nested structure

posterUrl = soup.select(".item.poster.card.image_content.result")
posterUrl
# Out:
# [<a alt="Venom" class="result" href="/movie/335983?language=en-US" id="movie_335983" title="Venom">
#  <img alt="Venom" class="poster lazyload fade" data-sizes="auto" data-src="https://image.tmdb.org/t/p/w185_and_h278_bestv2/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg" data-srcset="https://image.tmdb.org/t/p/w185_and_h278_bestv2/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg 1x, https://image.tmdb.org/t/p/w370_and_h556_bestv2/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg 2x"/>
#  <div class="meta">
#  <span class="hide popularity_rank_value" id="popularity_552f0466c3a3685951000ba5_value">
#  <div class="tooltip_popup popularity">
#  <h3>Popularity Rank</h3>
#  <p><span>Today:</span> 1</p>
#  <p><span>Last Week:</span> 1</p>
#  </div>
#  </span>
#  <span class="glyphicons glyphicons-cardio x1 popularity_rank" id="popularity_552f0466c3a3685951000ba5"></span>
#  <span class="right">
#  </span>
#  </div>
#  </a>,
# ...

# %%
ImgList = soup.select("div.image_content")

# %%
ImgList[0].find("img").attrs.get("data-src")
# Out:
# 'https://image.tmdb.org/t/p/w185_and_h278_bestv2/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg'

# %%
"poster fade lazyautosizes lazyloaded"
soup.select(".poster.fade.lazyautosizes.lazyloaded")
# Out:
# []

# %%
"""Get the url """
rawPosterUrl = soup.select('.poster.lazyload.fade')
PosterUrl = list(map(lambda x:x.attrs.get('data-src'),rawPosterUrl))

"""Download the poster to local"""
#urllib.request.urlretrieve(url, path)
# Out:
# 'Download the poster to local'

# %%
PosterUrl
# Out:
# ['https://image.tmdb.org/t/p/w185_and_h278_bestv2/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/bXs0zkv2iGVViZEy78teg2ycDBm.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/x1txcDXkcM65gl7w20PwYSxAYah.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/lgYGPujZNckyKwQQNwMLmkWoKui.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/wrFpXMNBRj2PBiN4Z5kix51XaIZ.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/cQvc9N6JiMVKqol3wcYrGshsIdZ.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/rW0A73hjzPWVwADlCTLnjLhAFLX.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/sFC1ElvoKGdHJIWRpNB3xWJ9lJA.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/2L8ehd95eSW9x7KINYtZmRkAlrZ.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/eyWICPcxOuTcDDDbTMOZawoOn8d.jpg',
#  'https://image.tmdb.org/t/p/w185_and_h278_bestv2/jf7jiy0rDVn1ljUwv3pWKousQ1p.jpg',
# ...
