# %%
from urllib.request import urlopen,Request
from bs4 import BeautifulSoup as BS #BeautifulSoup is a Python library                                  
import urllib.request
import urllib.parse
import urllib.error
import ssl
import re
import pandas as pd
import np
import json
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

def get_headers():
    #Headers
    headers={'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
            'accept-language':'en-US,en;q=0.9',
            'cache-control':'max-age=0',
            'upgrade-insecure-requests':'1',
            'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'}

    return headers


ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
count=1 # for pagination
address=[]
rent=[]
sch_crime=[]
sugg_income=[]
add1=[]
area=[]
bed=[]
bath=[]
floor=[]
commute=[]
descp=[]
addr_link=[]
urls = ["https://www.trulia.com/for_rent/Oakland,CA/1p_beds/SINGLE-FAMILY_HOME_type/",
         "https://www.trulia.com/for_rent/San_Jose,CA/1p_beds/SINGLE-FAMILY_HOME_type/",
       "https://www.trulia.com/for_rent/San_Francisco,CA/1p_beds/SINGLE-FAMILY_HOME_type/",
       "https://www.trulia.com/for_rent/Sunnyvale,CA/1p_beds/SINGLE-FAMILY_HOME_type/",
       "https://www.trulia.com/for_rent/Berkeley,CA/1p_beds/SINGLE-FAMILY_HOME_type/",
       "https://www.trulia.com/for_rent/Fremont,CA/1p_beds/SINGLE-FAMILY_HOME_type/",
       "https://www.trulia.com/for_rent/Pleasanton,CA/1p_beds/SINGLE-FAMILY_HOME_type/",
       "https://www.trulia.com/for_rent/Livermore,CA/SINGLE-FAMILY_HOME_type/"]


for x in urls:
    count=1
    y=x
    while(count < 5):  # Until 4 Pages
        print(x)
        req = Request(x, headers=get_headers())  #req all headers
        htmlfile = urlopen(req)
        htmltext = htmlfile.read()
        #print (htmltext)
        soup = BS(htmltext,'html.parser')
        #print (soup.prettify())
       
        for tag in soup.findAll('div',attrs={'data-testid':'property-price'}): #Rent
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                rent.append(row)

                  
        for tag in soup.findAll('div',attrs={'data-testid':'property-region'}): #address line 1
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                add1.append(row)
               
        for tag in soup.findAll('div',attrs={'data-testid':'property-street'}): #area code
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                area.append(row)
               
        for tag in soup.findAll('div',attrs={'data-testid':'property-beds'}): #bed
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                bed.append(row)
               
        for tag in soup.findAll('div',attrs={'data-testid':'property-baths'}): #bath
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                bath.append(row)
               
        for tag in soup.findAll('div',attrs={'data-testid':'property-floorSpace'}):  #floorsize
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                floor.append(row)
                                           

        links=[]
        for cards in soup.findAll('div',attrs={'class':'Box-sc-8ox7qa-0 jIGxjA PropertyCard__PropertyCardContainer-sc-1ush98q-2 gKJaNz'}):
           
            for link in cards.findAll('a', attrs={'href': re.compile("^/")}):
                links.append("https://www.trulia.com"+link.get('href')) #appends all links in the page
       
         # picking up each link and reading inside it    
        for link in links:
            addr_link.append(link)
            req = Request(link, headers=get_headers())
            htmlfile = urlopen(req)
            htmltext = htmlfile.read()
            soup = BS(htmltext,'html.parser')  # Reads inside links
            
           
            for tag in soup.findAll('div',attrs={'aria-label':'Crime'}):  # crime
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                sch_crime.append(row)
           
            for tag in soup.findAll('span',attrs={'class':'Text__TextBase-sc-1i9uasc-0 fOuqJu'}): # suggested income
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                sugg_income.append(row)
               
            for tag in soup.findAll('div',attrs={'data-testid':'explore-the-area-commuteTab'}): #commute
                row = tag.get_text()
                if not row:
                    row="NA"
                print(row)
                commute.append(row) #commute
             
            for tag in soup.findAll('div',attrs={'data-testid':'seo-description-paragraph'}): #descpription
                row = tag.get_text()

                print(row)
                descp.append(row) #commute
             
            
        count=count+1
        page=str(count)+"_p"  # changes page,will go till page 4,total 120 links per city
        x=y+page
data_frame = pd.DataFrame(list(zip(add1,area,rent,bed,bath,floor,descp,commute,sch_crime,sugg_income,addr_link)),columns=["Address","Location","Rent","Bed","Bath","Size","Description","Commute","Crime","Income","URL"])
data_frame
# Out:
# https://www.trulia.com/for_rent/Oakland,CA/1p_beds/SINGLE-FAMILY_HOME_type/
# $2,400/mo
# $1,700/mo
# $1,800/mo
# $2,400/mo
# $3,199/mo
# $2,950/mo
# $2,950/mo
# $3,975/mo
# $3,200/mo
# $3,600/mo
# $2,200/mo
# $2,799/mo
# $3,400/mo
# $2,850/mo
# $3,800/mo
# $3,000/mo
# $2,950/mo
# $4,250/mo
# $3,000/mo
# $3,900/mo
# $2,690/mo
# $2,550/mo
# $1,650/mo
# $2,650/mo
# $3,000/mo
# $2,400/mo
# $3,500/mo
# $2,200/mo
# $4,900/mo
# $2,400/mo
# Produce & Waterfront, Oakland, CA
# Prescott, Oakland, CA
# Upper Laurel, Oakland, CA
# Clinton, Oakland, CA
# Clawson, Oakland, CA
# Hoover/Foster, Oakland, CA
# Tuxedo, Oakland, CA
# Montclair, Oakland, CA
# Santa Fe, Oakland, CA
# Pill Hill, Oakland, CA
# Allendale, Oakland, CA
# Jefferson, Oakland, CA
# Longfellow, Oakland, CA
# Shafter, Oakland, CA
# Forestland, Oakland, CA
# Patten, Oakland, CA
# Seminary, Oakland, CA
# Forestland, Oakland, CA
# Hegenberger, Oakland, CA
# Crestmont, Oakland, CA
# Havenscourt, Oakland, CA
# Webster, Oakland, CA
# Frick, Oakland, CA
# Lynn, Oakland, CA
# Jefferson, Oakland, CA
# Elmhurst Park, Oakland, CA
# Millsmont, Oakland, CA
# Oakland, CA
# Cleveland Heights, Oakland, CA
# Arroyo Viejo, Oakland, CA
# 321 Castro St
# 1687 8th St
# Address Not Disclosed
# 2243 12th Ave
# 1064 30th St
# 692 31st St
# 2215 E 29th St
# 2185 Trafalgar Pl
# 843 60th St
# 32nd St
# Address Not Disclosed
# Address Not Disclosed
# Address Not Disclosed
# 421 Avon St #B
# 7028 Homewood Dr
# 2834 Atwell Ave
# 6000 Holway St
# Address Not Disclosed
# 1921 73rd Ave
# Address Not Disclosed
# 2598 61st Ave
# 1700 83rd Ave
# 2834 Seminary Ave
# Address Not Disclosed
# 2027 High St
# 9411 E St
# 6441 Mokelumne Ave
# 3531 Rhoda Ave
# Address Not Disclosed
# 1491 82nd Ave
# 3bd
# 1bd
# 2bd
# 2bd
# 3bd
# 2bd
# 3bd
# 3bd
# 3bd
# 4bd
# 2bd
# 2bd
# 3bd
# 2bd
# 2bd
# 3bd
# 2bd
# 2bd
# 3bd
# 3bd
# 2bd
# 2bd
# 1bd
# 1bd
# 3bd
# 2bd
# 2bd
# 1bd
# 3bd
# 2bd
# 1ba
# 1ba
# 1ba
# 1ba
# 2ba
# 1ba
# 1ba
# 2ba
# 1ba
# 2.5ba
# 1ba
# 1ba
# 2.5ba
# 1ba
# 1ba
# 2ba
# 2ba
# 2ba
# 1.5ba
# 2ba
# 1ba
# 1ba
# 1ba
# 1ba
# 2ba
# 1ba
# 1ba
# 1ba
# 1.5ba
# 1ba
# 900 sqft
# 450 sqft
# 700 sqft
# 1,017 sqft
# 1,100 sqft
# 1,000 sqft
# 1,300 sqft
# 1,000 sqft
# 950 sqft
# 912 sqft
# 1,412 sqft
# 750 sqft
# 1,250 sqft
# 1,500 sqft
# 1,050 sqft
# 1,600 sqft
# 1,550 sqft
# 839 sqft
# 700 sqft
# 1,292 sqft
# 900 sqft
# 1,200 sqft
# 608 sqft
# 1,285 sqft
# CrimeLow crime relative to the rest of Alameda county.
# $86,400
# Commute60% of residents commute by car.
# 321 Castro St, Oakland, CA is a 3 bedroom, 1 bathroom, 900 sqft single-family home. 321 Castro St is located in Produce & Waterfront, Oakland. 321 Castro St was listed for rent for $2,400/month on Mar 12, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $61,200
# Commute60% of residents commute by car.
# 1687 8th St, Oakland, CA is a 1 bedroom, 1 bathroom, 450 sqft single-family home built in 2006. 1687 8th St is located in Prescott, Oakland. 1687 8th St was listed for rent for $1,700/month on Mar 9, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $64,800
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 700 sqft single-family home built in 1920. This home is located in Upper Laurel, Oakland. This property was listed for rent for $1,800/month on Mar 12, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $86,400
# Commute70% of residents commute by car.
# 2243 12th Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 1,991 sqft single-family home built in 1890. 2243 12th Ave is located in Clinton, Oakland. 2243 12th Ave was listed for rent for $2,400/month on Mar 4, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $115,164
# Commute67% of residents commute by car.
# 1064 30th St, Oakland, CA is a 3 bedroom, 2 bathroom, 1,017 sqft single-family home built in 1897. 1064 30th St is located in Clawson, Oakland. 1064 30th St was listed for rent for $3,199/month on Mar 11, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $106,200
# Commute58% of residents commute by car.
# 692 31st St, Oakland, CA is a 2 bedroom, 1 bathroom, 1,100 sqft single-family home built in 1904. 692 31st St is located in Hoover/Foster, Oakland. 692 31st St was listed for rent for $2,950/month on Mar 3, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $106,200
# Commute70% of residents commute by car.
# 2215 E 29th St, Oakland, CA is a 3 bedroom, 1 bathroom, 1,000 sqft single-family home built in 1919. 2215 E 29th St is located in Tuxedo, Oakland. 2215 E 29th St was listed for rent for $2,950/month on Mar 6, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $143,100
# Commute79% of residents commute by car.
# 2185 Trafalgar Pl, Oakland, CA is a 3 bedroom, 2 bathroom, 1,300 sqft single-family home built in 1972. 2185 Trafalgar Pl is located in Montclair, Oakland. 2185 Trafalgar Pl was listed for rent for $3,975/month on Mar 7, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $115,200
# Commute67% of residents commute by car.
# 843 60th St, Oakland, CA is a 3 bedroom, 1 bathroom, 1,000 sqft single-family home built in 1907. 843 60th St is located in Santa Fe, Oakland. 843 60th St was listed for rent for $3,200/month on Mar 3, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $129,600
# Commute58% of residents commute by car.
# 32nd St, Oakland, CA is a 4 bedroom, 2.5 bathroom single-family home. 32nd St is located in Pill Hill, Oakland. 32nd St was listed for rent for $3,600/month on Mar 5, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $79,200
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 950 sqft single-family home. This home is located in Allendale, Oakland. This property was listed for rent for $2,200/month on Mar 10, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $100,764
# Commute74% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 912 sqft single-family home built in 1914. This home is located in Jefferson, Oakland. This property was listed for rent for $2,799/month on Mar 11, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $122,400
# Commute67% of residents commute by car.
# This home in Oakland, CA is a 3 bedroom, 2.5 bathroom, 1,412 sqft single-family home built in 2006. This home is located in Longfellow, Oakland. This property was listed for rent for $3,400/month on Mar 12, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $102,600
# Commute64% of residents commute by car.
# 421 Avon St #B, Oakland, CA is a 2 bedroom, 1 bathroom, 750 sqft single-family home. 421 Avon St #B is located in Shafter, Oakland. 421 Avon St #B was listed for rent for $2,850/month on Mar 11, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $136,800
# Commute79% of residents commute by car.
# 7028 Homewood Dr, Oakland, CA is a 2 bedroom, 1 bathroom, 792 sqft single-family home built in 1942. 7028 Homewood Dr is located in Forestland, Oakland. 7028 Homewood Dr was listed for rent for $3,800/month on Mar 11, 2020.
# CrimeHigh crime relative to the rest of Alameda county.
# $108,000
# Commute74% of residents commute by car.
# 2834 Atwell Ave, Oakland, CA is a 3 bedroom, 2 bathroom, 1,250 sqft single-family home. 2834 Atwell Ave is located in Patten, Oakland. 2834 Atwell Ave was listed for rent for $3,000/month on Mar 12, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $106,200
# Commute80% of residents commute by car.
# 6000 Holway St, Oakland, CA is a 2 bedroom, 2 bathroom, 1,187 sqft single-family home built in 1923. 6000 Holway St is located in Seminary, Oakland. 6000 Holway St was listed for rent for $2,950/month on Mar 7, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $153,000
# Commute79% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 2 bathroom, 1,500 sqft single-family home built in 1984. This home is located in Forestland, Oakland. This property was listed for rent for $4,250/month on Mar 4, 2020. This property is pet friendly.
# CrimeHighest crime relative to the rest of Alameda county.
# $108,000
# Commute80% of residents commute by car.
# 1921 73rd Ave, Oakland, CA is a 3 bedroom, 1.5 bathroom, 1,050 sqft single-family home. 1921 73rd Ave is located in Hegenberger, Oakland. 1921 73rd Ave was listed for rent for $3,000/month on Mar 5, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $140,400
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 3 bedroom, 2 bathroom, 1,600 sqft single-family home built in 1956. This home is located in Crestmont, Oakland. This property was listed for rent for $3,900/month on Mar 12, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $96,840
# Commute85% of residents commute by car.
# 2598 61st Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 1,550 sqft single-family home. 2598 61st Ave is located in Havenscourt, Oakland. 2598 61st Ave was listed for rent for $2,690/month on Mar 9, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $91,800
# Commute80% of residents commute by car.
# 1700 83rd Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 1,170 sqft single-family home built in 1928. 1700 83rd Ave is located in Webster, Oakland. 1700 83rd Ave was listed for rent for $2,550/month on Mar 4, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $59,400
# Commute85% of residents commute by car.
# 2834 Seminary Ave, Oakland, CA is a 1 bedroom, 1 bathroom, 839 sqft single-family home built in 1940. 2834 Seminary Ave is located in Frick, Oakland. 2834 Seminary Ave was listed for rent for $1,650/month on Mar 11, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $95,400
# Commute75% of residents commute by car.
# This home in Oakland, CA is a 1 bedroom, 1 bathroom, 700 sqft single-family home built in 1925. This home is located in Lynn, Oakland. This property was listed for rent for $2,650/month on Mar 7, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $108,000
# Commute74% of residents commute by car.
# 2027 High St, Oakland, CA is a 3 bedroom, 2 bathroom, 1,292 sqft single-family home built in 1908. 2027 High St is located in Jefferson, Oakland. 2027 High St was listed for rent for $3,000/month on Mar 11, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $86,400
# Commute81% of residents commute by car.
# 9411 E St, Oakland, CA is a 2 bedroom, 1 bathroom, 900 sqft single-family home built in 1920. 9411 E St is located in Elmhurst Park, Oakland. 9411 E St was listed for rent for $2,400/month on Mar 8, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $126,000
# Commute85% of residents commute by car.
# 6441 Mokelumne Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 1,200 sqft single-family home built in 1938. 6441 Mokelumne Ave is located in Millsmont, Oakland. 6441 Mokelumne Ave was listed for rent for $3,500/month on Mar 11, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $79,200
# Commute81% of residents commute by car.
# 3531 Rhoda Ave, Oakland, CA is a 1 bedroom, 1 bathroom, 608 sqft single-family home. 3531 Rhoda Ave was listed for rent for $2,200/month on Mar 10, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $176,400
# Commute70% of residents commute by car.
# This home in Oakland, CA is a 3 bedroom, 1.5 bathroom, 1,285 sqft single-family home built in 1923. This home is located in Cleveland Heights, Oakland. This property was listed for rent for $4,900/month on Mar 5, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $86,400
# Commute80% of residents commute by car.
# 1491 82nd Ave, Oakland, CA is a 2 bedroom, 1 bathroom single-family home. 1491 82nd Ave is located in Arroyo Viejo, Oakland. 1491 82nd Ave was listed for rent for $2,400/month on Mar 4, 2020.
# https://www.trulia.com/for_rent/Oakland,CA/1p_beds/SINGLE-FAMILY_HOME_type/2_p
# $3,950/mo
# $5,500/mo
# $5,800/mo
# $2,850/mo
# $3,850/mo
# $2,650/mo
# $3,600/mo
# $3,400/mo
# $7,200/mo
# $6,450/mo
# $3,950/mo
# $4,045/mo
# $5,000/mo
# $2,995/mo
# $4,500/mo
# $4,200/mo
# $6,450/mo
# $3,000/mo
# $2,950/mo
# $9,000/mo
# $5,200/mo
# $3,195/mo
# $2,200/mo
# $3,650/mo
# $2,450/mo
# $3,600/mo
# $3,200/mo
# $2,700/mo
# $3,450/mo
# $2,200/mo
# Glenview, Oakland, CA
# Santa Fe, Emeryville, CA
# Merriwood, Oakland, CA
# Allendale, Oakland, CA
# Longfellow, Oakland, CA
# Hacienda, Oakland, CA
# Golden Gate, Oakland, CA
# Castlemont, Oakland, CA
# Upper Rockridge, Oakland, CA
# Bushrod, Oakland, CA
# Allendale, Oakland, CA
# Foothill Square, Oakland, CA
# Oakland Avenue/Harrison Street, Oakland, CA
# Oakmore, Oakland, CA
# Longfellow, Oakland, CA
# Upper Rockridge, Oakland, CA
# Temescal, Oakland, CA
# Upper Peralta Creek, Oakland, CA
# Havenscourt, Oakland, CA
# Merriwood, Oakland, CA
# Glen Highlands, Oakland, CA
# Fitchburg, Oakland, CA
# Highland Terrace, Oakland, CA
# Oak Center, Oakland, CA
# Paradise Park, Oakland, CA
# Montclair, Oakland, CA
# Golden Gate, Oakland, CA
# Eastmont, Oakland, CA
# Hoover/Foster, Oakland, CA
# Allendale, Oakland, CA
# 3533 Glen Park Rd
# 5570 Lowell St
# 1840 Gouldin Rd
# 3333 Vale Ave
# 687 45th St
# 2311 Humboldt Ave #2
# 1143 66th St
# 9444 Peach St
# 5046 Cochrane Ave
# 514 North St
# 4089 Allendale Ave
# 2572 Truman Ave
# 235 30th St
# 3836 Forest Hill Ave
# 961 44th St
# 215 Hermosa Ave
# 514
# 3212 School St
# 2645 62nd Ave
# 49 Bay Forest Dr
# 6288 Ruthland Rd
# 1231 80th Ave
# Address Not Disclosed
# 1323 Adeline St
# Address Not Disclosed
# 5995 Balboa Dr
# 5879 Marshall St
# 2731 79th Ave
# 702 30th St
# Address Not Disclosed
# 2bd
# 2bd
# 4bd
# 2bd
# 2bd
# 2bd
# 2bd
# 3bd
# 3bd
# 6bd
# 4bd
# 5bd
# 4bd
# 2bd
# 3bd
# 2bd
# 6bd
# 3bd
# 2bd
# 3bd
# 4bd
# 4bd
# 2bd
# 3bd
# 2bd
# 3bd
# 3bd
# 3bd
# 4bd
# 2bd
# 1ba
# 2.5ba
# 2ba
# 1ba
# 2ba
# 2ba
# 2ba
# 1ba
# 3ba
# 2.5ba
# 2.5ba
# 2ba
# 3ba
# 1ba
# 2.5ba
# 1ba
# 2.5ba
# 1ba
# 1ba
# 3.5ba
# 2.5ba
# 2ba
# 1ba
# 2ba
# 1ba
# 1ba
# 1ba
# 1ba
# 1.5ba
# 1ba
# 1,247 sqft
# 2,000 sqft
# 2,002 sqft
# 906 sqft
# 1,108 sqft
# 950 sqft
# 1,528 sqft
# 2,412 sqft
# 1,794 sqft
# 1,688 sqft
# 975 sqft
# 1,800 sqft
# 1,350 sqft
# 1,750 sqft
# 984 sqft
# 711 sqft
# 3,300 sqft
# 2,710 sqft
# 550 sqft
# 1,300 sqft
# 750 sqft
# 1,400 sqft
# 1,045 sqft
# 1,141 sqft
# 1,501 sqft
# 800 sqft
# CrimeLowest crime relative to the rest of Alameda county.
# $142,200
# Commute81% of residents commute by car.
# 3533 Glen Park Rd, Oakland, CA is a 2 bedroom, 1 bathroom, 1,247 sqft single-family home built in 1930. 3533 Glen Park Rd is located in Glenview, Oakland. 3533 Glen Park Rd was listed for rent for $3,950/month on Mar 3, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $198,000
# Commute67% of residents commute by car.
# 5570 Lowell St, Emeryville, CA is a 2 bedroom, 2.5 bathroom, 2,000 sqft single-family home built in 2017. 5570 Lowell St is located in Santa Fe, Emeryville. 5570 Lowell St was listed for rent for $5,500/month on Mar 11, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $208,800
# Commute79% of residents commute by car.
# 1840 Gouldin Rd, Oakland, CA is a 4 bedroom, 2 bathroom, 2,002 sqft single-family home built in 1967. 1840 Gouldin Rd is located in Merriwood, Oakland. 1840 Gouldin Rd was listed for rent for $5,800/month on Mar 9, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $102,600
# Commute85% of residents commute by car.
# 3333 Vale Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 906 sqft single-family home built in 1915. 3333 Vale Ave is located in Allendale, Oakland. 3333 Vale Ave was listed for rent for $2,850/month on Mar 5, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $138,600
# Commute58% of residents commute by car.
# 687 45th St, Oakland, CA is a 2 bedroom, 2 bathroom, 1,108 sqft single-family home built in 1920. 687 45th St is located in Longfellow, Oakland. 687 45th St was listed for rent for $3,850/month on Mar 13, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $95,400
# Commute74% of residents commute by car.
# 2311 Humboldt Ave #2, Oakland, CA is a 2 bedroom, 2 bathroom, 950 sqft single-family home built in 1912. 2311 Humboldt Ave #2 is located in Hacienda, Oakland. 2311 Humboldt Ave #2 was listed for rent for $2,650/month on Mar 5, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $129,600
# Commute67% of residents commute by car.
# 1143 66th St, Oakland, CA is a 2 bedroom, 2 bathroom, 1,528 sqft single-family home built in 2006. 1143 66th St is located in Golden Gate, Oakland. 1143 66th St was listed for rent for $3,600/month on Mar 5, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $122,400
# Commute81% of residents commute by car.
# 9444 Peach St, Oakland, CA is a 3 bedroom, 1 bathroom single-family home. 9444 Peach St is located in Castlemont, Oakland. 9444 Peach St was listed for rent for $3,400/month on Mar 8, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $259,200
# Commute64% of residents commute by car.
# 5046 Cochrane Ave, Oakland, CA is a 3 bedroom, 3 bathroom, 2,412 sqft single-family home built in 1993. 5046 Cochrane Ave is located in Upper Rockridge, Oakland. 5046 Cochrane Ave was listed for rent for $7,200/month on Mar 12, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $232,200
# Commute58% of residents commute by car.
# 514 North St, Oakland, CA is a 6 bedroom, 2.5 bathroom, 1,794 sqft single-family home built in 1991. 514 North St is located in Bushrod, Oakland. 514 North St was listed for rent for $6,450/month on Mar 10, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $142,200
# Commute85% of residents commute by car.
# 4089 Allendale Ave, Oakland, CA is a 4 bedroom, 2.5 bathroom, 1,688 sqft single-family home built in 2015. 4089 Allendale Ave is located in Allendale, Oakland. 4089 Allendale Ave was listed for rent for $3,950/month on Mar 9, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $145,620
# Commute85% of residents commute by car.
# 2572 Truman Ave, Oakland, CA is a 5 bedroom, 2 bathroom, 1,654 sqft single-family home built in 1953. 2572 Truman Ave is located in Foothill Square, Oakland. 2572 Truman Ave was listed for rent for $4,045/month on Mar 3, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $180,000
# Commute79% of residents commute by car.
# 235 30th St, Oakland, CA is a 4 bedroom, 3 bathroom, 1,725 sqft single-family home built in 1900. 235 30th St is located in Oakland Avenue/Harrison Street, Oakland. 235 30th St was listed for rent for $5,000/month on Mar 4, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $107,820
# Commute81% of residents commute by car.
# 3836 Forest Hill Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 975 sqft single-family home built in 1949. 3836 Forest Hill Ave is located in Oakmore, Oakland. 3836 Forest Hill Ave was listed for rent for $2,995/month on Mar 4, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $162,000
# Commute67% of residents commute by car.
# 961 44th St, Oakland, CA is a 3 bedroom, 2.5 bathroom, 1,800 sqft single-family home built in 1910. 961 44th St is located in Longfellow, Oakland. 961 44th St was listed for rent for $4,500/month on Mar 8, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $151,200
# Commute64% of residents commute by car.
# 215 Hermosa Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 1,350 sqft single-family home built in 1936. 215 Hermosa Ave is located in Upper Rockridge, Oakland. 215 Hermosa Ave was listed for rent for $4,200/month on Mar 13, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of the area.
# $232,200
# Commute58% of residents commute by car.
# 514, Oakland, CA is a 6 bedroom, 2.5 bathroom, 1,750 sqft single-family home built in 1990. 514 is located in Temescal, Oakland. 514 was listed for rent for $6,450/month on Mar 11, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $108,000
# Commute81% of residents commute by car.
# 3212 School St, Oakland, CA is a 3 bedroom, 1 bathroom, 984 sqft single-family home built in 1921. 3212 School St is located in Upper Peralta Creek, Oakland. 3212 School St was listed for rent for $3,000/month on Mar 9, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $106,200
# Commute85% of residents commute by car.
# 2645 62nd Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 711 sqft single-family home built in 1924. 2645 62nd Ave is located in Havenscourt, Oakland. 2645 62nd Ave was listed for rent for $2,950/month on Mar 9, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $324,000
# Commute79% of residents commute by car.
# 49 Bay Forest Dr, Oakland, CA is a 3 bedroom, 3.5 bathroom, 3,300 sqft single-family home built in 1994. 49 Bay Forest Dr is located in Merriwood, Oakland. 49 Bay Forest Dr was listed for rent for $9,000/month on Mar 4, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $187,200
# Commute79% of residents commute by car.
# 6288 Ruthland Rd, Oakland, CA is a 4 bedroom, 2.5 bathroom, 2,710 sqft single-family home built in 2004. 6288 Ruthland Rd is located in Glen Highlands, Oakland. 6288 Ruthland Rd was listed for rent for $5,200/month on Sep 20, 2019.
# CrimeHigh crime relative to the rest of Alameda county.
# $115,020
# Commute80% of residents commute by car.
# 1231 80th Ave, Oakland, CA is a 4 bedroom, 2 bathroom, 660 sqft single-family home built in 1907. 1231 80th Ave is located in Fitchburg, Oakland. 1231 80th Ave was listed for rent for $3,195/month on Feb 3, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $79,200
# Commute70% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 550 sqft single-family home built in 1915. This home is located in Highland Terrace, Oakland. This property was listed for rent for $2,200/month on Feb 15, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $131,400
# Commute60% of residents commute by car.
# 1323 Adeline St, Oakland, CA is a 3 bedroom, 2 bathroom, 1,300 sqft single-family home built in 1907. 1323 Adeline St is located in Oak Center, Oakland. 1323 Adeline St was listed for rent for $3,650/month on Feb 24, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $88,200
# Commute67% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 750 sqft single-family home. This home is located in Paradise Park, Oakland. This property was listed for rent for $2,450/month on Feb 18, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $129,600
# Commute79% of residents commute by car.
# 5995 Balboa Dr, Oakland, CA is a 3 bedroom, 1 bathroom, 1,400 sqft single-family home built in 1958. 5995 Balboa Dr is located in Montclair, Oakland. 5995 Balboa Dr was listed for rent for $3,600/month on Feb 11, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $115,200
# Commute67% of residents commute by car.
# 5879 Marshall St, Oakland, CA is a 3 bedroom, 1 bathroom, 1,045 sqft single-family home built in 1918. 5879 Marshall St is located in Golden Gate, Oakland. 5879 Marshall St was listed for rent for $3,200/month on Feb 29, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $97,200
# Commute85% of residents commute by car.
# 2731 79th Ave, Oakland, CA is a 3 bedroom, 1 bathroom, 1,141 sqft single-family home built in 1925. 2731 79th Ave is located in Eastmont, Oakland. 2731 79th Ave was listed for rent for $2,700/month on Feb 9, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $124,200
# Commute58% of residents commute by car.
# 702 30th St, Oakland, CA is a 4 bedroom, 1.5 bathroom, 1,501 sqft single-family home built in 1908. 702 30th St is located in Hoover/Foster, Oakland. 702 30th St was listed for rent for $3,450/month on Feb 18, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $79,200
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 800 sqft single-family home. This home is located in Allendale, Oakland. This property was listed for rent for $2,200/month on Feb 8, 2020.
# https://www.trulia.com/for_rent/Oakland,CA/1p_beds/SINGLE-FAMILY_HOME_type/3_p
# $4,350/mo
# $3,150/mo
# $3,550/mo
# $3,095/mo
# $2,800/mo
# $3,350/mo
# $10,000/mo
# $2,000/mo
# $2,800/mo
# $3,600/mo
# $8,500/mo
# $3,200/mo
# $2,200/mo
# $2,950/mo
# $2,500/mo
# $3,200/mo
# $1,675/mo
# $3,500/mo
# $4,500/mo
# $4,975/mo
# $3,000/mo
# $2,295/mo
# $2,000/mo
# $2,700/mo
# $2,350/mo
# $3,200/mo
# $4,000/mo
# $5,600/mo
# $2,550/mo
# $1,950/mo
# Forestland, Oakland, CA
# Hoover/Foster, Oakland, CA
# Paradise Park, Oakland, CA
# Woodminster, Oakland, CA
# Jefferson, Oakland, CA
# Dimond, Oakland, CA
# Piedmont, CA
# Eastmont Hills, Oakland, CA
# Las Palmas, Oakland, CA
# Ralph Bunche, Oakland, CA
# Montclair, Piedmont, CA
# Highland Park, Oakland, CA
# Eastmont, Oakland, CA
# Fairview Park, Oakland, CA
# Oak Knoll/Golf Links, Oakland, CA
# Fairview Park, Oakland, CA
# Glenview, Oakland, CA
# Hacienda, Oakland, CA
# Prescott, Oakland, CA
# Bushrod, Oakland, CA
# Shafter, Oakland, CA
# Allendale, Oakland, CA
# Fairfax, Oakland, CA
# Webster, Oakland, CA
# Havenscourt, Oakland, CA
# Longfellow, Oakland, CA
# Reservoir Hill, Oakland, CA
# Montclair, Oakland, CA
# Sequoyah, Oakland, CA
# Bartlett, Oakland, CA
# 11 Chico Ct
# 680 23rd St
# Address Not Disclosed
# 3162 Burdeck Dr
# Address Not Disclosed
# 2946 Georgia St
# 515 Hampton Rd
# Address Not Disclosed
# 2375 Durant Ave
# 1827 Chestnut St
# 21 Tyson Cir
# 1346 E 26th St
# 2724 Ritchie St
# Address Not Disclosed
# Address Not Disclosed
# 5666 Telegraph Ave
# Address Not Disclosed
# 3447 Davis St
# 1339 Pullman Way
# 554 62nd St
# 5447 Lawton Ave
# 3946 Angelo Ave
# 2434 Fern St
# 1425 86th Ave
# 6434 Bancroft Ave
# 4115 Lusk St
# 2818 23rd Ave
# Address Not Disclosed
# Address Not Disclosed
# Address Not Disclosed
# 3bd
# 4bd
# 3bd
# 3bd
# 2bd
# 4bd
# 5bd
# 1bd
# 2bd
# 3bd
# 6bd
# 2bd
# 2bd
# 1bd
# 2bd
# 2bd
# 1bd
# 4bd
# 3bd
# 4bd
# 2bd
# 2bd
# 2bd
# 3bd
# 2bd
# 2bd
# 4bd
# 3bd
# 1bd
# 1bd
# 3ba
# 1ba
# 1ba
# 1ba
# 1ba
# 1ba
# 4.5ba
# 1ba
# 1ba
# 1.5ba
# 3ba
# 2ba
# 1ba
# 1ba
# 1ba
# 1ba
# 1ba
# 2ba
# 3.5ba
# 3.5ba
# 1ba
# 1ba
# 1ba
# 1ba
# 1ba
# 1ba
# 2ba
# 2ba
# 1ba
# 1ba
# 2,300 sqft
# 1,624 sqft
# 1,200 sqft
# 1,200 sqft
# 936 sqft
# 1,433 sqft
# 4,200 sqft
# 800 sqft
# 1,000 sqft
# 1,250 sqft
# 3,372 sqft
# 836 sqft
# 1,094 sqft
# 500 sqft
# 936 sqft
# 800 sqft
# 1,000 sqft
# 1,720 sqft
# 1,800 sqft
# 1,127 sqft
# 860 sqft
# 1,318 sqft
# 950 sqft
# 1,557 sqft
# 1,650 sqft
# 1,000 sqft
# CrimeLowest crime relative to the rest of Alameda county.
# $156,600
# Commute79% of residents commute by car.
# 11 Chico Ct, Oakland, CA is a 3 bedroom, 3 bathroom, 2,300 sqft single-family home built in 1964. 11 Chico Ct is located in Forestland, Oakland. 11 Chico Ct was listed for rent for $4,350/month on Jan 9, 2020.
# CrimeHighest crime relative to the rest of Alameda county.
# $113,400
# Commute42% of residents commute by car.
# 680 23rd St, Oakland, CA is a 4 bedroom, 1 bathroom, 1,624 sqft single-family home built in 1907. 680 23rd St is located in Hoover/Foster, Oakland. 680 23rd St was listed for rent for $3,150/month on Mar 2, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $127,800
# Commute67% of residents commute by car.
# This home in Oakland, CA is a 3 bedroom, 1 bathroom, 1,200 sqft single-family home built in 1911. This home is located in Paradise Park, Oakland. This property was listed for rent for $3,550/month on Feb 28, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $111,420
# Commute81% of residents commute by car.
# 3162 Burdeck Dr, Oakland, CA is a 3 bedroom, 1 bathroom, 1,200 sqft single-family home built in 1958. 3162 Burdeck Dr is located in Woodminster, Oakland. 3162 Burdeck Dr was listed for rent for $3,095/month on Feb 19, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $100,800
# Commute74% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 936 sqft single-family home built in 1921. This home is located in Jefferson, Oakland. This property was listed for rent for $2,800/month on Feb 20, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $120,600
# Commute81% of residents commute by car.
# 2946 Georgia St, Oakland, CA is a 4 bedroom, 1 bathroom, 1,433 sqft single-family home built in 1926. 2946 Georgia St is located in Dimond, Oakland. 2946 Georgia St was listed for rent for $3,350/month on Dec 14, 2019. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $360,000
# Commute79% of residents commute by car.
# 515 Hampton Rd, Piedmont, CA is a 5 bedroom, 4.5 bathroom, 4,200 sqft single-family home built in 1937. 515 Hampton Rd was listed for rent for $10,000/month on Feb 7, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $72,000
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 1 bedroom, 1 bathroom, 800 sqft single-family home built in 1959. This home is located in Eastmont Hills, Oakland. This property was listed for rent for $2,000/month on Sep 25, 2019.
# CrimeLow crime relative to the rest of Alameda county.
# $100,800
# Commute81% of residents commute by car.
# 2375 Durant Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 1,000 sqft single-family home built in 1927. 2375 Durant Ave is located in Las Palmas, Oakland. 2375 Durant Ave was listed for rent for $2,800/month on Feb 25, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $129,600
# Commute60% of residents commute by car.
# 1827 Chestnut St, Oakland, CA is a 3 bedroom, 1.5 bathroom, 1,250 sqft single-family home built in 1919. 1827 Chestnut St is located in Ralph Bunche, Oakland. 1827 Chestnut St was listed for rent for $3,600/month on Feb 26, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $306,000
# Commute79% of residents commute by car.
# 21 Tyson Cir, Piedmont, CA is a 6 bedroom, 3 bathroom, 3,372 sqft single-family home built in 1953. 21 Tyson Cir is located in Montclair, Piedmont. 21 Tyson Cir was listed for rent for $8,500/month on Jan 4, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $115,200
# Commute70% of residents commute by car.
# 1346 E 26th St, Oakland, CA is a 2 bedroom, 2 bathroom, 836 sqft single-family home built in 1920. 1346 E 26th St is located in Highland Park, Oakland. 1346 E 26th St was listed for rent for $3,200/month on Mar 2, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $79,200
# Commute85% of residents commute by car.
# 2724 Ritchie St, Oakland, CA is a 2 bedroom, 1 bathroom, 1,094 sqft single-family home built in 1925. 2724 Ritchie St is located in Eastmont, Oakland. 2724 Ritchie St was listed for rent for $2,200/month on Jan 21, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $106,200
# Commute58% of residents commute by car.
# This home in Oakland, CA is a 1 bedroom, 1 bathroom, 500 sqft single-family home. This home is located in Fairview Park, Oakland. This property was listed for rent for $2,950/month on Jan 8, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $90,000
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 936 sqft single-family home. This home is located in Oak Knoll/Golf Links, Oakland. This property was listed for rent for $2,500/month on Jan 31, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $115,200
# Commute58% of residents commute by car.
# 5666 Telegraph Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 800 sqft single-family home built in 1928. 5666 Telegraph Ave is located in Fairview Park, Oakland. 5666 Telegraph Ave was listed for rent for $3,200/month on Jan 3, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $60,300
# Commute81% of residents commute by car.
# This home in Oakland, CA is a 1 bedroom, 1 bathroom, 1,269 sqft single-family home built in 1930. This home is located in Glenview, Oakland. This property was listed for rent for $1,675/month on Feb 5, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $126,000
# Commute74% of residents commute by car.
# 3447 Davis St, Oakland, CA is a 4 bedroom, 2 bathroom, 1,000 sqft single-family home built in 1908. 3447 Davis St is located in Hacienda, Oakland. 3447 Davis St was listed for rent for $3,500/month on Jan 9, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $162,000
# Commute60% of residents commute by car.
# 1339 Pullman Way, Oakland, CA is a 3 bedroom, 3.5 bathroom, 1,720 sqft single-family home. 1339 Pullman Way is located in Prescott, Oakland. 1339 Pullman Way was listed for rent for $4,500/month on Feb 18, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $179,100
# Commute58% of residents commute by car.
# 554 62nd St, Oakland, CA is a 4 bedroom, 3.5 bathroom, 1,800 sqft single-family home built in 1914. 554 62nd St is located in Bushrod, Oakland. 554 62nd St was listed for rent for $4,975/month on Jan 16, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $108,000
# Commute64% of residents commute by car.
# 5447 Lawton Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 1,127 sqft single-family home built in 1912. 5447 Lawton Ave is located in Shafter, Oakland. 5447 Lawton Ave was listed for rent for $3,000/month on Feb 22, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $82,620
# Commute85% of residents commute by car.
# 3946 Angelo Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 860 sqft single-family home built in 1928. 3946 Angelo Ave is located in Allendale, Oakland. 3946 Angelo Ave was listed for rent for $2,295/month on Feb 25, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $72,000
# Commute74% of residents commute by car.
# 2434 Fern St, Oakland, CA is a 2 bedroom, 1 bathroom, 4,477 sqft single-family home built in 1962. 2434 Fern St is located in Fairfax, Oakland. 2434 Fern St was listed for rent for $2,000/month on Feb 7, 2020.
# CrimeHighest crime relative to the rest of Alameda county.
# $97,200
# Commute80% of residents commute by car.
# 1425 86th Ave, Oakland, CA is a 3 bedroom, 1 bathroom, 1,318 sqft single-family home built in 1920. 1425 86th Ave is located in Webster, Oakland. 1425 86th Ave was listed for rent for $2,700/month on Feb 2, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $84,600
# Commute85% of residents commute by car.
# 6434 Bancroft Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 950 sqft single-family home. 6434 Bancroft Ave is located in Havenscourt, Oakland. 6434 Bancroft Ave was listed for rent for $2,350/month on Feb 9, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $115,200
# Commute67% of residents commute by car.
# 4115 Lusk St, Oakland, CA is a 2 bedroom, 1 bathroom single-family home. 4115 Lusk St is located in Longfellow, Oakland. 4115 Lusk St was listed for rent for $3,200/month on Jan 3, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $144,000
# Commute70% of residents commute by car.
# 2818 23rd Ave, Oakland, CA is a 4 bedroom, 2 bathroom, 1,557 sqft single-family home built in 1938. 2818 23rd Ave is located in Reservoir Hill, Oakland. 2818 23rd Ave was listed for rent for $4,000/month on Feb 20, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $201,600
# Commute79% of residents commute by car.
# This home in Oakland, CA is a 3 bedroom, 2 bathroom, 1,650 sqft single-family home. This home is located in Montclair, Oakland. This property was listed for rent for $5,600/month on Nov 18, 2019.
# CrimeLowest crime relative to the rest of Alameda county.
# $91,800
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 1 bedroom, 1 bathroom, 1,000 sqft single-family home built in 1965. This home is located in Sequoyah, Oakland. This property was listed for rent for $2,550/month on May 6, 2019.
# CrimeLowest crime relative to the rest of Alameda county.
# $70,200
# Commute81% of residents commute by car.
# This home in Oakland, CA is a 1 bedroom, 1 bathroom single-family home. This home is located in Bartlett, Oakland. This property was listed for rent for $1,950/month on Feb 4, 2020. This property is pet friendly.
# https://www.trulia.com/for_rent/Oakland,CA/1p_beds/SINGLE-FAMILY_HOME_type/4_p
# $2,600/mo
# $4,450/mo
# $2,250/mo
# $2,300/mo
# $1,600/mo
# $2,050/mo
# $2,300/mo
# $3,495/mo
# $5,400/mo
# $4,500/mo
# $3,200/mo
# $3,000/mo
# $3,900/mo
# $3,000/mo
# $4,900/mo
# $3,900/mo
# $4,250/mo
# $3,000/mo
# $2,200/mo
# $2,450/mo
# $2,950/mo
# $2,950/mo
# $3,495/mo
# $4,575/mo
# $2,825/mo
# $3,300/mo
# $2,975/mo
# $3,300/mo
# $2,600/mo
# $2,500/mo
# Havenscourt, Oakland, CA
# Redwood Heights, Oakland, CA
# Fitchburg, Oakland, CA
# Clinton, Oakland, CA
# Eastmont, Oakland, CA
# Clinton, Oakland, CA
# Cleveland Heights, Oakland, CA
# Santa Fe, Oakland, CA
# Merriwood, Oakland, CA
# Golden Gate, Oakland, CA
# Seminary, Oakland, CA
# Arroyo Viejo, Oakland, CA
# Upper Rockridge, Oakland, CA
# Meadow Brook, Oakland, CA
# Merriwood, Oakland, CA
# Hoover/Foster, Oakland, CA
# Fairview Park, Oakland, CA
# Eastmont Hills, Oakland, CA
# Upper Laurel, Oakland, CA
# Frick, Oakland, CA
# Maxwell Park, Oakland, CA
# Upper Laurel, Oakland, CA
# East Peralta, Oakland, CA
# East Peralta, Oakland, CA
# Sobrante Park, Oakland, CA
# Coliseum, Oakland, CA
# Mosswood, Oakland, CA
# Emeryville, CA
# Longfellow, Oakland, CA
# North Stonehurst, Oakland, CA
# Address Not Disclosed
# 3401 Guido St
# 1018 76th Ave
# 1648 10th Ave
# 2347 82nd Ave
# Address Not Disclosed
# 351 Hanover Ave
# 840 Aileen St
# 11031 Broadway Ter
# 1161 Stanford Ave
# 5915 Hilton St
# 2031 81st Ave
# Address Not Disclosed
# 2469 26th Ave
# 1766 Woodhaven Way
# 2523 Martin Luther King Jr Way
# 443 McAuley St
# 8124 Greenly Dr
# 3681 35th Ave
# 2632 60th Ave
# Address Not Disclosed
# 4438 Steele St
# 1432 5th Ave
# 1429 7th Ave
# 10653 Topanga Dr
# 7201 Hamilton St
# 460 W Macarthur Blvd
# 1519 Brunswig Ln
# 4117 Lusk St
# 10509 E St
# 2bd
# 4bd
# 1bd
# 1bd
# 1bd
# 1bd
# 1bd
# 2bd
# 3bd
# 3bd
# 3bd
# 4bd
# 3bd
# 3bd
# 3bd
# 4bd
# 3bd
# 3bd
# 2bd
# 2bd
# 2bd
# 2bd
# 3bd
# 5bd
# 2bd
# 3bd
# 2bd
# 2bd
# 1bd
# 2bd
# 1ba
# 2ba
# 1ba
# 1ba
# 1ba
# 1ba
# 1ba
# 1ba
# 3ba
# 2ba
# 2ba
# 2ba
# 1ba
# 2ba
# 2ba
# 2.5ba
# 1ba
# 2ba
# 1.5ba
# 1ba
# 1ba
# 1ba
# 1.5ba
# 2ba
# 1ba
# 2ba
# 1.5ba
# 1.5ba
# 1ba
# 1ba
# 993 sqft
# 1,900 sqft
# 425 sqft
# 650 sqft
# 1,000 sqft
# 500 sqft
# 1,193 sqft
# 3,130 sqft
# 1,054 sqft
# 966 sqft
# 1,363 sqft
# 1,106 sqft
# 996 sqft
# 1,428 sqft
# 1,774 sqft
# 1,800 sqft
# 847 sqft
# 930 sqft
# 972 sqft
# 951 sqft
# 1,300 sqft
# 1,800 sqft
# 950 sqft
# 1,250 sqft
# 1,340 sqft
# 800 sqft
# 1,000 sqft
# CrimeLow crime relative to the rest of Alameda county.
# $93,600
# Commute80% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 993 sqft single-family home built in 1926. This home is located in Havenscourt, Oakland. This property was listed for rent for $2,600/month on Feb 18, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $160,200
# Commute81% of residents commute by car.
# 3401 Guido St, Oakland, CA is a 4 bedroom, 2 bathroom, 1,900 sqft single-family home built in 1935. 3401 Guido St is located in Redwood Heights, Oakland. 3401 Guido St was listed for rent for $4,450/month on Jan 9, 2020. This property is pet friendly.
# CrimeModerate crime relative to the rest of Alameda county.
# $81,000
# Commute80% of residents commute by car.
# 1018 76th Ave, Oakland, CA is a 1 bedroom, 1 bathroom, 425 sqft single-family home built in 1926. 1018 76th Ave is located in Fitchburg, Oakland. 1018 76th Ave was listed for rent for $2,250/month on Nov 14, 2019. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $82,800
# Commute70% of residents commute by car.
# 1648 10th Ave, Oakland, CA is a 1 bedroom, 1 bathroom, 650 sqft single-family home. 1648 10th Ave is located in Clinton, Oakland. 1648 10th Ave was listed for rent for $2,300/month on Jan 3, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $57,600
# Commute85% of residents commute by car.
# 2347 82nd Ave, Oakland, CA is a 1 bedroom, 1 bathroom, 1,000 sqft single-family home. 2347 82nd Ave is located in Eastmont, Oakland. 2347 82nd Ave was listed for rent for $1,600/month on Jan 30, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $73,800
# Commute70% of residents commute by car.
# This home in Oakland, CA is a 1 bedroom, 1 bathroom, 500 sqft single-family home built in 1885. This home is located in Clinton, Oakland. This property was listed for rent for $2,050/month on Apr 22, 2019.
# CrimeLow crime relative to the rest of Alameda county.
# $82,800
# Commute70% of residents commute by car.
# 351 Hanover Ave, Oakland, CA is a 1 bedroom, 1 bathroom, 12,624 sqft single-family home built in 1960. 351 Hanover Ave is located in Cleveland Heights, Oakland. 351 Hanover Ave was listed for rent for $2,300/month on Feb 27, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $125,820
# Commute67% of residents commute by car.
# 840 Aileen St, Oakland, CA is a 2 bedroom, 1 bathroom, 1,193 sqft single-family home built in 1908. 840 Aileen St is located in Santa Fe, Oakland. 840 Aileen St was listed for rent for $3,495/month on Mar 2, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $194,400
# Commute79% of residents commute by car.
# 11031 Broadway Ter, Oakland, CA is a 3 bedroom, 3 bathroom, 3,130 sqft single-family home built in 1968. 11031 Broadway Ter is located in Merriwood, Oakland. 11031 Broadway Ter was listed for rent for $5,400/month on Nov 6, 2019.
# CrimeLowest crime relative to the rest of Alameda county.
# $162,000
# Commute67% of residents commute by car.
# 1161 Stanford Ave, Oakland, CA is a 3 bedroom, 2 bathroom, 1,054 sqft single-family home built in 1905. 1161 Stanford Ave is located in Golden Gate, Oakland. 1161 Stanford Ave was listed for rent for $4,500/month on Feb 27, 2020. This property is pet friendly.
# CrimeLow crime relative to the rest of Alameda county.
# $115,200
# Commute85% of residents commute by car.
# 5915 Hilton St, Oakland, CA is a 3 bedroom, 2 bathroom, 966 sqft single-family home built in 1924. 5915 Hilton St is located in Seminary, Oakland. 5915 Hilton St was listed for rent for $3,200/month on Feb 22, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $108,000
# Commute80% of residents commute by car.
# 2031 81st Ave, Oakland, CA is a 4 bedroom, 2 bathroom, 1,363 sqft single-family home built in 1926. 2031 81st Ave is located in Arroyo Viejo, Oakland. 2031 81st Ave was listed for rent for $3,000/month on Feb 18, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $140,400
# Commute64% of residents commute by car.
# This home in Oakland, CA is a 3 bedroom, 1 bathroom, 1,106 sqft single-family home built in 1941. This home is located in Upper Rockridge, Oakland. This property was listed for rent for $3,900/month on Feb 27, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $108,000
# Commute74% of residents commute by car.
# 2469 26th Ave, Oakland, CA is a 3 bedroom, 2 bathroom, 996 sqft single-family home built in 1912. 2469 26th Ave is located in Meadow Brook, Oakland. 2469 26th Ave was listed for rent for $3,000/month on Feb 12, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $176,400
# Commute79% of residents commute by car.
# 1766 Woodhaven Way, Oakland, CA is a 3 bedroom, 2 bathroom, 1,428 sqft single-family home built in 1939. 1766 Woodhaven Way is located in Merriwood, Oakland. 1766 Woodhaven Way was listed for rent for $4,900/month on Mar 2, 2020. This property is pet friendly.
# CrimeHighest crime relative to the rest of Alameda county.
# $140,400
# Commute42% of residents commute by car.
# 2523 Martin Luther King Jr Way, Oakland, CA is a 4 bedroom, 2.5 bathroom, 1,774 sqft single-family home built in 1897. 2523 Martin Luther King Jr Way is located in Hoover/Foster, Oakland. 2523 Martin Luther King Jr Way was listed for rent for $3,900/month on Nov 4, 2019. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $153,000
# Commute58% of residents commute by car.
# 443 McAuley St, Oakland, CA is a 3 bedroom, 1 bathroom, 2,357 sqft single-family home built in 1935. 443 McAuley St is located in Fairview Park, Oakland. 443 McAuley St was listed for rent for $4,250/month on Jan 30, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $108,000
# Commute85% of residents commute by car.
# 8124 Greenly Dr, Oakland, CA is a 3 bedroom, 2 bathroom, 1,800 sqft single-family home built in 1948. 8124 Greenly Dr is located in Eastmont Hills, Oakland. 8124 Greenly Dr was listed for rent for $3,000/month on Feb 25, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $79,200
# Commute85% of residents commute by car.
# 3681 35th Ave, Oakland, CA is a 2 bedroom, 1.5 bathroom, 847 sqft single-family home built in 1989. 3681 35th Ave is located in Upper Laurel, Oakland. 3681 35th Ave was listed for rent for $2,200/month on Feb 17, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $88,200
# Commute85% of residents commute by car.
# 2632 60th Ave, Oakland, CA is a 2 bedroom, 1 bathroom, 930 sqft single-family home built in 1967. 2632 60th Ave is located in Frick, Oakland. 2632 60th Ave was listed for rent for $2,450/month on Feb 23, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $106,200
# Commute85% of residents commute by car.
# This home in Oakland, CA is a 2 bedroom, 1 bathroom, 972 sqft single-family home built in 1918. This home is located in Maxwell Park, Oakland. This property was listed for rent for $2,950/month on Mar 1, 2020. This property is pet friendly.
# CrimeLowest crime relative to the rest of Alameda county.
# $106,200
# Commute85% of residents commute by car.
# 4438 Steele St, Oakland, CA is a 2 bedroom, 1 bathroom, 951 sqft single-family home built in 1937. 4438 Steele St is located in Upper Laurel, Oakland. 4438 Steele St was listed for rent for $2,950/month on Mar 2, 2020.
# CrimeHighest crime relative to the rest of Alameda county.
# $125,820
# Commute70% of residents commute by car.
# 1432 5th Ave, Oakland, CA is a 3 bedroom, 1.5 bathroom, 1,300 sqft single-family home. 1432 5th Ave is located in East Peralta, Oakland. 1432 5th Ave was listed for rent for $3,495/month on Jan 3, 2020. This property is pet friendly.
# CrimeHighest crime relative to the rest of Alameda county.
# $164,700
# Commute70% of residents commute by car.
# 1429 7th Ave, Oakland, CA is a 5 bedroom, 2 bathroom, 1,800 sqft single-family home built in 1910. 1429 7th Ave is located in East Peralta, Oakland. 1429 7th Ave was listed for rent for $4,575/month on Dec 28, 2019.
# CrimeLow crime relative to the rest of Alameda county.
# $101,700
# Commute81% of residents commute by car.
# 10653 Topanga Dr, Oakland, CA is a 2 bedroom, 1 bathroom, 950 sqft single-family home built in 1945. 10653 Topanga Dr is located in Sobrante Park, Oakland. 10653 Topanga Dr was listed for rent for $2,825/month on Feb 28, 2020. This property is pet friendly.
# CrimeHigh crime relative to the rest of Alameda county.
# $118,800
# Commute80% of residents commute by car.
# 7201 Hamilton St, Oakland, CA is a 3 bedroom, 2 bathroom, 1,250 sqft single-family home built in 1927. 7201 Hamilton St is located in Coliseum, Oakland. 7201 Hamilton St was listed for rent for $3,300/month on Feb 17, 2020.
# CrimeModerate crime relative to the rest of Alameda county.
# $107,100
# Commute58% of residents commute by car.
# 460 W Macarthur Blvd, Oakland, CA is a 2 bedroom, 1.5 bathroom single-family home built in 1916. 460 W Macarthur Blvd is located in Mosswood, Oakland. 460 W Macarthur Blvd was listed for rent for $2,975/month on Jan 5, 2020.
# CrimeLowest crime relative to the rest of Alameda county.
# $118,800
# Commute67% of residents commute by car.
# 1519 Brunswig Ln, Emeryville, CA is a 2 bedroom, 1.5 bathroom, 1,340 sqft single-family home. 1519 Brunswig Ln was listed for rent for $3,300/month on Mar 2, 2020.
# CrimeLow crime relative to the rest of Alameda county.
# $93,600
# Commute67% of residents commute by car.
# ...
# 8    3bd    1ba    950 sqft
# 9    4bd  2.5ba    912 sqft
# 10   2bd    1ba  1,412 sqft
# 11   2bd    1ba    750 sqft
# 12   3bd  2.5ba  1,250 sqft
# 13   2bd    1ba  1,500 sqft
# 14   2bd    1ba  1,050 sqft
# 15   3bd    2ba  1,600 sqft
# 16   2bd    2ba  1,550 sqft
# 17   2bd    2ba    839 sqft
# 18   3bd  1.5ba    700 sqft
# 19   3bd    2ba  1,292 sqft
# 20   2bd    1ba    900 sqft
# 21   2bd    1ba  1,200 sqft
# 22   1bd    1ba    608 sqft
# 23   1bd    1ba  1,285 sqft
# 24   3bd    2ba  1,247 sqft
# 25   2bd    1ba  2,000 sqft
# 26   2bd    1ba  2,002 sqft
# 27   1bd    1ba    906 sqft
# 28   3bd  1.5ba  1,108 sqft
# 29   2bd    1ba    950 sqft
# ..   ...    ...         ...
# 782  4bd  2.5ba  1,040 sqft
# 783  3bd    1ba  1,195 sqft
# 784  3bd    2ba  1,486 sqft
# 785  3bd    2ba  1,178 sqft
# 786  3bd    2ba  1,586 sqft
# 787  4bd    2ba  1,269 sqft
# 788  3bd    2ba  1,036 sqft
# 789  2bd    2ba  1,924 sqft
# 790  4bd  2.5ba  1,135 sqft
# 791  3bd    2ba  1,665 sqft
# 792  3bd  2.5ba  2,128 sqft
# 793  4bd    2ba  1,612 sqft
# 794  3bd    3ba  2,109 sqft
# 795  4bd    3ba  2,820 sqft
# 796  5bd    3ba  1,000 sqft
# 797  2bd    2ba    925 sqft
# 798  2bd    2ba  1,905 sqft
# 799  4bd  3.5ba  1,100 sqft
# 800  3bd    1ba  1,800 sqft
# 801  4bd    2ba  1,747 sqft
# 802  4bd    2ba  1,415 sqft
# 803  3bd    2ba  1,514 sqft
# 804  3bd  2.5ba  1,200 sqft
# 805  3bd    2ba  1,526 sqft
# 806  3bd  2.5ba  1,274 sqft
# 807  3bd  2.5ba  1,150 sqft
# 808  2bd  1.5ba  1,080 sqft
# 809  3bd    2ba  1,676 sqft
# 810  4bd  2.5ba  1,962 sqft
# 811  4bd    3ba  2,012 sqft
#
#                                            Description  \
# 0    321 Castro St, Oakland, CA is a 3 bedroom, 1 b...
# 1    1687 8th St, Oakland, CA is a 1 bedroom, 1 bat...
# 2    This home in Oakland, CA is a 2 bedroom, 1 bat...
# 3    2243 12th Ave, Oakland, CA is a 2 bedroom, 1 b...
# 4    1064 30th St, Oakland, CA is a 3 bedroom, 2 ba...
# 5    692 31st St, Oakland, CA is a 2 bedroom, 1 bat...
# 6    2215 E 29th St, Oakland, CA is a 3 bedroom, 1 ...
# 7    2185 Trafalgar Pl, Oakland, CA is a 3 bedroom,...
# 8    843 60th St, Oakland, CA is a 3 bedroom, 1 bat...
# 9    32nd St, Oakland, CA is a 4 bedroom, 2.5 bathr...
# 10   This home in Oakland, CA is a 2 bedroom, 1 bat...
# 11   This home in Oakland, CA is a 2 bedroom, 1 bat...
# 12   This home in Oakland, CA is a 3 bedroom, 2.5 b...
# 13   421 Avon St #B, Oakland, CA is a 2 bedroom, 1 ...
# 14   7028 Homewood Dr, Oakland, CA is a 2 bedroom, ...
# 15   2834 Atwell Ave, Oakland, CA is a 3 bedroom, 2...
# 16   6000 Holway St, Oakland, CA is a 2 bedroom, 2 ...
# 17   This home in Oakland, CA is a 2 bedroom, 2 bat...
# 18   1921 73rd Ave, Oakland, CA is a 3 bedroom, 1.5...
# 19   This home in Oakland, CA is a 3 bedroom, 2 bat...
# 20   2598 61st Ave, Oakland, CA is a 2 bedroom, 1 b...
# 21   1700 83rd Ave, Oakland, CA is a 2 bedroom, 1 b...
# 22   2834 Seminary Ave, Oakland, CA is a 1 bedroom,...
# 23   This home in Oakland, CA is a 1 bedroom, 1 bat...
# 24   2027 High St, Oakland, CA is a 3 bedroom, 2 ba...
# 25   9411 E St, Oakland, CA is a 2 bedroom, 1 bathr...
# 26   6441 Mokelumne Ave, Oakland, CA is a 2 bedroom...
# 27   3531 Rhoda Ave, Oakland, CA is a 1 bedroom, 1 ...
# 28   This home in Oakland, CA is a 3 bedroom, 1.5 b...
# 29   1491 82nd Ave, Oakland, CA is a 2 bedroom, 1 b...
# ..                                                 ...
# 782  2784 Curry St, Pleasanton, CA is a 4 bedroom, ...
# 783  3922 California Way, Livermore, CA is a 3 bedr...
# 784  1525 Portola Ave, Livermore, CA is a 3 bedroom...
# 785  6407 Half Dome Ct, Livermore, CA is a 3 bedroo...
# 786  92 Tamalpais Ave, Livermore, CA is a 3 bedroom...
# 787  5809 Idlewild Ave, Livermore, CA is a 4 bedroo...
# 788  815 Crane Ave, Livermore, CA is a 3 bedroom, 2...
# 789  1011 Marigold Rd, Livermore, CA is a 2 bedroom...
# 790  5393 Hillflower Dr, Livermore, CA is a 4 bedro...
# 791  437 Anna Maria St, Livermore, CA is a 3 bedroo...
# 792  26 Sandstone Cmn, Livermore, CA is a 3 bedroom...
# 793  1068 Geneva St, Livermore, CA is a 4 bedroom, ...
# 794  This home in Livermore, CA is a 3 bedroom, 3 b...
# 795  5652 Nina Way, Livermore, CA is a 4 bedroom, 3...
# 796  2927 Bresso Dr, Livermore, CA is a 5 bedroom, ...
# 797  903 S G St, Livermore, CA is a 2 bedroom, 2 ba...
# 798  2480 Palm Ave, Livermore, CA is a 2 bedroom, 2...
# 799  2829 Patcham Cmn, Livermore, CA is a 4 bedroom...
# 800  426 N O St, Livermore, CA is a 3 bedroom, 1 ba...
# 801  This home in Livermore, CA is a 4 bedroom, 2 b...
# 802  4395 Pomona Way, Livermore, CA is a 4 bedroom,...
# 803  1141 Meadow Dr, Livermore, CA is a 3 bedroom, ...
# 804  63 Meritage Cmn #101, Livermore, CA is a 3 bed...
# 805  725 N O St, Livermore, CA is a 3 bedroom, 2 ba...
# 806  2164 Beech Cmn, Livermore, CA is a 3 bedroom, ...
# 807  1180 Spring Valley Cmn, Livermore, CA is a 3 b...
# 808  610 N K St, Livermore, CA is a 2 bedroom, 1.5 ...
# 809  669 Mayten Dr, Livermore, CA is a 3 bedroom, 2...
# 810  3196 Bridle Ct, Livermore, CA is a 4 bedroom, ...
# 811  1113 Heather Ln, Livermore, CA is a 4 bedroom,...
#
#                                      Commute  \
# 0    Commute60% of residents commute by car.
# 1    Commute60% of residents commute by car.
# 2    Commute85% of residents commute by car.
# 3    Commute70% of residents commute by car.
# 4    Commute67% of residents commute by car.
# 5    Commute58% of residents commute by car.
# 6    Commute70% of residents commute by car.
# 7    Commute79% of residents commute by car.
# 8    Commute67% of residents commute by car.
# 9    Commute58% of residents commute by car.
# 10   Commute85% of residents commute by car.
# 11   Commute74% of residents commute by car.
# 12   Commute67% of residents commute by car.
# 13   Commute64% of residents commute by car.
# 14   Commute79% of residents commute by car.
# 15   Commute74% of residents commute by car.
# 16   Commute80% of residents commute by car.
# 17   Commute79% of residents commute by car.
# 18   Commute80% of residents commute by car.
# 19   Commute85% of residents commute by car.
# 20   Commute85% of residents commute by car.
# 21   Commute80% of residents commute by car.
# 22   Commute85% of residents commute by car.
# 23   Commute75% of residents commute by car.
# 24   Commute74% of residents commute by car.
# 25   Commute81% of residents commute by car.
# 26   Commute85% of residents commute by car.
# 27   Commute81% of residents commute by car.
# 28   Commute70% of residents commute by car.
# 29   Commute80% of residents commute by car.
# ..                                       ...
# 782  Commute90% of residents commute by car.
# 783  Commute94% of residents commute by car.
# 784  Commute96% of residents commute by car.
# 785  Commute96% of residents commute by car.
# 786  Commute96% of residents commute by car.
# 787  Commute96% of residents commute by car.
# 788  Commute96% of residents commute by car.
# 789  Commute96% of residents commute by car.
# 790  Commute96% of residents commute by car.
# 791  Commute94% of residents commute by car.
# 792  Commute94% of residents commute by car.
# 793  Commute94% of residents commute by car.
# 794  Commute96% of residents commute by car.
# 795  Commute94% of residents commute by car.
# 796  Commute94% of residents commute by car.
# 797  Commute94% of residents commute by car.
# 798  Commute94% of residents commute by car.
# 799  Commute94% of residents commute by car.
# 800  Commute96% of residents commute by car.
# 801  Commute96% of residents commute by car.
# 802  Commute94% of residents commute by car.
# 803  Commute96% of residents commute by car.
# 804  Commute96% of residents commute by car.
# 805  Commute96% of residents commute by car.
# 806  Commute96% of residents commute by car.
# 807  Commute96% of residents commute by car.
# 808  Commute96% of residents commute by car.
# 809  Commute96% of residents commute by car.
# 810  Commute96% of residents commute by car.
# 811  Commute96% of residents commute by car.
#
#                                                  Crime    Income  \
# 0    CrimeLow crime relative to the rest of Alameda...   $86,400
# 1    CrimeHigh crime relative to the rest of Alamed...   $61,200
# 2    CrimeLowest crime relative to the rest of Alam...   $64,800
# 3    CrimeModerate crime relative to the rest of Al...   $86,400
# 4    CrimeHigh crime relative to the rest of Alamed...  $115,164
# 5    CrimeHigh crime relative to the rest of Alamed...  $106,200
# 6    CrimeLow crime relative to the rest of Alameda...  $106,200
# 7    CrimeLowest crime relative to the rest of Alam...  $143,100
# 8    CrimeLow crime relative to the rest of Alameda...  $115,200
# 9    CrimeModerate crime relative to the rest of Al...  $129,600
# 10   CrimeLowest crime relative to the rest of Alam...   $79,200
# 11   CrimeModerate crime relative to the rest of Al...  $100,764
# 12   CrimeLow crime relative to the rest of Alameda...  $122,400
# 13   CrimeLowest crime relative to the rest of Alam...  $102,600
# 14   CrimeLowest crime relative to the rest of Alam...  $136,800
# 15   CrimeHigh crime relative to the rest of Alamed...  $108,000
# 16   CrimeModerate crime relative to the rest of Al...  $106,200
# 17   CrimeLowest crime relative to the rest of Alam...  $153,000
# 18   CrimeHighest crime relative to the rest of Ala...  $108,000
# 19   CrimeLowest crime relative to the rest of Alam...  $140,400
# 20   CrimeLow crime relative to the rest of Alameda...   $96,840
# 21   CrimeHigh crime relative to the rest of Alamed...   $91,800
# 22   CrimeLow crime relative to the rest of Alameda...   $59,400
# 23   CrimeLow crime relative to the rest of Alameda...   $95,400
# 24   CrimeModerate crime relative to the rest of Al...  $108,000
# 25   CrimeModerate crime relative to the rest of Al...   $86,400
# 26   CrimeLow crime relative to the rest of Alameda...  $126,000
# 27   CrimeLowest crime relative to the rest of Alam...   $79,200
# 28   CrimeLowest crime relative to the rest of Alam...  $176,400
# 29   CrimeHigh crime relative to the rest of Alamed...   $86,400
# ..                                                 ...       ...
# 782  CrimeLowest crime relative to the rest of Alam...  $125,640
# 783  CrimeLowest crime relative to the rest of Alam...  $100,800
# 784  CrimeLowest crime relative to the rest of Alam...   $90,000
# 785  CrimeLowest crime relative to the rest of Alam...  $111,600
# 786  CrimeLowest crime relative to the rest of Alam...  $107,100
# 787  CrimeLowest crime relative to the rest of Alam...  $122,400
# 788  CrimeLowest crime relative to the rest of Alam...   $99,000
# 789  CrimeLowest crime relative to the rest of Alam...   $93,600
# 790  CrimeLowest crime relative to the rest of Alam...  $122,328
# 791  CrimeLowest crime relative to the rest of Alam...  $118,080
# 792  CrimeLowest crime relative to the rest of Alam...  $115,020
# 793  CrimeLowest crime relative to the rest of Alam...  $136,800
# 794  CrimeLowest crime relative to the rest of Alam...  $122,400
# 795  CrimeLowest crime relative to the rest of Alam...  $135,000
# 796  CrimeLowest crime relative to the rest of Alam...  $171,000
# 797  CrimeLowest crime relative to the rest of Alam...  $106,200
# 798  CrimeLowest crime relative to the rest of Alam...  $107,100
# 799  CrimeLowest crime relative to the rest of Alam...  $122,400
# 800  CrimeLowest crime relative to the rest of Alam...   $93,600
# 801  CrimeLowest crime relative to the rest of Alam...  $117,900
# 802  CrimeLowest crime relative to the rest of Alam...  $110,700
# 803  CrimeLowest crime relative to the rest of Alam...  $111,600
# 804  CrimeLowest crime relative to the rest of Alam...  $104,220
# 805  CrimeLowest crime relative to the rest of Alam...  $111,600
# 806  CrimeLowest crime relative to the rest of Alam...  $106,200
# 807  CrimeLowest crime relative to the rest of Alam...   $95,400
# 808  CrimeLowest crime relative to the rest of Alam...   $88,200
# 809  CrimeLowest crime relative to the rest of Alam...  $108,000
# 810  CrimeLowest crime relative to the rest of Alam...  $126,000
# 811  CrimeLowest crime relative to the rest of Alam...  $118,620
#
#                                                    URL
# 0    https://www.trulia.com/p/ca/oakland/321-castro...
# 1    https://www.trulia.com/p/ca/oakland/1687-8th-s...
# 2    https://www.trulia.com/p/ca/oakland/address-no...
# 3    https://www.trulia.com/p/ca/oakland/2243-12th-...
# 4    https://www.trulia.com/p/ca/oakland/1064-30th-...
# 5    https://www.trulia.com/p/ca/oakland/692-31st-s...
# 6    https://www.trulia.com/p/ca/oakland/2215-e-29t...
# 7    https://www.trulia.com/p/ca/oakland/2185-trafa...
# 8    https://www.trulia.com/p/ca/oakland/843-60th-s...
# 9    https://www.trulia.com/p/ca/oakland/0-32nd-st-...
# 10   https://www.trulia.com/p/ca/oakland/address-no...
# 11   https://www.trulia.com/p/ca/oakland/address-no...
# 12   https://www.trulia.com/p/ca/oakland/address-no...
# 13   https://www.trulia.com/p/ca/oakland/421-avon-s...
# 14   https://www.trulia.com/p/ca/oakland/7028-homew...
# 15   https://www.trulia.com/p/ca/oakland/2834-atwel...
# 16   https://www.trulia.com/p/ca/oakland/6000-holwa...
# 17   https://www.trulia.com/p/ca/oakland/address-no...
# 18   https://www.trulia.com/p/ca/oakland/1921-73rd-...
# 19   https://www.trulia.com/p/ca/oakland/address-no...
# 20   https://www.trulia.com/p/ca/oakland/2598-61st-...
# 21   https://www.trulia.com/p/ca/oakland/1700-83rd-...
# 22   https://www.trulia.com/p/ca/oakland/2834-semin...
# 23   https://www.trulia.com/p/ca/oakland/address-no...
# 24   https://www.trulia.com/p/ca/oakland/2027-high-...
# 25   https://www.trulia.com/p/ca/oakland/9411-e-st-...
# 26   https://www.trulia.com/p/ca/oakland/6441-mokel...
# 27   https://www.trulia.com/p/ca/oakland/3531-rhoda...
# 28   https://www.trulia.com/p/ca/oakland/address-no...
# 29   https://www.trulia.com/p/ca/oakland/1491-82nd-...
# ..                                                 ...
# 782  https://www.trulia.com/p/ca/pleasanton/2784-cu...
# 783  https://www.trulia.com/p/ca/livermore/3922-cal...
# 784  https://www.trulia.com/p/ca/livermore/1525-por...
# 785  https://www.trulia.com/p/ca/livermore/6407-hal...
# 786  https://www.trulia.com/p/ca/livermore/92-tamal...
# 787  https://www.trulia.com/p/ca/livermore/5809-idl...
# 788  https://www.trulia.com/p/ca/livermore/815-cran...
# 789  https://www.trulia.com/p/ca/livermore/1011-mar...
# 790  https://www.trulia.com/p/ca/livermore/5393-hil...
# 791  https://www.trulia.com/p/ca/livermore/437-anna...
# 792  https://www.trulia.com/p/ca/livermore/26-sands...
# 793  https://www.trulia.com/p/ca/livermore/1068-gen...
# 794  https://www.trulia.com/p/ca/livermore/address-...
# 795  https://www.trulia.com/p/ca/livermore/5652-nin...
# 796  https://www.trulia.com/p/ca/livermore/2927-bre...
# 797  https://www.trulia.com/p/ca/livermore/903-s-g-...
# 798  https://www.trulia.com/p/ca/livermore/2480-pal...
# 799  https://www.trulia.com/p/ca/livermore/2829-pat...
# 800  https://www.trulia.com/p/ca/livermore/426-n-o-...
# 801  https://www.trulia.com/p/ca/livermore/address-...
# 802  https://www.trulia.com/p/ca/livermore/4395-pom...
# 803  https://www.trulia.com/p/ca/livermore/1141-mea...
# 804  https://www.trulia.com/p/ca/livermore/63-merit...
# 805  https://www.trulia.com/p/ca/livermore/725-n-o-...
# 806  https://www.trulia.com/p/ca/livermore/2164-bee...
# 807  https://www.trulia.com/p/ca/livermore/1180-spr...
# 808  https://www.trulia.com/p/ca/livermore/610-n-k-...
# 809  https://www.trulia.com/p/ca/livermore/669-mayt...
# 810  https://www.trulia.com/p/ca/livermore/3196-bri...
# 811  https://www.trulia.com/p/ca/livermore/1113-hea...
#
# [812 rows x 11 columns]

# %%
#Save the obtained dataframe to csv
data_frame.to_csv('./datasets/SFBayArea_Rental.csv')

# %%
df = pd.read_csv('datasets/SFBayArea_Rental.csv') 
df.head(5)
# Out:
#    Unnamed: 0                            Address               Location  \
# 0           0  Produce & Waterfront, Oakland, CA          321 Castro St
# 1           1              Prescott, Oakland, CA            1687 8th St
# 2           2          Upper Laurel, Oakland, CA  Address Not Disclosed
# 3           3               Clinton, Oakland, CA          2243 12th Ave
# 4           4               Clawson, Oakland, CA           1064 30th St
#
#         Rent  Bed Bath        Size  \
# 0  $2,400/mo  3bd  1ba    900 sqft
# 1  $1,700/mo  1bd  1ba    450 sqft
# 2  $1,800/mo  2bd  1ba    700 sqft
# 3  $2,400/mo  2bd  1ba  1,017 sqft
# 4  $3,199/mo  3bd  2ba  1,100 sqft
#
#                                          Description  \
# 0  321 Castro St, Oakland, CA is a 3 bedroom, 1 b...
# 1  1687 8th St, Oakland, CA is a 1 bedroom, 1 bat...
# 2  This home in Oakland, CA is a 2 bedroom, 1 bat...
# 3  2243 12th Ave, Oakland, CA is a 2 bedroom, 1 b...
# 4  1064 30th St, Oakland, CA is a 3 bedroom, 2 ba...
#
#                                    Commute  \
# 0  Commute60% of residents commute by car.
# 1  Commute60% of residents commute by car.
# 2  Commute85% of residents commute by car.
# 3  Commute70% of residents commute by car.
# 4  Commute67% of residents commute by car.
#
#                                                Crime     Income  \
# 0  CrimeLow crime relative to the rest of Alameda...   $86,400
# 1  CrimeHigh crime relative to the rest of Alamed...   $61,200
# 2  CrimeLowest crime relative to the rest of Alam...   $64,800
# 3  CrimeModerate crime relative to the rest of Al...   $86,400
# 4  CrimeHigh crime relative to the rest of Alamed...  $115,164
#
#                                                  URL
# 0  https://www.trulia.com/p/ca/oakland/321-castro...
# 1  https://www.trulia.com/p/ca/oakland/1687-8th-s...
# 2  https://www.trulia.com/p/ca/oakland/address-no...
# 3  https://www.trulia.com/p/ca/oakland/2243-12th-...
# 4  https://www.trulia.com/p/ca/oakland/1064-30th-...

# %%
#Pre-processing of data - Stage 1
df['Rent'] = df['Rent'].map(lambda x: x.lstrip('$').rstrip('/mo?')).str.replace(",","").astype(float)
df['Bed'] = df['Bed'].map(lambda x: x.lstrip('bd').rstrip('bds')).astype(float)
df['Bath'] = df['Bath'].map(lambda x: x.lstrip('ba').rstrip('AaBbCc')).astype(float)
df['Size'] = df['Size'].map(lambda x: x.lstrip('sf').rstrip('sqft')).str.replace(",","").astype(float)
df[' Income'] = df['Income'].map(lambda x: x.lstrip('$').rstrip('AaBbCc')).str.replace(",","").astype(float)
df['Commute']  = df.Commute.str.extract('(\d+)').astype(float)
df['Crime']  = df.Crime.str.extract('^(.*?)(?=[ ])')
df2 = df["Address"].apply(lambda x: x.split(","))
df['City'] = df2.apply(lambda x: " ".join(x[-2].split()[:]))

# %%
#Checking missing values 
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Address        0
# Location       0
# Rent           0
# Bed            0
# Bath           0
# Size           0
# Description    0
# Commute        0
# Crime          0
# Income         0
# URL            0
#  Income        0
# City           0
# dtype: int64

# %%
#Checking for duplicate rows 
duplicateRowsDF = df[df.duplicated()]
print(duplicateRowsDF)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Address, Location, Rent, Bed, Bath, Size, Description, Commute, Crime, Income, URL,  Income, City]
# Index: []

# %%
#checking Outliers 
import seaborn as sns
sns.boxplot(x="Bed", y="Rent",data=df);

# %%
#Preprocessing Data - stage 2
#To remove records that capture few data from border of cities 
df = df.groupby("City").filter(lambda x : len(x)>5)

# %%
import numpy as np
df.rename(columns = {'Unnamed: 0':'Index'}, inplace = True)
df = df.reindex(list(np.arange(1,809,1)))
df.head()
# Out:
#    Index                     Address               Location    Rent  Bed  \
# 1    1.0       Prescott, Oakland, CA            1687 8th St  1700.0  1.0
# 2    2.0   Upper Laurel, Oakland, CA  Address Not Disclosed  1800.0  2.0
# 3    3.0        Clinton, Oakland, CA          2243 12th Ave  2400.0  2.0
# 4    4.0        Clawson, Oakland, CA           1064 30th St  3199.0  3.0
# 5    5.0  Hoover/Foster, Oakland, CA            692 31st St  2950.0  2.0
#
#    Bath    Size                                        Description  Commute  \
# 1   1.0   450.0  1687 8th St, Oakland, CA is a 1 bedroom, 1 bat...     60.0
# 2   1.0   700.0  This home in Oakland, CA is a 2 bedroom, 1 bat...     85.0
# 3   1.0  1017.0  2243 12th Ave, Oakland, CA is a 2 bedroom, 1 b...     70.0
# 4   2.0  1100.0  1064 30th St, Oakland, CA is a 3 bedroom, 2 ba...     67.0
# 5   1.0  1000.0  692 31st St, Oakland, CA is a 2 bedroom, 1 bat...     58.0
#
#            Crime     Income  \
# 1      CrimeHigh   $61,200
# 2    CrimeLowest   $64,800
# 3  CrimeModerate   $86,400
# 4      CrimeHigh  $115,164
# 5      CrimeHigh  $106,200
#
#                                                  URL    Income     City
# 1  https://www.trulia.com/p/ca/oakland/1687-8th-s...   61200.0  Oakland
# 2  https://www.trulia.com/p/ca/oakland/address-no...   64800.0  Oakland
# 3  https://www.trulia.com/p/ca/oakland/2243-12th-...   86400.0  Oakland
# 4  https://www.trulia.com/p/ca/oakland/1064-30th-...  115164.0  Oakland
# 5  https://www.trulia.com/p/ca/oakland/692-31st-s...  106200.0  Oakland

# %%
# Which is the most affordable city for larger family homes ?

large_family=df['Bed'] >=3
df_large_family=df[large_family] # df creation

sns.relplot(x='Bed',y='Rent',hue='City',data=df_large_family)
plt.ylim(df_large_family['Rent'].min(),df_large_family['Rent'].max())
plt.title('Which City is the most affordable for larger families?')
plt.show()

# %%
labels = 'Lowest', 'Low', 'Moderate', 'High','Highest'
A = [752, 104, 35, 17, 8]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'grey','red']
explode = (0.1, 0, 0, 0, 0) 
plt.figure(figsize=(10,8))
plt.pie(A, explode=explode, labels=labels, colors=colors,
        autopct='%.2f%%', pctdistance = 0.6, shadow=True, startangle=180, frame = False)
plt.axis('equal')
plt.legend(title="Crime_Type", loc = 'upper right')
plt.show()

# %%
#Which is the Safest City in Bayarea?
crime_city=pd.crosstab(df.City,df.Crime)
crime_norm=crime_city.div(crime_city.sum(1),axis=0)
crime_norm.plot.barh(stacked = 'True')
plt.legend(title = 'Crime',loc='upper right',bbox_to_anchor=(1.4,1))
plt.show()

# %%
#How Size impact on Rental Price ?
sns.jointplot(x='Size', y= 'Rent',kind='kde', data=df, color ='b',line_kws={"color":"r","alpha":0.9,"lw":5}, stat_func= pearsonr, )
#plt.title('Pearson Correlation: Rental Vs Size ')
plt.show()

# %%
#Does Rental Price increase if an area is more car dependent?
sns.jointplot(x='Commute',y='Rent',kind='kde',stat_func=pearsonr,data=df,color='g')
plt.show()


def func(x):
    if 20 < x <= 40:
        return '20-40'
    elif 40 < x <= 60:
        return '40-60'
    elif 60 < x <=80:
        return '60-80'
    elif 80 < x <=100:
        return '80-100'
    
df['Commute_range'] = df['Commute'].apply(func)
df=df.sort_values('Commute_range')    
plt.figure(figsize = (15,5))
sns.swarmplot(x="Commute_range",y="Rent",hue="City",data=df)
plt.ylim(df['Rent'].min(),df['Rent'].max())
plt.title('Commute Percentage across the cities')
plt.show()
