# %% [markdown]
# # Boolean Selection Multiple Conditions
#
# ## Multiple condition expression
# So far, our boolean selections have involved a single condition. You can have as many conditions as you would like. To do so, you will need to combine your boolean expressions using the three logical operators, and, or, and not.
#
# ### Use `&`, `|` , `~`
# Although Python uses the keywords `and`, `or`, and `not`, these will not work with boolean Series. You must use the following operators instead.
#
# * `&` for and (ampersand character)
# * `|` for or (pipe character)
# * `~` for not (tilde character)
#
# ### Our first multiple condition expression
# Let's find all the rides longer than 1,000 seconds when it was cloudy. This query has two conditions - trip durations greater than 1,000 and cloudy weather. The way we approach the problem is to assign each condition to a separate variable. Since we desire both of the conditions to be true, we must use the and (`&`) operator.

# %%
import pandas as pd
bikes = pd.read_csv('../data/bikes.csv')
bikes.head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St      41.90096
# 1       -87.641170              31.0     Wells St & Walton St      41.89993
# 2       -87.653497              15.0  Dearborn St & Monroe St      41.88132
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 2     -87.629521            23.0         73.0        10.0        16.1
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 2        -9999.0  mostlycloudy

# %% [markdown]
# Each single condition is placed on its own line before using the `&` operator to create the final filter that completes the boolean selection.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['events'] == 'cloudy'
filt = filt1 & filt2
bikes[filt].head(3)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 8     21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 18    40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 80    90932  Subscriber  Female  2013-07-22 07:59:00  2013-07-22 08:19:00
#
#     tripduration             from_station_name  latitude_start  \
# 8           1300  Clinton St & Washington Blvd       41.883380
# 18          5396       Canal St & Jackson Blvd       41.878114
# 80          1224    Lincoln Ave & Armitage Ave       41.918273
#
#     longitude_start  dpcapacity_start         to_station_name  latitude_end  \
# 8        -87.641170              31.0   Wood St & Division St     41.903320
# 18       -87.639971              35.0         Millennium Park     41.881032
# 80       -87.638116              19.0  Dearborn St & Adams St     41.879356
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 8      -87.672730            15.0         71.1         8.0         0.0
# 18     -87.624084            35.0         79.0        10.0        13.8
# 80     -87.629791            19.0         73.4        10.0         0.0
#
#     precipitation  events
# 8         -9999.0  cloudy
# 18            0.0  cloudy
# 80        -9999.0  cloudy

# %% [markdown]
# ## Multiple conditions in one line
# It is possible to combine the entire expression into a single line. Many pandas users like doing this. Regardless, it is a good idea to know how it's done as you will definitely encounter it.
#
# ### Use parentheses to separate conditions
# You must encapsulate each condition in a set of parentheses in order to make this work. Each condition will be separated like this:
#
# ```
# (bikes['tripduration'] > 1000) & (bikes['events'] == 'cloudy')
# ```
#
# ### Same results
# The above expression is placed inside of *just the brackets* to get the same results. Again, I prefer assigning each condition to its own variable for better readability.

# %%
bikes[(bikes['tripduration'] > 1000) & (bikes['events'] == 'cloudy')].head(3)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 8     21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 18    40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 80    90932  Subscriber  Female  2013-07-22 07:59:00  2013-07-22 08:19:00
#
#     tripduration             from_station_name  latitude_start  \
# 8           1300  Clinton St & Washington Blvd       41.883380
# 18          5396       Canal St & Jackson Blvd       41.878114
# 80          1224    Lincoln Ave & Armitage Ave       41.918273
#
#     longitude_start  dpcapacity_start         to_station_name  latitude_end  \
# 8        -87.641170              31.0   Wood St & Division St     41.903320
# 18       -87.639971              35.0         Millennium Park     41.881032
# 80       -87.638116              19.0  Dearborn St & Adams St     41.879356
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 8      -87.672730            15.0         71.1         8.0         0.0
# 18     -87.624084            35.0         79.0        10.0        13.8
# 80     -87.629791            19.0         73.4        10.0         0.0
#
#     precipitation  events
# 8         -9999.0  cloudy
# 18            0.0  cloudy
# 80        -9999.0  cloudy

# %% [markdown]
# ## Using an `or` condition
# Let's find all the rides that were done by females **or** had trip durations longer than 1,000 seconds. In this example, we need at least one of the conditions to be true, which necessitates the use of the or (`|`) operator.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['gender'] == 'Female'
filt = filt1 | filt2
bikes[filt].head(3)
# Out:
#    trip_id    usertype  gender            starttime             stoptime  \
# 2    10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8    21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 9    23558  Subscriber  Female  2013-07-04 15:00:00  2013-07-04 15:16:00
#
#    tripduration              from_station_name  latitude_start  \
# 2          1040   Sheffield Ave & Kingsbury St       41.909592
# 8          1300   Clinton St & Washington Blvd       41.883380
# 9           922  Lakeview Ave & Fullerton Pkwy       41.925858
#
#    longitude_start  dpcapacity_start             to_station_name  \
# 2       -87.653497              15.0     Dearborn St & Monroe St
# 8       -87.641170              31.0       Wood St & Division St
# 9       -87.638973              19.0  Racine Ave & Congress Pkwy
#
#    latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 2      41.88132     -87.629521            23.0         73.0        10.0
# 8      41.90332     -87.672730            15.0         71.1         8.0
# 9      41.87464     -87.657030            19.0         81.0        10.0
#
#    wind_speed  precipitation        events
# 2        16.1        -9999.0  mostlycloudy
# 8         0.0        -9999.0        cloudy
# 9        12.7        -9999.0  mostlycloudy

# %% [markdown]
# ## Inverting a condition with the not operator
# The tilde character, `~`, represents the not operator and inverts a condition. For instance, if we wanted all the rides with trip duration less than or equal to 1000, we could do it like this:

# %%
filt = bikes['tripduration'] > 1000
bikes[~filt].head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 3           667       Carpenter St & Huron St       41.894556
#
#    longitude_start  dpcapacity_start         to_station_name  latitude_end  \
# 0       -87.616970              11.0   Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0    Wells St & Walton St     41.899930
# 3       -87.653449              19.0  Clark St & Randolph St     41.884576
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 3     -87.631890            31.0         72.0        10.0        16.1
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 3        -9999.0  mostlycloudy

# %% [markdown]
# Of course, inverting single conditions is basically pointless as we can use the less than or equal to operator instead.

# %%
filt = bikes['tripduration'] <= 1000
bikes[filt].head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 3           667       Carpenter St & Huron St       41.894556
#
#    longitude_start  dpcapacity_start         to_station_name  latitude_end  \
# 0       -87.616970              11.0   Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0    Wells St & Walton St     41.899930
# 3       -87.653449              19.0  Clark St & Randolph St     41.884576
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 3     -87.631890            31.0         72.0        10.0        16.1
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 3        -9999.0  mostlycloudy

# %% [markdown]
# ### Invert a more complex condition
# Typically, we will save the not operator for reversing more complex conditions. Let's reverse the condition for selecting rides by females or those with duration over 1,000 seconds. Logically, this should return only male riders with duration 1,000 or less.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['gender'] == 'Female'
filt = filt1 | filt2
bikes[~filt].head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 3           667       Carpenter St & Huron St       41.894556
#
#    longitude_start  dpcapacity_start         to_station_name  latitude_end  \
# 0       -87.616970              11.0   Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0    Wells St & Walton St     41.899930
# 3       -87.653449              19.0  Clark St & Randolph St     41.884576
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 3     -87.631890            31.0         72.0        10.0        16.1
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 3        -9999.0  mostlycloudy

# %% [markdown]
# ### Even more complex conditions
# It is possible to build extremely complex conditions to select rows of your DataFrame that meet a very specific query. For instance, we can select males riders with trip duration between 1,000 and 2,000 seconds along with female riders with trip duration between 5,000 and 10,000 seconds. With multiple conditions, it's probably best to break out the logic into multiple steps:

# %%
filt1 = ((bikes['gender'] == 'Male') &
         (bikes['tripduration'] >= 1000) &
         (bikes['tripduration'] <= 2000))

filt2 = ((bikes['gender'] == 'Female') &
         (bikes['tripduration'] >= 5000) &
         (bikes['tripduration'] <= 10000))
filt = filt1 | filt2
bikes[filt].head(10)
# Out:
#     trip_id    usertype  gender            starttime             stoptime  \
# 2     10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8     21028  Subscriber    Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10    24383  Subscriber    Male  2013-07-04 17:17:00  2013-07-04 17:42:00
# 11    24673  Subscriber    Male  2013-07-04 18:13:00  2013-07-04 18:42:00
# 13    30404  Subscriber    Male  2013-07-06 09:43:00  2013-07-06 10:06:00
# 26    51130  Subscriber    Male  2013-07-12 01:07:00  2013-07-12 01:24:00
# 34    54257  Subscriber    Male  2013-07-12 18:13:00  2013-07-12 18:40:00
# 40    61401  Subscriber  Female  2013-07-14 14:08:00  2013-07-14 15:53:00
# 41    64257  Subscriber    Male  2013-07-15 06:26:00  2013-07-15 06:44:00
# 47    67013  Subscriber    Male  2013-07-15 19:10:00  2013-07-15 19:34:00
#
#     tripduration             from_station_name  latitude_start  \
# 2           1040  Sheffield Ave & Kingsbury St       41.909592
# 8           1300  Clinton St & Washington Blvd       41.883380
# 10          1523           Morgan St & 18th St       41.858086
# 11          1697    Ashland Ave & Armitage Ave       41.917859
# 13          1365          May St & Randolph St       41.883970
# 26          1043        State St & Harrison St       41.873958
# 34          1616       Clinton St & Madison St       41.881582
# 40          6274     Wabash Ave & Roosevelt Rd       41.867173
# 41          1125    Racine Ave & Fullerton Ave       41.925563
# 47          1463       Lake Shore Dr & Ohio St       41.892570
#
#     longitude_start  dpcapacity_start             to_station_name  \
# 2        -87.653497              15.0     Dearborn St & Monroe St
# 8        -87.641170              31.0       Wood St & Division St
# 10       -87.651073              15.0      Damen Ave & Pierce Ave
# 11       -87.668919              15.0  Lincoln Ave & Armitage Ave
# 13       -87.655688              15.0             Millennium Park
# 26       -87.627739              19.0        Racine Ave & 18th St
# 34       -87.641277              23.0      Damen Ave & Pierce Ave
# 40       -87.625955              19.0   Lake Shore Dr & Monroe St
# 41       -87.658404              19.0        State St & Kinzie St
# 47       -87.614492              19.0     Lake Shore Dr & Ohio St
#
#     latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 2      41.881320     -87.629521            23.0         73.0        10.0
# 8      41.903320     -87.672730            15.0         71.1         8.0
# 10     41.909396     -87.677692            19.0         79.0        10.0
# 11     41.918273     -87.638116            19.0         79.0        10.0
# 13     41.881032     -87.624084            35.0         78.1        10.0
# 26     41.858181     -87.656487            15.0         64.9        10.0
# 34     41.909396     -87.677692            19.0         78.1        10.0
# 40     41.881050     -87.616970            11.0         87.1        10.0
# 41     41.889180     -87.627700            15.0         73.9        10.0
# 47     41.892570     -87.614492            19.0         80.1        10.0
#
#     wind_speed  precipitation        events
# 2         16.1        -9999.0  mostlycloudy
# 8          0.0        -9999.0        cloudy
# 10         9.2        -9999.0  mostlycloudy
# 11        10.4        -9999.0  mostlycloudy
# 13         5.8        -9999.0  partlycloudy
# 26         0.0        -9999.0         clear
# 34        10.4        -9999.0  partlycloudy
# 40         8.1        -9999.0  partlycloudy
# 41         0.0        -9999.0  partlycloudy
# 47         6.9        -9999.0  mostlycloudy

# %% [markdown]
# ## Lots of equality conditions in a single column - use `isin`
# Occasionally, we will want to test equality in a single column with multiple values. This is most common in string columns. For instance, let's say we wanted to find all the rides where the events were either rain, snow, tstorms or sleet. One way to do this would be with four or conditions.

# %%
filt = ((bikes['events'] == 'rain') | 
        (bikes['events'] == 'snow') | 
        (bikes['events'] == 'tstorms') | 
        (bikes['events'] == 'sleet'))

bikes[filt].head(3)
# Out:
#     trip_id    usertype gender            starttime             stoptime  \
# 45    66336  Subscriber   Male  2013-07-15 16:43:00  2013-07-15 16:55:00
# 78    89180  Subscriber   Male  2013-07-21 16:35:00  2013-07-21 17:06:00
# 79    89228  Subscriber   Male  2013-07-21 16:47:00  2013-07-21 17:03:00
#
#     tripduration          from_station_name  latitude_start  longitude_start  \
# 45           727    Greenwood Ave & 47th St       41.809835       -87.599383
# 78          1809  Michigan Ave & Pearson St       41.897660       -87.623510
# 79           999    Carpenter St & Huron St       41.894556       -87.653449
#
#     dpcapacity_start          to_station_name  latitude_end  longitude_end  \
# 45              15.0   State St & Harrison St     41.873958     -87.627739
# 78              23.0          Millennium Park     41.881032     -87.624084
# 79              19.0  Carpenter St & Huron St     41.894556     -87.653449
#
#     dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 45            19.0         82.9        10.0         5.8            0.0
# 78            35.0         82.4        10.0        11.5            0.0
# 79            19.0         82.4        10.0        11.5            0.0
#
#      events
# 45     rain
# 78  tstorms
# 79  tstorms

# %% [markdown]
# Instead of using an operator, we will use the `isin` method. Pass it a list (or a set) of all the values you want to test equality with. The `isin` method will return a boolean Series and in this example, the same exact boolean Series as the previous one.

# %%
filt = bikes['events'].isin(['rain', 'snow', 'tstorms', 'sleet'])
bikes[filt].head(3)
# Out:
#     trip_id    usertype gender            starttime             stoptime  \
# 45    66336  Subscriber   Male  2013-07-15 16:43:00  2013-07-15 16:55:00
# 78    89180  Subscriber   Male  2013-07-21 16:35:00  2013-07-21 17:06:00
# 79    89228  Subscriber   Male  2013-07-21 16:47:00  2013-07-21 17:03:00
#
#     tripduration          from_station_name  latitude_start  longitude_start  \
# 45           727    Greenwood Ave & 47th St       41.809835       -87.599383
# 78          1809  Michigan Ave & Pearson St       41.897660       -87.623510
# 79           999    Carpenter St & Huron St       41.894556       -87.653449
#
#     dpcapacity_start          to_station_name  latitude_end  longitude_end  \
# 45              15.0   State St & Harrison St     41.873958     -87.627739
# 78              23.0          Millennium Park     41.881032     -87.624084
# 79              19.0  Carpenter St & Huron St     41.894556     -87.653449
#
#     dpcapacity_end  temperature  visibility  wind_speed  precipitation  \
# 45            19.0         82.9        10.0         5.8            0.0
# 78            35.0         82.4        10.0        11.5            0.0
# 79            19.0         82.4        10.0        11.5            0.0
#
#      events
# 45     rain
# 78  tstorms
# 79  tstorms

# %% [markdown]
# ### Combining `isin` with other filters
# You can use the resulting boolean Series from the `isin` method in the same way as you would from the logical operators. For instance, If we wanted to find all the rides that had the same events as above and had a duration greater than 2,000 we would do the following:

# %%
filt1 = bikes['events'].isin(['rain', 'snow', 'tstorms', 'sleet'])
filt2 = bikes['tripduration'] > 2000
filt = filt1 & filt2
bikes[filt].head(3)
# Out:
#       trip_id    usertype  gender            starttime             stoptime  \
# 2344  1266453  Subscriber  Female  2014-03-19 07:23:00  2014-03-19 08:00:00
# 7697  3557596  Subscriber    Male  2014-09-12 14:20:00  2014-09-12 14:57:00
# 8357  3801419  Subscriber    Male  2014-09-30 08:21:00  2014-09-30 08:58:00
#
#       tripduration        from_station_name  latitude_start  longitude_start  \
# 2344          2181   Seeley Ave & Roscoe St       41.943403       -87.679618
# 7697          2213   Damen Ave & Pierce Ave       41.909396       -87.677692
# 8357          2246  Damen Ave & Melrose Ave       41.940600       -87.678500
#
#       dpcapacity_start               to_station_name  latitude_end  \
# 2344              11.0         Franklin St & Lake St     41.885837
# 7697              19.0  California Ave & Division St     41.903029
# 8357              11.0           Wood St & Taylor St     41.869154
#
#       longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 2344     -87.635500            23.0         43.0         3.0         6.9
# 7697     -87.697474            15.0         52.0         2.0        12.7
# 8357     -87.671045            15.0         46.9         3.0        11.5
#
#       precipitation events
# 2344           0.07   rain
# 7697           0.00   rain
# 8357           0.00   rain

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# <span  style="color:green; font-size:16px">Select all movies from the 1970s.</span>

# %%
movie = pd.read_csv('../data/movie.csv', index_col='title')
filt1 = movie['year'] >= 1970
filt2 = movie['year'] <= 1979
filt = filt1 & filt2
movie[filt].head(3)
# Out:
#                  year            color content_rating  duration  \
# title
# All That Jazz  1979.0            Color              R     123.0
# Superman       1978.0            Color             PG     188.0
# Solaris        1972.0  Black and White             PG     115.0
#
#                   director_name  director_fb            actor1  actor1_fb  \
# title
# All That Jazz         Bob Fosse        189.0      Roy Scheider      813.0
# Superman         Richard Donner        503.0     Marlon Brando    10000.0
# Solaris        Andrei Tarkovsky          0.0  Donatas Banionis       29.0
#
#                             actor2  actor2_fb  ... actor3_fb        gross  \
# title                                          ...
# All That Jazz           Ben Vereen      388.0  ...      87.0          NaN
# Superman             Margot Kidder      593.0  ...     467.0  134218018.0
# Solaris        Anatoliy Solonitsyn       29.0  ...      12.0          NaN
#
#                                               genres num_reviews  \
# title
# All That Jazz             Comedy|Drama|Music|Musical        84.0
# Superman       Action|Adventure|Drama|Romance|Sci-Fi       169.0
# Solaris                         Drama|Mystery|Sci-Fi       144.0
#
#                num_voted_users  \
# title
# All That Jazz            19228
# Superman                126357
# Solaris                  54057
#
#                                                    plot_keywords language  \
# title
# All That Jazz  dancer|editing|stand up comedian|surgery|vomiting  English
# Superman             1970s|clark kent|planet|superhero|year 1978  English
# Solaris        hallucination|ocean|psychologist|scientist|spa...  Russian
#
#                     country      budget  imdb_score
# title
# All That Jazz           USA         NaN         7.8
# Superman                USA  55000000.0         7.3
# Solaris        Soviet Union   1000000.0         8.1
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Select all movies from the 1970s that had IMDB scores greater than 8.</span>

# %%
filt1 = movie['year'] >= 1970
filt2 = movie['year'] <= 1979 
filt3 = movie['imdb_score'] > 8

filt = filt1 & filt2 & filt3
movie[filt].head(3)
# Out:
#                    year            color content_rating  duration  \
# title
# Solaris          1972.0  Black and White             PG     115.0
# Apocalypse Now   1979.0            Color              R     289.0
# The Deer Hunter  1978.0            Color              R     183.0
#
#                         director_name  director_fb            actor1  \
# title
# Solaris              Andrei Tarkovsky          0.0  Donatas Banionis
# Apocalypse Now   Francis Ford Coppola          0.0     Harrison Ford
# The Deer Hunter        Michael Cimino        517.0    Robert De Niro
#
#                  actor1_fb               actor2  actor2_fb  ... actor3_fb  \
# title                                                       ...
# Solaris               29.0  Anatoliy Solonitsyn       29.0  ...      12.0
# Apocalypse Now     11000.0        Marlon Brando    10000.0  ...    3000.0
# The Deer Hunter    22000.0         Meryl Streep    11000.0  ...     652.0
#
#                       gross                genres num_reviews  \
# title
# Solaris                 NaN  Drama|Mystery|Sci-Fi       144.0
# Apocalypse Now   78800000.0             Drama|War       261.0
# The Deer Hunter         NaN             Drama|War       140.0
#
#                  num_voted_users  \
# title
# Solaris                    54057
# Apocalypse Now            450676
# The Deer Hunter           232577
#
#                                                      plot_keywords language  \
# title
# Solaris          hallucination|ocean|psychologist|scientist|spa...  Russian
# Apocalypse Now            army|green beret|insanity|jungle|vietnam  English
# The Deer Hunter    escape|friend|party|pittsburgh steelers|vietnam  English
#
#                       country      budget  imdb_score
# title
# Solaris          Soviet Union   1000000.0         8.1
# Apocalypse Now            USA  31500000.0         8.5
# The Deer Hunter            UK  15000000.0         8.2
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">Select movies that were rated either R, PG-13, or PG.</span>

# %%
filt = movie['content_rating'].isin(['R', 'PG-13', 'PG'])
movie[filt].head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Avatar                                        936.0  ...     855.0
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Exercise 4
# <span  style="color:green; font-size:16px">Select movies that are either rated PG-13 or were made after 2010.</span>

# %%
filt1 = movie['content_rating'] == 'PG-13'
filt2 = movie['year'] > 2010
filt = filt1 | filt2

movie[filt].head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Avatar                                        936.0  ...     855.0
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Exercise 5
# <span  style="color:green; font-size:16px">Find all the movies that have at least one of the three actors with more than 10,000 Facebook likes.</span>

# %%
filt1 = movie['actor1_fb'] > 10000
filt2 = movie['actor2_fb'] > 10000
filt3 = movie['actor3_fb'] > 10000
filt = filt1 | filt2 | filt3

movie[filt].head(3)
# Out:
#                                             year  color content_rating  \
# title
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
#
#                                           duration      director_name  \
# title
# Pirates of the Caribbean: At World's End     169.0     Gore Verbinski
# Spectre                                      148.0         Sam Mendes
# The Dark Knight Rises                        164.0  Christopher Nolan
#
#                                           director_fb           actor1  \
# title
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
# The Dark Knight Rises                         22000.0        Tom Hardy
#
#                                           actor1_fb          actor2  \
# title
# Pirates of the Caribbean: At World's End    40000.0   Orlando Bloom
# Spectre                                     11000.0    Rory Kinnear
# The Dark Knight Rises                       27000.0  Christian Bale
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
# The Dark Knight Rises                       23000.0  ...   23000.0
#
#                                                 gross  \
# title
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
# The Dark Knight Rises                     448130642.0
#
#                                                              genres  \
# title
# Pirates of the Caribbean: At World's End   Action|Adventure|Fantasy
# Spectre                                   Action|Adventure|Thriller
# The Dark Knight Rises                               Action|Thriller
#
#                                          num_reviews  num_voted_users  \
# title
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
# The Dark Knight Rises                          813.0          1144337
#
#                                                                               plot_keywords  \
# title
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                     deception|imprisonment|lawlessness|police offi...
#
#                                          language country       budget  \
# title
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
# The Dark Knight Rises                     English     USA  250000000.0
#
#                                           imdb_score
# title
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
# The Dark Knight Rises                            8.5
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Exercise 6
# <span  style="color:green; font-size:16px">Reverse the condition from problem 4. In words, what have you selected?</span>

# %%
filt1 = movie['content_rating'] == 'PG-13'
filt2 = movie['year'] > 2010
filt = filt1 | filt2

movie[~filt].head(3)
# Out:
#                                               year  color content_rating  \
# title
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# Tangled                                     2010.0  Color             PG
# Harry Potter and the Half-Blood Prince      2009.0  Color             PG
#
#                                             duration director_name  \
# title
# Star Wars: Episode VII - The Force Awakens       NaN   Doug Walker
# Tangled                                        100.0  Nathan Greno
# Harry Potter and the Half-Blood Prince         153.0   David Yates
#
#                                             director_fb        actor1  \
# title
# Star Wars: Episode VII - The Force Awakens        131.0   Doug Walker
# Tangled                                            15.0  Brad Garrett
# Harry Potter and the Half-Blood Prince            282.0  Alan Rickman
#
#                                             actor1_fb            actor2  \
# title
# Star Wars: Episode VII - The Force Awakens      131.0        Rob Walker
# Tangled                                         799.0      Donna Murphy
# Harry Potter and the Half-Blood Prince        25000.0  Daniel Radcliffe
#
#                                             actor2_fb  ... actor3_fb  \
# title                                                  ...
# Star Wars: Episode VII - The Force Awakens       12.0  ...       NaN
# Tangled                                         553.0  ...     284.0
# Harry Potter and the Half-Blood Prince        11000.0  ...   10000.0
#
#                                                   gross  \
# title
# Star Wars: Episode VII - The Force Awakens          NaN
# Tangled                                     200807262.0
# Harry Potter and the Half-Blood Prince      301956980.0
#
#                                                                                        genres  \
# title
# Star Wars: Episode VII - The Force Awakens                                        Documentary
# Tangled                                     Adventure|Animation|Comedy|Family|Fantasy|Musi...
# Harry Potter and the Half-Blood Prince                       Adventure|Family|Fantasy|Mystery
#
#                                            num_reviews  num_voted_users  \
# title
# Star Wars: Episode VII - The Force Awakens         NaN                8
# Tangled                                          324.0           294810
# Harry Potter and the Half-Blood Prince           375.0           321795
#
#                                                                                 plot_keywords  \
# title
# Star Wars: Episode VII - The Force Awakens                                                NaN
# Tangled                                     17th century|based on fairy tale|disney|flower...
# Harry Potter and the Half-Blood Prince                       blood|book|love|potion|professor
#
#                                            language country       budget  \
# title
# Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
# Tangled                                     English     USA  260000000.0
# Harry Potter and the Half-Blood Prince      English      UK  250000000.0
#
#                                             imdb_score
# title
# Star Wars: Episode VII - The Force Awakens         7.1
# Tangled                                            7.8
# Harry Potter and the Half-Blood Prince             7.5
#
# [3 rows x 21 columns]
