# %%
import pandas as pd 
import numpy as np
import random 
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %matplotlib inline

# %% [markdown]
# ## Random Raffles

# %%
raffle = df[['Submission ID', 'Last Name', 'First Name','Email']]
raffle.shape

# %%
raffle.loc[random.randint(0,len(df))]

# %%
pd.DataFrame(df.loc[86])

# %% [markdown]
# ## Orientation Data Charts

# %%
school = pd.read_excel("Orientation data 2019.xlsx", sheetname = "School", index_col = 0)
degree = pd.read_excel("Orientation data 2019.xlsx", sheetname = "Degree", index_col = 0)
fl_pt = pd.read_excel("Orientation data 2019.xlsx", sheetname = "Enrollment", index_col = 0)
session = pd.read_excel("Orientation data 2019.xlsx", sheetname = "EdSession")
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
def bar_plot(df): 
    ind = np.arange(df.shape[0])    # The x locations for the groups 
    width = 0.35       # the width of the bars: can also be len(x) sequence 
    
    ta = df['total attendance']
    reg = df['Registered']
    att = df['attend']
    site = df['on site reg']
    
    fig, ax = plt.subplots()
    p1 = ax.bar(ind - width/2, att, width, label = "Registered Attendee")
    p2 = ax.bar(ind - width/2, site, width, bottom=att, label = "On-site Registration")
    
    p3 = ax.bar(ind + width/2, reg, width, label = "Registered")
    
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_xticks(ind)
    ax.set_xticklabels(df.index)
    ax.legend()
    fig.tight_layout()

    plt.show()

bar_plot(school)
bar_plot(degree)
bar_plot(fl_pt)

# %%
plt.bar(np.arange(session.shape[0]), session['head count'], width = 0.5)
plt.ylabel("Head Count")
plt.title("Education Session Attendees")

# zip joins x and y coordinates in pairs
for x,y in zip(np.arange(session.shape[0]), session['head count']):

    plt.annotate(y, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

textstr = "\n 0: Life on the Heights, 1: Ed Tools, 2: Life in the City; \n 3: Live the Mission; 4: Return to the Academy; 5: Strive to Thrive; \n 6: How to Succeed in a Doc Program; 7: Financial Services"
plt.text(0.01, 1, textstr, fontsize=14, verticalalignment='top')
# Out:
# Text(0.01, 1, '\n 0: Life on the Heights, 1: Ed Tools, 2: Life in the City; \n 3: Live the Mission; 4: Return to the Academy; 5: Strive to Thrive; \n 6: How to Succeed in a Doc Program; 7: Financial Services')

# %% [markdown]
# # Orientation Survey Result

# %%
df = pd.read_excel("87db55e209364_new_graduate_professional_student_orientation_2019_survey.xlsx", header = 0)
df.shape
# Out:
# (344, 49)

# %%
colnames = df.columns
colnames
# Out:
# Index(['Submission ID', 'Portal', 'Portal Category', 'Last Name', 'First Name',
#        'Email', 'Status', 'Submission Date',
#        'In which graduate school are you currently enrolled at Boston College? (Check all that apply)',
#        'Which of the following best describes your degree program(s)?',
#        'What is your program of study?', 'What is your enrollment status?',
#        'Did you attend New Graduate & Professional Student Orientation on August 22, 2019?',
#        'You indicated that you did not attend orientation. What were your reasons for not attending? (Please check all that apply).',
#        'Please tell us why you were unable to attend orientation.',
#        'Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".',
#        'Are you able to locate one of the campus libraries?',
#        'Please list two opportunities for getting involved on campus as a graduate student.',
#        'Name one potential challenge you may face as a graduate student and identify a resource you learned about during orientation that could support you in navigating that challenge.',
#        'The returning student panel I attended was informative.',
#        'If you attended a returning student panel, please share any comments or suggestions about the panel you attended.',
#        'If you attended any Educational Sessions, which one(s) did you attend? Please mark up to two.',
#        'I learned something informative in the Life in the City: Getting to Know Boston educational session I attended.',
#        'Please share any comments or suggestions about the Life in the City: Getting to Know Boston educational session you attended.',
#        'I learned something informative in the Live the Mission: An Introduction to BC's Jesuit Tradition educational session I attended.',
#        'Please share any comments or suggestions about the Live the Mission: An Introduction to BC's Jesuit Tradition educational session you attended.',
#        'I learned something informative in the Strive to Thrive educational session I attended.',
#        'Please share any comments or suggestions about the Strive to Thrive educational session you attended.',
#        'I learned something informative in The Return to the Academy educational session I attended.',
#        'Please share any comments or suggestions about The Return to the Academy educational session you attended.',
#        'I learned something informative in the Financial Services educational session I attended.',
#        'Please share any comments or suggestions about the Financial Services educational session you attended.',
#        'I learned something informative in the Educational Tool to Get You Started educational session I attended.',
#        'Please share any comments or suggestions about the Educational Tool to Get You Started educational session you attended.',
#        'I learned something informative in the Life on the Heights: Getting to Know Boston College educational session I attended.',
#        'Please share any comments or suggestions about the Life on the Heights: Getting to Know Boston College educational session you attended.',
#        'I learned something informative in the What to Expect and How to Succeed in a Doctoral Program educational session I attended.',
#        'Please share any comments or suggestions about the What to Expect and How to Succeed in a Doctoral Program educational session you attended.',
#        'The online orientation registration process was easy, fast, and intuitive.',
#        'Orientation helped me to better understand the academic expectations of graduate school at Boston College.',
#        'Participation in orientation provided me opportunities to connect with new people (i.e. new students, current students, faculty, and staff).',
#        'At orientation, I learned about different resources available to graduate students, including clubs and organizations that I could join.',
#        'Orientation helped me feel connected to Boston College.',
#        'The length of orientation was:',
#        'Orientation helped me to better understand how to integrate my academic and personal/social lives during graduate school at Boston College.',
#        'Overall, how would you rate the orientation program?',
#        'What aspects of orientation did you find most useful?',
#        'What suggestions do you have for future orientations?',
#        'Is there any other feedback you would to share with us about orientation?'],
#       dtype='object')

# %%
df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'].unique()
# Out:
# array(['Graduate School of the Morrisey College of Arts & Sciences',
#        'Carroll Graduate School of Management',
#        'Lynch School of Education and Human Development',
#        'Woods College of Advancing Studies',
#        'School of Theology and Ministry', 'School of Social Work',
#        'Connell School of Nursing', 'Law School',
#        'Carroll Graduate School of Management, Law School',
#        'School of Social Work, School of Theology and Ministry',
#        'School of Social Work, Law School',
#        'School of Social Work, Woods College of Advancing Studies',
#        'Law School, Lynch School of Education and Human Development'],
#       dtype=object)

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == 'Graduate School of the Morrisey College of Arts & Sciences').sum()
# Out:
# 45

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == 'Carroll Graduate School of Management').sum()
# Out:
# 59

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "Lynch School of Education and Human Development").sum()
# Out:
# 81

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "Woods College of Advancing Studies").sum()
# Out:
# 26

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "School of Social Work").sum()
# Out:
# 77

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "Connell School of Nursing").sum()
# Out:
# 21

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "Law School").sum()
# Out:
# 5

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "School of Theology and Ministry").sum()
# Out:
# 23

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "Carroll Graduate School of Management, Law School").sum()
# Out:
# 1

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "School of Social Work, School of Theology and Ministry").sum()
# Out:
# 2

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "School of Social Work, Law School").sum()
# Out:
# 2

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "School of Social Work, Woods College of Advancing Studies").sum()
# Out:
# 1

# %%
(df['In which graduate school are you currently enrolled at Boston College? (Check all that apply)'] == "Law School, Lynch School of Education and Human Development").sum()
# Out:
# 1

# %%
df['Which of the following best describes your degree program(s)?'].unique()
# Out:
# array(["Master's", 'Doctoral', 'JD', "Master's, JD",
#        'Certificate of Advancing Studies'], dtype=object)

# %%
(df['Did you attend New Graduate & Professional Student Orientation on August 22, 2019?'] == "No").sum()
# Out:
# 182

# %%
(df['Did you attend New Graduate & Professional Student Orientation on August 22, 2019?'] == "Yes").sum()
# Out:
# 162

# %%
df['Please list two opportunities for getting involved on campus as a graduate student.'].unique()
# Out:
# array([nan, 'On-campus recruiting and student organizations.',
#        'International graduate student organization \nCampus recreation center',
#        "The Graduate Student Association\nThe Women's Center",
#        "Graduate Student Forum\nBC Women's Center",
#        'Student organizations, student government',
#        'Sports and graduate veterans association.',
#        'GSA and the Social Work Collective', 'Not sure',
#        'Gaudete, Murray House', 'Sport groups, TA opportunities',
#        'sport team, instrument team',
#        'GSA and conversation partners with international students',
#        'Grad student pride alliance.\nBoston College POC organization.',
#        'Graduate Student Assocation, attend events/programs put on by Murray house',
#        'orientation BBQ', 'Joining GSA or GSCA',
#        'Campus Ministries and Graduate Student Association',
#        'the GEA\nclub or intramural sports',
#        'Graduate Student Association, Murray House',
#        'Graduate student association, campus ministries retreats for grad students',
#        'I don’t know how to get involved yet', 'GSA and GEA',
#        'Ministry, connors family learning center',
#        'Murray House\nGraduate Education Association',
#        'Student government\nemployment oppurtunites',
#        'Graduate student government, other graduate student clubs',
#        '1. Getting permission to access libraries, where you can everything such as research papers, books, journals,\n2. Research services',
#        'Graduate student retreat\nOrientation leaders',
#        'GSA\nVeterans Association', 'GEA or other clubs/orgs',
#        'Joining the graduate student association and attending grad student events such as the tailgate party.',
#        'Graduate Student Association',
#        'get free windows office installation\nget free coffee and tea',
#        'Clubs (IntEnt, Marketing, Flag Football, etc.) I only know how to connect with other MBAs... would love to meet other grad students!!',
#        'GEA, OGSL', 'Murray Hall, do something you like.',
#        "Clubs (like the GSA Pride group) and volunteering in the Women's Center",
#        'Research\n\nStudents clubs/organizations', "Don't know",
#        'Graduate Pride Alliance\nCampus Ministry\nGraduate Student Association',
#        'Going to the Murray House to socialize with other graduate students \nAttending events hosted by the Graduate Student Association',
#        'Graduate Student Association;Career Fair',
#        'Graduate Student Association and going to football games',
#        'Join professional clubs, become a TA',
#        'Graduate organizations like GFA and the flag football team.',
#        'GSA and GMA', 'Tutors, assistantships',
#        'Murray Fellow House, Grad Student Collective',
#        'LSA 1L Section Rep\nLexis Rep', 'GSA\nClubs',
#        'Umoja\nStudent Government', 'library',
#        'To network and to grow and develop my knowledge and skill set.',
#        'Graduate Student Organization, Graduate Nurses Organization',
#        'Clubs and classes', 'GSA\nSports',
#        'Graduate Student Association and Student Social Work Collective  , UMOJA',
#        'GEA\nOISS',
#        "international student's organization \ngrad students association",
#        'Volunteering at the Diversity Challenge conference; attend Counseling lecture series',
#        'Student Social Work Collective \nGraduate Student Association',
#        'Murrey House \nRecreation Center',
#        'Joining the Graduate Student Association or visiting the Murray House for free coffee and tea (and fellowship!)',
#        'Clubs\nGraduate student events',
#        'Join the student clubs\nAttend events',
#        'The Murray House\nGrad tailgate parties for football games',
#        'International Student Organization.\nTeaching Excellence',
#        'I only went to the Woods College orientation.',
#        'Volunteering through the BC Neighborhood Center, School of Social Work Student Collective',
#        'Graduate Student Group', 'events, courses',
#        'Through the gym and the the GSA',
#        "Women's Center and Campus Ministry events!", 'Clubs\nGEA',
#        'GSA \n\nVisiting the Murray House',
#        'Graduate Students of Colors Association\nGraduate Students Association',
#        'Graduate Education Association and Graduate Student Life',
#        'graduate student association\ngraduate student veteran association',
#        'Hanging out at the Murray House\nUmoja', 'Cannot think of one.',
#        'Campus Ministry, BCWC', 'GISA and OGSL',
#        'Library, Orientation, Clubs',
#        'Language exchange \nLanguage learning center',
#        'STM Student Forum and Liturgical Ministries at STM',
#        'Murray House will host various activities monthly.\nOISS office also have events for grad students.',
#        'join in clubs and organizations\ngo to recreation centers to play sports',
#        'The group with the different name that means Unity.  They are having an icecream social and I will be attending.  Monthly meetings.',
#        'join the graduate association. school work for graduate students.',
#        'Gaudette and Lumen et Vita',
#        '-Sports\n-Graduate Student Association',
#        'Murray house\nGraduate student elections',
#        'Womens Center, Graduate Student Center',
#        'Being a Priest I may be able to be a part of conducting Retreats and spiritual activities.\n\nI can meet different people of different contexts and make friendship with them.',
#        'Meeting new people \nGetting to know campus and it’s resource',
#        'Graduate Student Association. Pride,',
#        'Lunch Time & Sunset Cruise',
#        'Join clubs like UMOJA and Volunteer opportunities',
#        'Volunteering, Sports Club', 'GEA, GSA, Graduate Student Pride',
#        'GSA\nGroups for International Students', 'GSA\nCTE',
#        'Fulfilling a Graduate Assistantship\nJoining a campus leadership organization (e.g. Graduate Student Association)',
#        'GSA, LGBTQ',
#        'Grad student union \nWomen’s center \nLGBTQ\nI can also utilize the gym if I pay for it as well as the counseling center',
#        'Latin group\nLGBTQ+ group\nWomen’s group', 'GSA\nHiking Club',
#        'Club Sports\nMurray House', 'Research positions, student groups',
#        'Graduate Student Association, IntEnt',
#        '1. GSA (Graduate Student Association)\n2. Murray House \n3. Graduate Retreat in November',
#        'Grad student association, graduate orientation',
#        'Graduate student association \nStudent veteran association - I realize this is not specific to grad students however it’ll feel like home with my brothers to me.',
#        'Graduate Student Association\nGraduate Education Association',
#        'Career Development Center,\nGraudate student center,\nGraduate Financial Association',
#        'I didn’t remember the name, but I am sure there some clubs and organizations that graduate student can join in.',
#        'Graduate Student Association\nClubs for graduates',
#        '- Student government\n- Making new friends at Murray House',
#        'student organization\nvolunteer', 'Join in student org;',
#        'I am attending the MSW program on a part-time basis.',
#        "International Student's Association, Tutoring English",
#        'Participating in the government of your field, and attending event hosted by the GSA.',
#        '1) On-campus job website for BC grad students\n2) Clubs and organizations that are on campus for grad students',
#        'Murray House and Volunteer Services though email newsletters',
#        'Murphy House', 'GSA\nIrish Studies',
#        'Graduate Student Association\nMurray House',
#        'Graduate Student Association and the Volunteer Center',
#        'Graduate Financial Association\nVeterans Association',
#        'Campus ministry, athlete tutoring',
#        'Graduate Education Association\nGraduate Student of Color',
#        'Student organization\ncommunity service',
#        'Carroll School Student Organization Fair(For example, GFA) \nEagle Linkin\nCanvas',
#        'Boston College Athletics, Campus Recreation',
#        'workshops, info sessions, career coaching',
#        'Melissa - women in business.',
#        'Join student organizations, attend workshop in liabraries',
#        'Clubs and students organization',
#        'Graduate Student Association\nInternational Graduate Student Association',
#        'Center for Teaching Excellence, Graduate Student Association',
#        'Graduate student association', 'Friday lunch-talk\nStudent Clubs',
#        'Organizations, dining halls',
#        '-Learning the general and the academic life in Boston and at BC in particular\n-Meeting people from various parts of the world with whom we shall share a lot',
#        'GSA and Murray house', '1. club sport\n2. Sunday mass',
#        'Doing on-campus job\nTaking part in football games',
#        'Murray house, social work collective', 'GISA, GSA, Murray House',
#        'GSA\nCampus Rec', 'Joining the GSA or the GEA at Lynch.', 'GSA',
#        'Center for Teaching Excellence, intramural sports.',
#        'Campus Ministry\nGraduate Student Life',
#        'Graduate Student Association (GSA)\nGraduate intermural sports',
#        'Attend events at Murray Hall\nAttend community service programs',
#        'Orientation. \nStudent organization.', 'Club sports, free coffee'],
#       dtype=object)

# %%
df['Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".'].unique()
# Out:
# array([nan,
#        'Yes, Fulton where the Carroll school of management is, and Murray house where the office of graduate student is. I also know a couple of others but I’m not sure how to write their names.',
#        'Yes\nGasson Hall\nRobsham theater arts center',
#        'Gasson Hall\nFulton Hall\nHiggins Hall\nMc Guinn',
#        'Lyons Hall\nGasson Hall', 'Carney, McGuinn',
#        "O'Neil Library\nLyons Hall", 'Gassing and Devlin',
#        "Campion Hall, Lyons Hall, Gasson Hall, O'Neil",
#        "Lyon, Simboli, O'Neal", 'No', 'o neil library,higgins hall',
#        'Fulton Hall and Devlin Hall', 'Lyons and Lynch.',
#        'Fulton, Gasson', 'no', 'Stokes and Lyons',
#        "Yes - Fulton and Lyons; also Campion; and O'Neill Library",
#        'McGuinn Hall, Carney Hall', 'Yes - Stokes hall and Fulton hall',
#        'Financial Aid \nCarney Hall',
#        "O'Neill Library, Devlin, Campion, McElroy, Lyons, and Gasson",
#        'Yawkey Center\nDevin Hall', 'Mcguinn Hall\nFulton Hall',
#        'Gasson, Lyons, Fulton', "Lyson's hall \nFulton Hall\nGasson hall",
#        'Lyons hall', 'Yes\nDevlin\nMcGuinn',
#        'No (mostly because buildings are poorly labeled and I am easily lost)',
#        'Yes', 'Yes. Lyons Hall and Maloney',
#        'Yes. I know Murray House that could provide us free coffee. And I know Robsham theater arts center.',
#        'Fulton Hall\nLyons Hall', 'Campion Hall\nDevlin Hall',
#        "O'nell library, the theater", 'Lyons & Maloney',
#        'McGuinn \n\nLyons', 'Fulton \nStokes',
#        'Maloney Hall (Residential Life)\nStokes Hall (humanities)\nDevlin Hall',
#        'Yes, Fulton Hall and Gasson Hall.',
#        'Chemistry Merket Center; Lyons Hall',
#        "St. Mary's Hall and O'Neill Library", 'Fulton Hall, Gasson',
#        'Murray House and the library', 'Fulton Hall, Lyons.',
#        'Lyons and Fulton',
#        'Stokes, Devlin, Oneill, Maloney\nMany buildings are multi purpose (class and administration).',
#        'McGuinn, Stokes',
#        'Student Services on the main  campus\nStudent Services on the Law School Campus',
#        'Lyons \nMurray house', 'Lyons Hall and McGuinn',
#        'Fulton Hall & Lyons Hall', 'Carney Hall\nMaloney Hall',
#        'Higgins\nGasson', 'Lyons Hall\nGassons Hall', 'Lyons \nGasson',
#        'Campion Hall and Devlin (where all my classes are)',
#        'Yes. McGuinn Hall, Gasson Hall', 'Lyons \nGassons',
#        'Gasson Hall and Simboli Hall', 'Champion Hall\nLyons Hall',
#        'Gasson Hall\nMurray House',
#        "Gasson, O'Neil, Burns, Stokes N/S, McElroy, Fulton, Robsham Theatre",
#        'Lyons\nMcElory', "Yes. Lyons Hall. O'Neill Library",
#        'McGuinn Hall\nFulton Hall', 'McGuinn Hall \nLyons Hall',
#        'Gasson, Fulton', 'Stokes\nO’Neill Library', 'Campion\nDevlin',
#        'Lyons Hall\n\nMcElroy Commons', 'Murray House and Gasson Hall',
#        'Lyons, Fulton',
#        "Corcoran Commons\nGasson\nFulton\nO'Neill\nYawkey\nBapst",
#        'Fulton \nHiggins', 'Stokes, Lyons',
#        "O'Neil Library and Fulton Hall",
#        'Gasson Hall, Fulton, Lions, O’Nell Library',
#        'Malloney Hall\nLyons Hall\nGasson Hall\nRobsham Theatre',
#        '- bapst library\n- stokes hall',
#        'SIMBOLI HALL and THEA BOWMAN HOUSE', 'Fulton Hall\nLyon\nGasson',
#        'Fulton\nLyons\nHiggins',
#        "Unfair question...I work in ResLife.  I know all the buildings, but if i didn't the libraries stand out: McGuinn Social Work Library, O'Neill, and Bapst.",
#        "yes. Gasson Hall. O'Neil library", 'Simboli Hall and Lyons Hall',
#        'Saint Mary Hall\nLyons Hall', 'McGuinn \nFulton\nGasson',
#        "O'Neill Library\nSimboli Hall\nLyons Hall\nMaloney Hall",
#        'Gasson hall, mcguinn hall', "Gasson, Fulton, O'Neil",
#        'Lyons Hall, Gasson Hall', 'Gasson Hall, Fulton Hall',
#        'McGuinn Hall\nLyons Hall', 'Gasson\nLyons\nMcElroy\nHiggins',
#        'Gasson Hall\nStokes Hall', 'Lyons, Lynch',
#        'Yes, Gasson, McGuinn, O’Neill library is all I need to know.',
#        'Lyons Hall\nGasson\nFulton',
#        'Merkert Chemistry Building \nHiggins',
#        'Gasson Hall\nStokes Hall (south and north)\nFulton Hall\nLyons Hall',
#        'Maloney Hall, Campion Hall',
#        'Yes. I know all of them as I was an undergrad at BC.',
#        'Gasson, Stokes, Lyons,\nFulton',
#        'Yes - Maloney, McEvoy and Carney', 'Gasson and Lyons',
#        "Maurrny House,\nO'Neil Library\nLyons House",
#        'gasson hall\nFulton',
#        'Yes, Campion and Fulton are academic buildings. An administrative building is Lyons.',
#        "Gasson, Lyons, Devlin, O'Neil", "Gym\nO'neill",
#        'Robsham hall; Fulton Hall; Gasson Hall', 'Lyons\nYawkey',
#        'Campion Hall, Student Services Office', 'Gasson Hall Lyons Hall',
#        '1) Lyons Hall\n2) The Woods\' building\n3) The "main" library and the library for grad students\n4) Stokes Hall',
#        'Yes. Fulton and Lyons', "Fulton, O'Neil library",
#        'Stokes and Gasson', 'Gassing Hall\nMcGuinn Hall',
#        'Gasson and Stokes', 'Gasson\nHiggins\nLyons\nFulton\nCarey',
#        'Gasson, lyons', 'Fulton Hall \nConnors Family Learning Center',
#        'Fulton Hall\nGasson Hall\nHiggins Hall',
#        'Fulton Hall  Higgins Hall',
#        "Yes. Campion Hall and the O'Neill Library",
#        'Yes - Gasson Hall, Burns Library', 'O’neil Library, Fulton Hall',
#        "O'Neil Library and Gasson Hall",
#        "Fulton Hall\nGasson Hall\nCampion\nO'Neill library",
#        "Gasson, O'Neil, Fulton, Stokes", 'Gasson\nLyons',
#        'OSIS (72 College Road)\nStudent Service Center (opposite to OSIS)',
#        'Main Library and Bowman, the office of International students and scholars',
#        'The Gasson Building and Lyons Hall',
#        'Gasson Hall, McQuinn Hall, Fulton Hall, Baptist library',
#        'Lyons Hall\nFulton Hall\nGasson Hall\nHiggins Hall',
#        "O'Neill Library, Gasson Hall", 'Fulton Hall \nLyons hall',
#        'Gasson\nStokes',
#        "Yes - Stokes, Lyons, Gasson, Maloney, Campion, McGuinn, Fulton, Carney, Higgins, O'Neill Library.",
#        'Lyons Hall\nFulton Hall', 'Yes: Fulton Hall and Gasson Hall.',
#        'Lyon\nStroke (North and South)', 'Lyons hall\nStokes hall',
#        'Higgins Hall, Fulton hall, Murray hall', 'Library carrol',
#        'Gason, Maloney'], dtype=object)

# %%
df['Name one potential challenge you may face as a graduate student and identify a resource you learned about during orientation that could support you in navigating that challenge.'].unique()
# Out:
# array([nan,
#        'The challenge of dealing with the change of environment and balancing my social and my academic life. I can go to Graduate Students Life office where I can get counciling.',
#        'How to get a parking permit(lol) \nThe student service office',
#        'Be efficient when conducting research > Referent Librarian',
#        'Staying awake to study --> free coffee at the Murray House :)',
#        'Making friends - student orgs, Murray house, campus events',
#        'Researching challenges, Library research assistants can help with that.',
#        'Transition to graduate student life. A resource that could support me in navigating this challenge is professors and advisors as well as University Counseling Services',
#        'Research tutorials', 'The winter--sun lamps and exercise',
#        'It may be hard to come to terms with the fact that my life as an undergraduate is over. I can use the mental health resources on campus to battle said challenge.',
#        'how to deal with your students\ncontact the seniors for help',
#        'More in-depth research; subject-area librarians',
#        'Stresses of the workload, can be helped by seeking out counseling.',
#        'Finding a job straight out of grad program, Career center & Alumni network',
#        'find a job  career help center',
#        'struggling with self care; take advantage of health and counseling',
#        'Finding resources for an essay, with which the department-specific librarian can help.',
#        'balancing personal life and graduate school --> could seek help at the University Counseling Services',
#        "One potential challenge that may arise is difficulty transitioning not only to the academic demands of graduate school, but also a new environment in the city of Boston. Adjusting to a new location, in addition to learning the public transportation system, may negatively impact new students. However, I learned about the counseling center's eagerness to assist the student body with feeling more comfortable and overcoming self-doubt or insecurities.",
#        'Research using a new database for term papers. I learned some tips on how to properly use the BC library as a resource.',
#        'A challenge I would face as a graduate student would be doing the research for all my projects and the resource I learned about was in the O’Neil library resources and online resources.',
#        "One potential challenge is adjusting to the new academic expectations of my master's program and I learned about resources within the library to help with research and writing papers.",
#        'Writing papers again — library citation software can help',
#        'Difficulty in academic research.\n\nResearch services',
#        'A challenge I will probably face is getting back into academic essay writing and I know I can go to the connors center for help.',
#        'Research or writing papers there are resources at the library',
#        'As my background is different, I need to learn more about analysis, software packages . Research services are providing free tutorials which will help us to gain knowledge in many areas.',
#        'Counseling services if you need help with mental health',
#        'Long-term mental health services \n\nBCBS Student plan waiving co-pay for off campus support',
#        '$, financial aid office',
#        'Researching for a project. Using the libraries extensive system for obtaining materials.',
#        'Finances and I learned about the financial advisor that is available to all grad students',
#        'I might miss home. I know there is consulting help in campus.',
#        'Having peer mentors who have just gone through what I am about to. My college arranged for student mentors and I would love that program here to have someone check in on me & have someone to ask unfiltered questions to.',
#        'Seasonal affective disorder (adjusting to the climate) and going to the health center for 10 free counseling sessions',
#        'writing skills would be a challenge, and writing support would available in the library.',
#        "As a commuter student, I'll be driving in to bC everyday so it was especially nice to hear about peak/off peak times for parking.",
#        'The need for textual resources --> the social work library',
#        'Not being sure when assignments are due and checking canvas for due dates',
#        'A challenge would be getting to and from campus without a vehicle. A solution would be the reduced T pass available through Boston College via, I believe, Lyons Hall.',
#        'One potential challenge is me not finding a quiet area to study, away from undergraduate students but I identified a resource, such as the Murray house where graduate students can study.',
#        'writing in English; Dissertation Writing Group',
#        'balancing a full-time job, part-time job, social life and schoolwork',
#        'A challenge that I may face is not knowing how to get connected with other students on campus. I learned from the orientation that the Murray House is a center that is exclusive for graduate students.',
#        'ways to get involved - graduate student association',
#        'Meeting new students outside of my specific program. Possibly heading to the Murray house?',
#        'Balancing a busy school schedule and making sure that I still work out and eat right. Office of health promotion can help me with that',
#        'Literature review, every BC school has a librarian assigned to help',
#        'Prioritizing my mental health. During orientation I learned that the University’s Counseling Services were also available to graduate students.',
#        'Getting a summer internship, CSO at the Law School',
#        'Time management/finding time and space to study\n\nVarious libraries, Murray house, tutoring center',
#        'Balancing the demands of school and work.  I can reach out to the counseling center if needed.',
#        'diversity',
#        'Meeting with current part-time graduate students was very helpful! The balance of work and school work is going to be a challenging. However, the current students provided me with several ways to navigate this challenge. For instance, they specified that attendance and participation is on the top of most professors grading scale. As long as all assignments are completed on time and you put the time in to study and network with your cohorts, then you will be successful in the part-time MBA program.',
#        'Parking - received my permit and good tips at the QandA',
#        'getting lost and finding parking but using the many libraries as support',
#        'Research may be challenging, and I learned about the research support at BC.',
#        'Struggling with increasing demands can take a toll on mental health- you can visit the Counseling Center.',
#        'Improving my writing skills --> Center for Teaching Excellence',
#        'stress \\ anxiety - counseling service',
#        'Health problems -> BC health services',
#        'Struggling to balance school/friends/family/work/self-care. Use Student Counseling services as needed!',
#        'Meet new people: Join the groups and clubs that created for Grad students',
#        'One potential challenge would be figuring out new, graduate student-specific study habits, and it sounds like the Murray house is a great resource for meeting other grad students, learning from one another, and creating new study habits together.',
#        'Feeling isolated/ lonely can be solved or bettered from join groups or attending student events',
#        'The career affair\nGo to the career center and ask for advice',
#        'Challenge: Stress; Resource: counseling center offerings/outsourced suggestions',
#        'Challenge: Securing study space\nResource: Murray House and graduate space in Bapst Library',
#        'Mental Health Services',
#        'Balancing my School Work along with adjusting to living in a new city.  I learned about the counseling center and different counseling sessions available to me, as well as to meet new friends at the Murray House',
#        'speaking with a professor',
#        'During the winter, the snow will affect the train. But we can take the shuttle if the train does not work.',
#        'Stress, and Morrisey House',
#        'I learned out the mental health resources',
#        'Feeling overwhelmed: There is free mental health counselors available to students with the blue cross blue shield insurance plan',
#        'Struggling to balance graduate student life with married life. Meeting other graduate students at the Murray House, finding groups of students who may be in similar situation.',
#        'As a graduate student, it is very stressful and can be overwhelming. But after orientation, I know there is the Counseling Services that I can go to for some help and support.',
#        'For me it will be meeting friends but I was told about many different social activities put on by the varying student associations and that the Murray house will be available for me to use a sort of hub',
#        "online research tools - o'neill library",
#        'Balancing time and getting lost in schoolwork to the point of overwhelm... resource would be to schedule your study time, work time, and family time, and work hard to keep that schedule.',
#        'Huge study load. Library offers a lot of resources to help students with their coursework.',
#        'Mental health, counseling centre',
#        'School load will get complicated and demanding. It is important to find ways to dedicate time for my personal interests or hobbies.',
#        'Different language, hard to understand new courses...',
#        'Stress and anxiety University Health Services',
#        'we learned about the counseling center',
#        'Balancing academic work with leisure. iPlan could support me in navigating that challenge.',
#        'English is not my native language. So I may meet some problems in essays. Gratefully, the learning centre will offer help.',
#        'encounter problems when living off-campus\ngo to Office of Residential Life for help',
#        'Working full-time at BC and part-time in a homeless shelter for women and children will make my internships very difficult.  Especially, if a weekend or evening internship is not possible.',
#        'communicate in English. communicate partner.',
#        "I'll be commuting from at least an hour away, so I won't really be able to get involved or make friends. I don't think there's a resource for that.",
#        '-Homesickness. I can get help from the Counseling Services.',
#        'Financial struggle, going to student services',
#        "I know where to get computer hardware help in O'Neill Library",
#        "Language is a challenge before me as I don't grasp all things that are spoken by others.\nEveryone is so kind and generous to help me in this matter.",
#        'Parking- learnt about the best time to drive to campus and potentially get a parking spot',
#        'Stress: mental health resources are free with student insurance!',
#        'Severe weather - emergency toolkit',
#        'Juggling school, full time job, and field placement. Have family as a support system, school offers counseling, and also a support group meetings',
#        'Psycological distress, Counseling',
#        'Personal wellness and caring properly for myself, university counseling services can help me if I struggle with this',
#        'One challenge might be research and, relatedly, research technology (e.g. Mendeley or Zotera)\nThe Library and Technology Departments will work with you.',
#        'Teaching Fellows can be supported by CTE.',
#        "Balancing work and academic responsibilities will prove to be a challenge at times. While it wasn't a newfound piece of advice, I did find the testimonials of advisors, administrators and even current students, stressing the importance and value of communication with professors and supervisors in navigating potential challenges, to be validating in the hopes that I will transition successfully this fall and over the remainder of the program length.",
#        'Transitions\nMeditation or yoga',
#        'The writing center and tutoring, the center on the second floor of the library',
#        'Technology \nO’Neil Library and the IT help desk',
#        'Mental Health- Health Services',
#        'commuting, and the resource is the t',
#        'Stress with courseload - counseling center',
#        'I am coming to graduate school after having been in the workforce for a few years, so I am nervous about getting back into an academic mindset. I might face challenges when trying to write papers and correctly site sources. I learned about the resources that the library offers, and more specifically the subject-specific librarians, that are available to help graduate students.',
#        'As a part-time Graduate Student, finding the time to engage in campus life may be difficult due to the limited time I will spend on campus. However, the Murray House provides a unique opportunity for students to meet others, study, and to build a strong community.',
#        'Finding quiet, graduate-only study space. Murray House and a dedicated grad-only study area in Bapst Library are available',
#        'A lot of research and library use - Wanda is my librarian (nursing) and I can make an appointment with her!',
#        'Transitioning into a new city and program, managing my time, and taking care of myself. I know that University Counseling services can help with this, and I downloaded the Welltrack app.',
#        "can't easily get access to career resources.\nThe resource i learned from yesterday is the GRADUATE SUEDENT CAREER CENTER that provide us BC student with Eagle Link which will make us connect to plenty of resources about our future career.",
#        'how to use internet tools.',
#        'Transitioning can be challenging, and counseling services are available to students (same day drop-in, scheduled appointments, 30 minute consultations).',
#        '- Becoming too monomaniacal about studies and not having balance.  A resource:  Variety of programs to support spiritual engagement & wellbeing.',
#        'missing on campus?',
#        'A potential challenge of me as a graduate student as well as an international student is how to adapt myself to USA culture and expand my networking. I learned that I can utilize places like Murray House to gather with other students, take each opportunity to immerse into local environment.',
#        'One challenge that comes to mind is having time to work full-time and attend part-time.  \n\nI hope that the accessibility and availability of the library will be helpful to my school work.',
#        'Getting stressed out. Recreational Center would help. Get some exercise, regularly.',
#        'Acclimation to a new location is a big one for many, there are many resources from provided from study spaces and also therapy on campus.',
#        'Being overwhelmed by schoolwork\n--> Asking help to professors might be the solution',
#        'Financing my education. There is an office for financial aid and planning to assist me with this',
#        'Balancing school and work', 'Anxiety - the counseling center',
#        'Struggling with Mental illness, or other mental health issues. Can get help at the counseling center',
#        'During my studies as an English major, I may require access to specific texts for research that are hard to locate on my own. At orientation, I was assured that the school library will be able to track down these texts for me, and that the reference librarians are also extremely helpful in case I have to seek out alternative sources.',
#        'Struggling with courses\nSolution: Carey hall houses the graduate student services and the faculty are willing to work with me in finding a tutor',
#        'Boston winters. Resource: LL Bean',
#        'One of the challenges I anticipate as first year graduate student is finding balance between work-life, personal-life and academic commitments. During orientation I was comforted by former and current BC students advice on finding and maintaing balance - more specifically, making sure to carve out time to continue doing at least one thing you enjoy.',
#        'career path， such as resume revision and self improvement\ncareer service office will be helpful in this aspect',
#        'Seeking job ： Career development office and eagle linkin & grad leader',
#        'Getting back into the swing of academics/ writing papers after not being in school for 4 years. The Connors Family Learning Center offers tutoring and help.',
#        'find the internships and job opportunity',
#        'finding the right buildings!  i figured out how to get there from boston on the green line and how much time to allow, etc.',
#        'I didn’t know how to use some area in libraries, the library tour taught me how to use and who to ask.',
#        'Writing paper, learning center',
#        'Learn about diverse research methods needed for my doctoral study; free research services offered by library',
#        'Returning to the academy and having to re-learn my field and academic writing',
#        'Balance between study and teaching',
#        'Medical need: health and wellness service is available under the MCAS building; also for medical assistance, go to 2150 Commonwealth Ave',
#        'Sexual assault',
#        '- Getting acquainted with the academic life at BC.  This challenge will be solved by cooperation with my department and my fellow graduate students',
#        'If I were to have trouble writing or needing some extra help I could go see the connors family learning center',
#        'challenge: depression, anxiety\nsource: counseling center in Gasson Hall',
#        'To find a job\nUse eagle link',
#        'Maintaining relationships, counseling office',
#        'Writing: learning center, education librarian at O’Neil',
#        'Work/life balance - Counseling Services',
#        'I work full-time on campus at CSON so just balancing the duties of my job with my duties as a graduate student and also being able to put both on the back burner to take care of myself as a person.',
#        'Adjusting to working full time and doing school part time\nCareer services',
#        'I could use Academic Research Services to learn more about doing research.',
#        'Writing research papers can be challenging. However Connor Learning center can offer assistance in this regard.',
#        'Managing stress as a graduate student -- using campus counseling services to talk to a trained professional, using the campus gym',
#        'living off-campus may let us miss some of the interesting events in campus. I can always check the school website and emails from Office of Graduate Student Life to get help.',
#        'Job.', 'Teaching'], dtype=object)

# %% [markdown]
# ## Enrollment in survey
#
# 81, 77, 59, 45, 26, 23, 21, 5, 2, 2, 1, 1, 1

# %%
enroll = df.groupby("In which graduate school are you currently enrolled at Boston College? (Check all that apply)")
enroll.size().sort_values(ascending=False).plot.bar()

# %%
enroll = df.groupby("Which of the following best describes your degree program(s)?")
enroll.size().sort_values(ascending=False).plot.bar()

# %%
attend = df.groupby("Did you attend New Graduate & Professional Student Orientation on August 22, 2019?")
attend.size().sort_values(ascending = False).plot.bar()

# %% [markdown]
# > 41% of the people answering surveys have attended the orientation (162/182).

# %%
# Start with one review:
excuse = df["You indicated that you did not attend orientation. What were your reasons for not attending? (Please check all that apply)."]
excuse.dropna(inplace = True)
text = " ".join(review for review in excuse)

# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["hours", "another"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Start with one review:
excuse = df["Please tell us why you were unable to attend orientation."]
excuse.dropna(inplace = True)
text = " ".join(review for review in excuse)

# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["orientation", "student", "program", "attend", "school", "year"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Place Location

# %%
len(df['Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".'].unique())
# Out:
# 149

# %%
(df['Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".'] == 'No (mostly because buildings are poorly labeled and I am easily lost)').sum()
# Out:
# 1

# %%
(df['Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".'] == 'no').sum()
# Out:
# 3

# %%
(df['Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".'] == 'No').sum()
# Out:
# 5

# %%
# isnull
df['Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".'].isnull().sum()
# Out:
# 182

# %%
bldg = df['Are you able to identify at least two academic or administrative buildings on the BC campus? If so, please list them below. If not, write "No".']
bldg.dropna(inplace = True)
text = " ".join(review for review in bldg)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["yes", "Hall"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# > 182 didn't answer the question, 9 answered "no";
#
# 97.4% of participants are able to name two buildings.

# %%
df['Are you able to locate one of the campus libraries?'].unique()
# Out:
# array([nan, 'Yes', 'No'], dtype=object)

# %%
(df['Are you able to locate one of the campus libraries?'] == "Yes").sum()
# Out:
# 157

# %%
(df['Are you able to locate one of the campus libraries?'] == "No").sum()
# Out:
# 5

# %%
df['Are you able to locate one of the campus libraries?'].isnull().sum()
# Out:
# 182

# %%
lib = df['Are you able to locate one of the campus libraries?']
lib.dropna(inplace = True)
text = " ".join(review for review in lib)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
#stopwords.update(["yes", "Hall"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# > 182 didn't answer the question, 5 anwered "no;
#
# 98.5% of participants are able to name one library.

# %% [markdown]
# ## Understanding

# %%
df["Please list two opportunities for getting involved on campus as a graduate student."].isnull().sum()
# Out:
# 183

# %%
oppo = df["Please list two opportunities for getting involved on campus as a graduate student."]
oppo.dropna(inplace = True)
text = " ".join(review for review in oppo)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df["Name one potential challenge you may face as a graduate student and identify a resource you learned about during orientation that could support you in navigating that challenge."].isnull().sum()
# Out:
# 183

# %%
challenge = df["Name one potential challenge you may face as a graduate student and identify a resource you learned about during orientation that could support you in navigating that challenge."]
challenge.dropna(inplace = True)
text = " ".join(review for review in challenge)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["student", "challenge", "graduate student", "will"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Returning Student Panel

# %%
df["The returning student panel I attended was informative."].unique()
# Out:
# array([nan, 'Neither agree nor disagree', 'Strongly Agree', 'Agree',
#        'Did not attend', 'Disagree'], dtype=object)

# %%
(df["The returning student panel I attended was informative."] == "Disagree").sum()
# Out:
# 2

# %%
(df["The returning student panel I attended was informative."] == "Neither agree nor disagree").sum()
# Out:
# 10

# %% [markdown]
# > Only 3.49% of the survey participants felt the student panel was not informative or neither agree nor agree with the statement.

# %%
panel = df["If you attended a returning student panel, please share any comments or suggestions about the panel you attended."]
panel.dropna(inplace = True)
text = " ".join(review for review in panel)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["student", "panel", "students", "returning"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Ed Session

# %%
ed = df["If you attended any Educational Sessions, which one(s) did you attend? Please mark up to two."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df.groupby("If you attended any Educational Sessions, which one(s) did you attend? Please mark up to two.")
ed.size().sort_values(ascending = False).plot.bar()

# %%
ed = df["Please share any comments or suggestions about the Life in the City: Getting to Know Boston educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df["Please share any comments or suggestions about the Live the Mission: An Introduction to BC's Jesuit Tradition educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["student", "Really"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df["Please share any comments or suggestions about the Strive to Thrive educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["take", "session", "different", "school", "really"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df["Please share any comments or suggestions about The Return to the Academy educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["panel", "student"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df["Please share any comments or suggestions about the Financial Services educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["session", "financial"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df["Please share any comments or suggestions about the Educational Tool to Get You Started educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["many"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df["Please share any comments or suggestions about the Life on the Heights: Getting to Know Boston College educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["session", "really", "university", "student"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
ed = df["Please share any comments or suggestions about the What to Expect and How to Succeed in a Doctoral Program educational session you attended."]
ed.dropna(inplace = True)
text = " ".join(review for review in ed)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["session", "really", "people", "student"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Online Orientation

# %%
df["The online orientation registration process was easy, fast, and intuitive."].unique()
# Out:
# array([nan, 'Strongly Agree', 'Agree', 'Neither agree nor disagree',
#        'Disagree', 'Strongly Disagree'], dtype=object)

# %%
df["The online orientation registration process was easy, fast, and intuitive."].isnull().sum()
# Out:
# 182

# %%
(df["The online orientation registration process was easy, fast, and intuitive."] == "Strongly Disagree").sum()
# Out:
# 2

# %%
(df["The online orientation registration process was easy, fast, and intuitive."] == "Disagree").sum()
# Out:
# 2

# %%
(df["The online orientation registration process was easy, fast, and intuitive."] == "Neither agree nor disagree").sum()
# Out:
# 10

# %% [markdown]
# > 162 answered the question regarding the online orientation, but 14 participants were not very much satisfied.
# WHY?

# %% [markdown]
# ## Comments

# %%
comment = df["What aspects of orientation did you find most useful?"]
comment.dropna(inplace = True)
text = " ".join(review for review in comment)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["helpful", "useful"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
comment = df["What suggestions do you have for future orientations?"]
comment.dropna(inplace = True)
text = " ".join(review for review in comment)
# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
stopwords.update(["student", "students", "orientation", "maybe", "session", "people"])
wordcloud = WordCloud(stopwords=stopwords).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
