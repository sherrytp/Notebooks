# %% [markdown]
# ## Options Correlation
#
# This file is created for the project 3 of Option Correlation. Even though the size of equity/stock is (9242, 1397), dating from 2014-01-02, the size of options is (), dating only for a month. The purpose of this project is to compare the daily options prices of each company/ticker against the equity price change.
#
#
#
# * **SP Tian**
# * **Aug 1, 2019**
#
#
# **def function to judge whether it's at the money within a month
# def a month
# at the money price range **
# > weekly options

# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
def plot_corr(df, size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    img = ax.matshow(corr)
    fig.colorbar(img)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

# %%
# No need to run 
SP500 = pd.read_excel("SP500.xlsx", sheetname = "Ticker", index_col=None, header=None)
SP500 = SP500[0]
SP500.to_pickle("SP500 tickers.pkl")
SP500.sample(20)
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
# 180     RHT
# 63       GE
# 372      CE
# 328     EFX
# 294    FAST
# 450     MOS
# 457    NLSN
# 223     RCL
# 104    SPGI
# 89      CSX
# 411     AES
# 330     PFG
# 483       M
# 331    NTAP
# 311    CPRT
# 306     KEY
# 269     LLL
# 118     ITW
# 24       HD
# 481      LB
# Name: 0, dtype: object

# %%
SP500 = pd.read_pickle("SP500 tickers.pkl")
print(SP500.shape)
SP500.sample(20)
# Out:
# (511,)
# 250     PPL
# 213     MSI
# 210    XLNX
# 121    ILMN
# 494     HRB
# 115     EXC
# 372      CE
# 90      TJX
# 414     COG
# 172     HUM
# 427     EMN
# 176      DG
# 237     GLW
# 380     ROL
# 374     CPB
# 16      DIS
# 200     EQR
# 275    ULTA
# 268     SWK
# 116      WM
# Name: 0, dtype: object

# %%
optionschain = pd.read_excel("SP500.xlsx", sheetname = "Options", index_col=None, header=None)
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py:188: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
print(optionschain.shape)
optionschain[0].sample(10)
# Out:
# (103066, 2)
# 8330     @BAC   190802P00030000
# 67911    @AZO   190906C01132500
# 83706    @NTAP  190802P00053500
# 95032    @COG   210115P00018000
# 64666    @LRCX  190823P00197500
# 36497    @PNC   190906C00130000
# 38486    @ISRG  191018P00560000
# 15709    @C     190823C00075000
# 74400    @SWK   190809P00138000
# 35041    @COP   190830C00060000
# Name: 0, dtype: object

# %% [markdown]
# > SP500: all S&P 500 tickers
#
# > Equity: all equity tickers
#
# > Optionschain: all 10,000+ option tickers
#
# > Options: 20 companies, 20 put and 20 cut

# %%
equity = pd.read_excel("SP500.xlsx", sheetname = "Equity", index_col='Date')
equity.sample(10)
# Out:
#               MSFT      AMZN     AAPL     GOOGL     GOOG   BRK.B      FB  \
# Date
# 2018-12-04  108.52  1668.400  176.690  1062.470  1050.82  210.12  137.93
# 2015-03-02   43.88   385.655  129.090   575.020   571.34  147.08   79.75
# 2015-11-25   53.69   675.340  118.030   769.260   748.15  135.13  105.41
# 2014-07-28   43.97   320.410   99.020   599.020   590.60  127.74   74.92
# 2014-04-02   41.35   341.960   77.507   568.118   567.00  124.47   62.72
# 2017-01-09   62.64   796.920  118.990   827.180   806.65  162.02  124.90
# 2019-01-11  102.80  1640.560  152.290  1064.470  1057.19  196.29  143.80
# 2016-07-06   51.38   737.610   95.530   708.970   697.77  142.51  116.70
# 2015-06-19   46.10   434.920  126.600   557.520   536.69  140.96   82.51
# 2016-04-05   54.56   586.140  109.810   758.570   737.80  141.20  112.22
#
#                   V     JNJ     JPM  ...    HOG    PWR    JEF    MAC   CPRI  \
# Date                                 ...
# ...

# %%
equity.shape
# Out:
# (1396, 505)

# %%
put_op = pd.read_excel("SP500.xlsx", sheetname = "OptionsPut", index_col='date')
print(put_op.shape)
put_op
# Out:
# (22, 99)
#             @MSFT  190906P00139000  @AMZN  190906P01830000  \
# date
# 2019-08-13                    3.58                   51.88
# 2019-08-12                    5.35                   70.00
# 2019-08-09                    3.90                   57.01
# 2019-08-08                    3.85                   51.56
# 2019-08-07                    6.35                   85.00
# 2019-08-06                    7.00                   79.50
# 2019-08-05                    7.42                  103.10
# 2019-08-02                    5.47                   62.45
# 2019-08-01                    4.51                   45.35
# 2019-07-31                    5.50                   26.93
# 2019-07-30                    2.53                   22.33
# 2019-07-29                    2.31                   16.30
# 2019-07-26                    2.10                     NaN
# 2019-07-25                    2.77                     NaN
# 2019-07-24                     NaN                     NaN
# ...

# %%
call_op = pd.read_excel("SP500.xlsx", sheetname = "OptionsCall", index_col='date')
print(call_op.shape)
call_op
# Out:
# (22, 99)
#             @MSFT  190906C00139000  @AMZN  190906C01830000  \
# date
# 2019-08-13                    2.75                   44.00
# 2019-08-12                    2.09                   32.90
# 2019-08-09                    2.80                   45.20
# 2019-08-08                    3.30                   53.55
# 2019-08-07                    2.09                   40.70
# 2019-08-06                    2.05                   41.93
# 2019-08-05                    1.49                   39.65
# 2019-08-02                    2.47                   56.20
# 2019-08-01                    3.35                   93.45
# 2019-07-31                    2.31                     NaN
# 2019-07-30                    3.75                     NaN
# 2019-07-29                    4.25                     NaN
# 2019-07-26                    4.50                     NaN
# 2019-07-25                    3.59                     NaN
# NaT                            NaN                     NaN
# ...

# %%
from scipy import interpolate
interpolate?

# %%
plot_corr(equity)

# %%
plot_corr(put_op)

# %%
plot_corr(call_op

# %%
corr_df = equity.corr(method='pearson')
corr_df.style

# %%
corr_put = put_op.corr(method='pearson')

# %%
corr_call = call_op.corr(method='pearson')

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

corr_call.style.applymap(color_negative_red)

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

corr_call.style.apply(highlight_max)

# %%
corr_put.style.applymap(color_negative_red).apply(highlight_max)

# %% [markdown]
# Style functions should return strings with one or more CSS attribute: value delimited by semicolons. Use
#
# 1. Styler.applymap(func) for elementwise styles
# 2. Styler.apply(func, axis=0) for columnwise styles
# 3. Styler.apply(func, axis=1) for rowwise styles
# 4. Styler.apply(func, axis=None) for tablewise styles

# %%
cm = sns.light_palette("green", as_cmap=True)
corr_put.style.set_caption('Colormaps, with a caption.').background_gradient(cmap=cm)   # create heatmap using ```background_gradient```

# %%
# Uses the full color range
corr_put.loc[:4].style.background_gradient(cmap='viridis')

# Compress the color range
(df.loc[:4]
    .style
    .background_gradient(cmap='viridis', low=.5, high=0)
    .highlight_null('red'))

#corr.style.background_gradient(cmap, axis=1)\
#    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
#    .set_caption("Hover to magify")\
#    .set_precision(2)\
#    .set_table_styles(magnify())

# corr_put.style.highlight_null().render().split('\n')[:10]

# %%
# Hover to highlight in html 

from IPython.display import HTML
def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = (corr_call.style.set_table_styles(styles)
          .set_caption("Hover to highlight."))
html

# %%
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0., 99.9), l=(0., 99.9)):
    return corr_put.style.background_gradient(
        cmap=sns.palettes.diverging_palette(h_neg=h_neg, h_pos=h_pos, s=s, l=l,
                                            as_cmap=True)
    )

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "4pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

# %%
np.random.seed(25)
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
bigdf = pd.DataFrame(np.random.randn(20, 25)).cumsum()

bigdf.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
corr_put.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
corr_call.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %% [markdown]
# SP100 Correlation Plot
